# %%
import re
import json

class WordPieceTokenizer:
    
    """
    Initialisation: 
    1. Create a dictionary to store vocab and another to store freq
    2. Define vocab size
    """
    def __init__(self, vocab_size : int):
        
        self.vocab = []
        self.word_freq = {}
        self.vocab_size = vocab_size
    
    """
    Preprocessing: 
    1. Convert to lower case
    2. Split into words & remove spaces
    3. Remove numbers & non-alphabetic chars like ",", ".", "!" etc. 
    4. Returns an array of strings
    """
    def preprocess_data(self, text: str):
        
        text = text.lower() 
        text = re.sub(r"[^a-zA-Z\s]", "", text) #replacing characters using RegEx
        return text.split()
    
    """
    Vocab Construction: 
    1. Preprocess the data and store in dict the frequency of every word/token
    2. Create alphabets from the  by splitting each word into letters
    3. Create splits for every word i.e. storing letters of each word in a dictionary
    4. 
    """
    def construct_vocabulary(self, corpus: list):
        
        # we get corpus as a list of sentences
        # preprocess the list and store word frequencies
        for sentence in corpus:
            tokens = self.preprocess_data(sentence)
            
            for token in tokens:
                self.word_freq[token] = self.word_freq.get(token, 0) + 1
                
        # create an initial vocabulary and splits for every word
        initial_vocabulary = [] #unique morphemes stored
        splits = {}
        for word in self.word_freq.keys():
            if word[0] not in initial_vocabulary:
                initial_vocabulary.append(word[0])
            splits[word] = []
            splits[word].append(word[0])
            
            for remaining_letter in word[1:]:
                if f"##{remaining_letter}" not in initial_vocabulary:
                    initial_vocabulary.append(f"##{remaining_letter}")
                splits[word].append(f"##{remaining_letter}")
            
        initial_vocabulary.sort()
        
        self.vocab = ["[PAD]", "[UNK]"] + initial_vocabulary.copy() # adding two special tokens to vocab
        
        # compute scores for pairs
        # merge pair
        # continue until desired vocab size is reached
        while len(self.vocab) < self.vocab_size:
            
            # calculate the scores for every possible pair in a given words' split
            scores = self.compute_all_pair_scores(splits) # returns a dictionary => pair (tuple) : score (float)
            best_pair, max_score = (), -1
            for pair, score in scores.items():
                if max_score == -1 or max_score < score:
                    best_pair = pair
                    max_score = score
             
            # merge the best pair selected in all the splits and add the merged pair to vocab   
            splits = self.merge_best_pair(best_pair[0], best_pair[1], splits)
            
            merged_pair = ""
            if best_pair[1].startswith("##") :
                merged_pair = best_pair[0] + best_pair[1][2:]
            else :
                merged_pair = best_pair[0] + best_pair[1]
                
            self.vocab.append(merged_pair)
        
        self.save_vocabulary()
            
    """
        Tokenization Process:  
        1. We preprocess the input text to clean and normalize it.  
        2. We tokenize each word into subword units using the `subword_tokenise` method.  
        3. We flatten the list of subword tokens to get a single sequence.  
        4. Finally, we return the complete list of subword tokens.  
    """
    def tokenize(self, text: str):
        processed_text = self.preprocess_data(text) 
        
        subword_tokens = []  
        for word in processed_text:  
            subword_tokens.append(self.subword_tokenise(word))  
            
        flattened_tokens = []
        for tokens in subword_tokens:
            flattened_tokens.extend(tokens)   
            
        return flattened_tokens

    
    
   ####----------------------##____________Helper Methods____________##----------------------####
    
    def save_vocabulary(self):
        vocab_file = f"../Data/vocabulary_86.txt"
        with open(vocab_file, "w") as f:
            for token in self.vocab:
                f.write(f"{token}\n")
    
    
    """
    Pair Score Computation:  
    1. We count the frequency of individual tokens and adjacent token pairs from word splits.  
    2. Then store token frequencies in `letter_freq_dict` and pair frequencies in `pair_freq_dict`.  
    3. Compute the score for each token pair using their frequency and individual token frequencies.  
    4. Return the computed scores for determining merge priorities in tokenization.  
    """
    def compute_all_pair_scores(self, splits):
        letter_freq_dict = {}
        pair_freq_dict = {}
        
        #cnt the occurrences
        for word, cnt in self.word_freq.items():
            
            split = splits[word]
            for token in split:
                letter_freq_dict[token] = letter_freq_dict.get(token, 0) + cnt
            
            if len(split) == 1 :
                continue
            else: 
                for i in range(len(split)-1):
                    pair = (split[i], split[i+1]) 
                    pair_freq_dict[pair] = pair_freq_dict.get(pair, 0) + cnt
                    
        scores = {}
        #calc the score
        for pair, freq in pair_freq_dict.items(): 
            score = freq / (letter_freq_dict[pair[0]] * letter_freq_dict[pair[1]])
            scores[pair] = score
                
        return scores
    
    
    """
    Best Pair Merging:  
    1. We iterate over each word and look for occurrences of the given token pair (a, b).  
    2. If we find the pair, we merge it into a single token and update the word’s split.  
    3. We ensure the updated split is stored back, allowing further merges if needed.  
    4. Finally, we return the modified splits with the merged tokens.  
    """
    def merge_best_pair(self, x, y, splits):
        for word in self.word_freq:
            split = splits[word]
            i = 0
            # continue until we've checked all adjacent pairs in the split.
            while i < len(split) - 1:
                if split[i] == x and split[i + 1] == y: 
                    if y.startswith("##"):
                        merge = x + y[2:]
                    else:
                        merge = x + y
                    split = split[:i] + [merge] + split[i + 2:]
                    
                    # update the split back in the dictionary.
                    splits[word] = split
                    # do not increment i, in case the new merged token can merge further.
                    # break
                else:
                    i += 1 
                    
            splits[word] = split

        return splits


    """
    Subword Tokenization:  
    1. We iteratively extract the longest valid prefix from the word that exists in our vocabulary.  
    2. If no valid prefix is found, we return the "[UNK]" token.  
    3. We append the matched prefix to the token list and remove it from the word.  
    4. If any part of the word remains, we prepend "##" to indicate it’s a subword and continue.  
    """
    def subword_tokenise(self, word):
        tokens = [] 
        # keep going until word is not empty
        while word:
            prefix = None 
            for i in range(len(word), 0, -1):
                checkWord = word[:i]
                if checkWord in self.vocab:
                    prefix = checkWord
                    break  # found longest valid prefix
            
            # no valid prefix is found -> return the unk token
            if prefix is None:
                return ["[UNK]"]
            else:
                tokens.append(prefix)
            
            # Remove the matched prefix from the word
            word = word[len(prefix):]
            if word:
                word = f"##{word}"
        
        return tokens

####----------------------####----------------------####----------------------####----------------------####----------------------####

def make_vocab_and_tokenize(vocab_size):
    corpus = []
    with open("../Data/corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        for sentence in sentences: 
            sentence = sentence.strip()
            if sentence:
                corpus.append(sentence)

    # print(corpus)
    tokenizer = WordPieceTokenizer(vocab_size)

    tokenizer.construct_vocabulary(corpus)
    vocab = tokenizer.vocab 

    input_json_path = 'sample_test.json'  
    output_json_path = 'tokenized_86.json' 

    tokenized_data = {}
    with open("../Data/corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        sentence_id = 0
        for sentence in sentences: 
            sentence = sentence.strip() 
            if sentence:
                tokens = tokenizer.tokenize(sentence)
                tokenized_data[sentence_id] = tokens
                sentence_id += 1

    # Write the tokenized data to the output JSON file
    with open(output_json_path, 'w') as f:
        json.dump(tokenized_data, f, indent=4)

if __name__ == "__main__":
    corpus = []
    with open("../Data/corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split()
        for sentence in sentences:
            sentence = sentence.strip()
            if sentence:
                corpus.append(sentence)

    tokenizer = WordPieceTokenizer(vocab_size=14000)

    tokenizer.construct_vocabulary(corpus)
    vocab = tokenizer.vocab

    output_json_path = '../Data/tokenized_data.json'  # Path to save tokenized output

    # Prepare a dictionary to store the tokenized sentences
    tokenized_data = {}
    with open("../Data/corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        sentence_id = 0
        for sentence in sentences:
            sentence = sentence.strip()
            if sentence:
                tokens = tokenizer.tokenize(sentence)
                tokenized_data[sentence_id] = tokens
                sentence_id += 1

    # Write the tokenized data to the output JSON file
    with open(output_json_path, 'w') as f:
        json.dump(tokenized_data, f, indent=4)

# %%
import torch.nn as nn
from torch.utils.data import Dataset
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from tqdm import tqdm
import torch.nn.functional

vocabulary_size = 14000
context_window = 2
embedding_dim = 400
batch_size = 1024
epochs = 25
lr = 0.001
dropout_rate = 0.3
word_index_mapping, index_word_mapping = {}, {}
train_dataloader = []
val_dataloader = []

class Word2VecDataset(Dataset):
    def __init__(self, corpus):
        self.preprocessed_data = []
        self.corpus = corpus

    def __len__(self):
        return len(self.preprocessed_data)

    def __getitem__(self, index):
        target, context = self.preprocessed_data[index]
        context_tensor = torch.tensor(context, dtype=torch.long)

        total_padding = 2 * context_window - len(context_tensor)

        left_padding = total_padding // 2
        right_padding = total_padding - left_padding

        context = torch.nn.functional.pad(context_tensor, (left_padding, right_padding), value=0)
        return torch.tensor(target, dtype=torch.long), context

    def preprocess_data(self, word_index_mapping):
        data = []
        for key in self.corpus:
            tokens = self.corpus[key]

            n = len(tokens)

            for i in range(0, n):
                target = tokens[i]

                # if target not in word_index_mapping:
                #     print(f"Warning: '{target}' not found in vocabulary, skipping.")
                #     continue  # Skip this word

                tokens_before_word = tokens[max(0, i - context_window):i]
                tokens_after_word = tokens[i + 1: min(n + 1, i + 1 + context_window)]

                context = tokens_before_word + tokens_after_word

                target_index = word_index_mapping[target]
                context_index = []
                for word in context:
                    if word in word_index_mapping:
                        context_index.append(word_index_mapping[word])

                if len(context_index) > 0:
                    data.append((target_index, context_index))

        self.preprocessed_data = data


class Word2VecModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.dropout = nn.Dropout(dropout_rate)
        self.linear = nn.Linear(embedding_dim, vocab_size)

        nn.init.xavier_uniform_(self.embedding.weight)
        nn.init.xavier_uniform_(self.linear.weight)
        if self.linear.bias is not None:
            nn.init.zeros_(self.linear.bias)

    def forward(self, context):
        embedded = self.embedding(context)  # [batch_size, context_length, embedding_dim]
        aggregated = embedded.mean(dim=1)     # [batch_size, embedding_dim]
        aggregated = self.dropout(aggregated)   # Apply dropout
        out = self.linear(aggregated)           # [batch_size, vocab_size]
        return out

    def train_model(self, model, criterion, optimizer):
        loss_list, val_loss = [], []

        for _ in tqdm(range(epochs)):
            total_loss = 0
            model.train()  # enable this if we r able to implement some dropout thingy

            for target, context in train_dataloader:
                target = target.long()
                context = context.long()

                pred = model.forward(context)
                loss = criterion(pred, target)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.item()

            number_of_samples = len(train_dataloader)
            avg_loss = total_loss / number_of_samples
            loss_list.append(avg_loss)
            print(f"Epoch {_ + 1}, Loss: {avg_loss}")

            total_loss = 0
            model.eval()

            with torch.no_grad():
                for target, context in val_dataloader:
                    target = target.long()
                    context = context.long()

                    pred = model.forward(context)
                    loss = criterion(pred, target)
                    total_loss += loss.item()

            avg_val_loss = total_loss / len(val_dataloader)
            val_loss.append(avg_val_loss)

        return loss_list, val_loss

    # def get_triplets(self, model):
    #     embeddings = model.network[0].weight.data.cpu().numpy()
    #     similarities = cosine_similarity(embeddings)
    #     triplets = []
    #
    #     for item in word_index_mapping:
    #         word, index = item[0], item[1]
    #
    #         similar, triplet = [], []
    #         similar_indices = np.argsort(similarities[index])[::-1]
    #         similar_indices = similar_indices[:3]
    #
    #         for i in similar_indices:
    #             similar.append(index_word_mapping[i])
    #         del similar[index_word_mapping[index]]
    #
    #         dissimilar_index = np.argsort(similarities[idx])[0]
    #         dissimilar = index_word_mapping[dissimilar_index]
    #
    #         triplet = [word, similar, dissimilar]
    #         triplets.append(triplet)
    #
    #     for triplet in triplets:
    #         print("Word:", triplet[0])
    #         print("Similar:", triplet[1])
    #         print("Dissimilar:", triplet[2])
    #         print()
    def get_triplets(self):
        embeddings = self.embedding.weight.data.cpu().numpy()
        similarities = cosine_similarity(embeddings)

        triplets = []

        for word, index in word_index_mapping.items():
            similar = []

            similar_indices = np.argsort(similarities[index])[::-1]
            similar_indices = [i for i in similar_indices if i != index][:3]

            for i in similar_indices:
                similar.append((index_word_mapping[i], similarities[index][i]))

            dissimilar_index = np.argsort(similarities[index])[0]
            dissimilar = (index_word_mapping[dissimilar_index], similarities[index][dissimilar_index])

            triplets.append([word, similar, dissimilar])

        for triplet in triplets:
            print("Word:", triplet[0])
            print("Similar:", [(w, round(sim, 4)) for w, sim in triplet[1]])
            print("Dissimilar:", (triplet[2][0], round(triplet[2][1], 4)))
            print()

        return triplets


def get_data(vocab_size, split=0.9):
    task1.make_vocab_and_tokenize(vocab_size)

    file_path = "../Data/tokenized_data.json"
    with open(file_path, "r", encoding="utf-8") as file:
        corpus = json.load(file)

    vocab_file_path = "../Data/vocabulary_86.txt"

    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = [line.strip() for line in f]

    word_index_mapping = {word: idx for idx, word in enumerate(vocab)}
    index_word_mapping = {idx: word for word, idx in word_index_mapping.items()}
    dataset = Word2VecDataset(corpus)
    dataset.preprocess_data(word_index_mapping)

    n = len(dataset)
    train = int(n * split)
    val = n - train

    train_dataset, val_dataset = random_split(dataset, [train, val])

    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

    return train_dataloader, val_dataloader, word_index_mapping, index_word_mapping


def plot(loss_list, val_loss):
    plt.plot(range(1, epochs + 1), loss_list, label="Training Loss")
    plt.plot(range(1, epochs + 1), val_loss, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training Loss")
    plt.savefig("task_2.png")
    plt.legend()
    plt.grid(visible=True)
    plt.show()

def get_triplet_for_word(self, word):
    if word not in word_index_mapping:
        print(f"Word '{word}' not found in vocabulary.")
        return None

    index = word_index_mapping[word]
    embeddings = self.embedding.weight.data.cpu().numpy()
    similarities = cosine_similarity(embeddings)

    # Get sorted indices of words based on similarity (descending order)
    similar_indices = np.argsort(similarities[index])[::-1]

    # Exclude the word itself (index = `index`)
    similar_indices = [i for i in similar_indices if i != index][:3]

    similar_words = [(index_word_mapping[i], similarities[index][i]) for i in similar_indices]

    # Find the most dissimilar word (smallest similarity score)
    dissimilar_index = np.argsort(similarities[index])[0]  # Least similar word
    dissimilar_word = index_word_mapping[dissimilar_index]
    dissimilar_similarity = similarities[index][dissimilar_index]

    # Print results
    print(f"Word: {word}")
    print("Similar Words (with Cosine Similarity):")
    for sim_word, sim_value in similar_words:
        print(f"  {sim_word}: {sim_value:.4f}")

    print(f"Dissimilar Word: {dissimilar_word} (Cosine Similarity: {dissimilar_similarity:.4f})\n")

    return word, similar_words, (dissimilar_word, dissimilar_similarity)

def run_Word2Vec(vocabulary_size_ = 14000, context_window_ = 2,embedding_dim_ = 400,batch_size_ = 1024,epochs_ = 50,lr_ = 0.001, dropout_rate_ = 0.3):

    global train_dataloader, val_dataloader, word_index_mapping, index_word_mapping, vocabulary_size, context_window, embedding_dim, batch_size, epochs, lr, dropout_rate

    vocabulary_size = vocabulary_size_
    context_window = context_window_
    embedding_dim = embedding_dim_
    batch_size = batch_size_
    epochs = epochs_
    lr = lr_

    train_dataloader, val_dataloader, word_index_mapping, index_word_mapping = get_data(vocabulary_size)

    print("Loaded Data")

    model = Word2VecModel(vocabulary_size)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    print("Training...")

    loss_list, val_loss = model.train_model(model, criterion, optimizer)
    plot(loss_list, val_loss)

    torch.save(model.state_dict(), "word2vec_checkpoint.pth")

    model.get_triplets()

    get_triplet_for_word(model, "is")

if __name__ == "__main__":
    run_Word2Vec( vocabulary_size_= vocabulary_size, context_window_= context_window, embedding_dim_= embedding_dim, batch_size_= batch_size, epochs_= epochs, lr_= lr, dropout_rate_=dropout_rate)
# Out:
# Loaded Data
# Training...
#   4%|▍         | 1/25 [00:04<01:55,  4.82s/it]
# Epoch 1, Loss: 9.286689758300781
#   8%|▊         | 2/25 [00:09<01:47,  4.69s/it]
# Epoch 2, Loss: 7.346891782500527
#  12%|█▏        | 3/25 [00:13<01:41,  4.63s/it]
# Epoch 3, Loss: 6.16315461288799
#  16%|█▌        | 4/25 [00:18<01:36,  4.61s/it]
# Epoch 4, Loss: 6.056776133450595
#  20%|██        | 5/25 [00:23<01:33,  4.65s/it]
# Epoch 5, Loss: 5.996797561645508
#  24%|██▍       | 6/25 [00:28<01:30,  4.78s/it]
# Epoch 6, Loss: 5.934530583294955
# Epoch 7, Loss: 5.865508610552007
#  28%|██▊       | 7/25 [00:33<01:25,  4.77s/it]
# Epoch 8, Loss: 5.792780301787636
#  32%|███▏      | 8/25 [00:38<01:25,  5.01s/it]
# Epoch 9, Loss: 5.712465210394426
#  36%|███▌      | 9/25 [00:44<01:23,  5.22s/it]
# Epoch 10, Loss: 5.62615302476016
#  40%|████      | 10/25 [00:49<01:18,  5.23s/it]
# Epoch 11, Loss: 5.5419731898741285
#  44%|████▍     | 11/25 [00:54<01:13,  5.27s/it]
# Epoch 12, Loss: 5.454541477290067
#  48%|████▊     | 12/25 [01:00<01:08,  5.26s/it]
# Epoch 13, Loss: 5.367015231739391
#  52%|█████▏    | 13/25 [01:05<01:02,  5.22s/it]
# Epoch 14, Loss: 5.279114473949779
#  56%|█████▌    | 14/25 [01:10<00:57,  5.18s/it]
# Epoch 15, Loss: 5.191496079618281
#  60%|██████    | 15/25 [01:15<00:51,  5.16s/it]
# Epoch 16, Loss: 5.105874722654169
#  64%|██████▍   | 16/25 [01:20<00:46,  5.17s/it]
# Epoch 17, Loss: 5.018135016614741
#  68%|██████▊   | 17/25 [01:25<00:41,  5.16s/it]
# Epoch 18, Loss: 4.9344308809800586
#  72%|███████▏  | 18/25 [01:30<00:36,  5.17s/it]
# Epoch 19, Loss: 4.849094520915639
#  76%|███████▌  | 19/25 [01:36<00:31,  5.19s/it]
# Epoch 20, Loss: 4.766270366582003
#  80%|████████  | 20/25 [01:41<00:26,  5.27s/it]
# Epoch 21, Loss: 4.681677189740268
#  84%|████████▍ | 21/25 [01:47<00:21,  5.31s/it]
# Epoch 22, Loss: 4.598419503732161
#  88%|████████▊ | 22/25 [01:52<00:15,  5.30s/it]
# Epoch 23, Loss: 4.511679595166987
#  92%|█████████▏| 23/25 [01:57<00:10,  5.31s/it]
# Epoch 24, Loss: 4.428601622581482
#  96%|█████████▌| 24/25 [02:02<00:05,  5.29s/it]
# Epoch 25, Loss: 4.342606847936457
# 100%|██████████| 25/25 [02:08<00:00,  5.16s/it]
# Word: [PAD]
# Similar: [('earning', np.float32(0.7794)), ('supremely', np.float32(0.7603)), ('until', np.float32(0.7562))]
# Dissimilar: ('kindness', np.float32(-0.55))
#
# Word: [UNK]
# Similar: [('##eback', np.float32(0.1934)), ('submissiv', np.float32(0.192)), ('unus', np.float32(0.1767))]
# Dissimilar: ('##collection', np.float32(-0.2005))
#
# Word: ##a
# Similar: [('omg', np.float32(0.9191)), ('kill', np.float32(0.896)), ('talent', np.float32(0.8906))]
# Dissimilar: ('sore', np.float32(-0.6893))
#
# Word: ##b
# Similar: [('##nflu', np.float32(0.1861)), ('##astar', np.float32(0.1775)), ('of', np.float32(0.1694))]
# Dissimilar: ('trag', np.float32(-0.1696))
#
# Word: ##c
# Similar: [('oppress', np.float32(0.1724)), ('##cifical', np.float32(0.1595)), ('aba', np.float32(0.1554))]
# Dissimilar: ('chocola', np.float32(-0.1874))
#
# Word: ##d
# Similar: [('nov', np.float32(0.8158)), ('##ar', np.float32(0.8035)), ('dr', np.float32(0.7988))]
# Dissimilar: ('wh', np.float32(-0.541))
#
# Word: ##e
# Similar: [('unfaithful', np.float32(0.8432)), ('julie', np.float32(0.8026)), ('initiation', np.float32(0.788))]
# Dissimilar: ('exhibit', np.float32(-0.478))
#
# Word: ##f
# Similar: [('##spous', np.float32(0.1852)), ('layout', np.float32(0.1831)), ('##ldom', np.float32(0.1793))]
# Dissimilar: ('accustom', np.float32(-0.1814))
#
# Word: ##g
# Similar: [('chiangmai', np.float32(0.6533)), ('s', np.float32(0.6355)), ('##ss', np.float32(0.5729))]
# Dissimilar: ('dread', np.float32(-0.3462))
#
# Word: ##h
# Similar: [('flat', np.float32(0.5869)), ('cohen', np.float32(0.5107)), ('handled', np.float32(0.4977))]
# Dissimilar: ('n', np.float32(-0.2606))
#
# Word: ##i
# Similar: [('trials', np.float32(0.1675)), ('organization', np.float32(0.1666)), ('grabb', np.float32(0.1664))]
# Dissimilar: ('similari', np.float32(-0.2095))
#
# Word: ##j
# Similar: [('##icrous', np.float32(0.1768)), ('##choo', np.float32(0.1759)), ('afaerytaleinmakebeliev', np.float32(0.1758))]
# Dissimilar: ('jimm', np.float32(-0.201))
#
# Word: ##k
# Similar: [('contracti', np.float32(0.1984)), ('nobody', np.float32(0.1861)), ('gonna', np.float32(0.1852))]
# Dissimilar: ('##orgiv', np.float32(-0.1877))
#
# Word: ##l
# Similar: [('##at', np.float32(0.8756)), ('##a', np.float32(0.8574)), ('##ss', np.float32(0.856))]
# Dissimilar: ('regardless', np.float32(-0.5154))
#
# Word: ##m
# Similar: [('root', np.float32(0.1932)), ('kneel', np.float32(0.1917)), ('##emind', np.float32(0.185))]
# Dissimilar: ('##pot', np.float32(-0.215))
#
# Word: ##n
# Similar: [('ive', np.float32(0.7692)), ('weve', np.float32(0.7214)), ('spoilers', np.float32(0.7004))]
# Dissimilar: ('wh', np.float32(-0.4117))
#
# Word: ##o
# Similar: [('inve', np.float32(0.1701)), ('maint', np.float32(0.1685)), ('##rginia', np.float32(0.1666))]
# Dissimilar: ('##nging', np.float32(-0.23))
#
# Word: ##p
# Similar: [('your', np.float32(0.1954)), ('##adach', np.float32(0.1682)), ('convolu', np.float32(0.1679))]
# Dissimilar: ('sharknad', np.float32(-0.1656))
#
# Word: ##q
# Similar: [('##espond', np.float32(0.1965)), ('haban', np.float32(0.1921)), ('##llian', np.float32(0.1873))]
# Dissimilar: ('##cogniz', np.float32(-0.1704))
#
# Word: ##r
# Similar: [('moisturizing', np.float32(0.7354)), ('carrry', np.float32(0.7091)), ('purpose', np.float32(0.7077))]
# Dissimilar: ('sore', np.float32(-0.5091))
#
# Word: ##s
# Similar: [('jimmys', np.float32(0.7706)), ('austen', np.float32(0.713)), ('r', np.float32(0.705))]
# Dissimilar: ('verrrrrrrryyyy', np.float32(-0.4941))
#
# Word: ##t
# Similar: [('r', np.float32(0.8686)), ('##ar', np.float32(0.8598)), ('##at', np.float32(0.8537))]
# Dissimilar: ('wh', np.float32(-0.5467))
#
# Word: ##u
# Similar: [('##easur', np.float32(0.1752)), ('archi', np.float32(0.1651)), ('exhausti', np.float32(0.164))]
# Dissimilar: ('jubil', np.float32(-0.1878))
#
# Word: ##v
# Similar: [('##by', np.float32(0.1704)), ('##dventur', np.float32(0.1691)), ('##iti', np.float32(0.1678))]
# Dissimilar: ('disast', np.float32(-0.19))
#
# Word: ##w
# Similar: [('##crous', np.float32(0.1852)), ('##zz', np.float32(0.182)), ('litt', np.float32(0.1786))]
# Dissimilar: ('ignor', np.float32(-0.2194))
#
# Word: ##x
# Similar: [('##arly', np.float32(0.2378)), ('caw', np.float32(0.1771)), ('##mitat', np.float32(0.1763))]
# Dissimilar: ('##eluctanc', np.float32(-0.1817))
#
# Word: ##y
# Similar: [('##obing', np.float32(0.1804)), ('##dblog', np.float32(0.18)), ('force', np.float32(0.179))]
# Dissimilar: ('stimu', np.float32(-0.163))
#
# Word: ##z
# Similar: [('##entence', np.float32(0.21)), ('##ermination', np.float32(0.2006)), ('nons', np.float32(0.1792))]
# Dissimilar: ('##eeeally', np.float32(-0.1789))
#
# Word: a
# Similar: [('rylin', np.float32(0.6745)), ('impractical', np.float32(0.592)), ('shove', np.float32(0.5831))]
# Dissimilar: ('varsities', np.float32(-0.3491))
#
# Word: b
# Similar: [('gloating', np.float32(0.7847)), ('quit', np.float32(0.7837)), ('realised', np.float32(0.782))]
# Dissimilar: ('levi', np.float32(-0.5917))
#
# Word: c
# Similar: [('celebrate', np.float32(0.8567)), ('comment', np.float32(0.8355)), ('tend', np.float32(0.8345))]
# Dissimilar: ('sore', np.float32(-0.7145))
#
# Word: d
# Similar: [('emergence', np.float32(0.7587)), ('di', np.float32(0.7562)), ('mistakes', np.float32(0.7503))]
# Dissimilar: ('sore', np.float32(-0.4799))
#
# Word: e
# Similar: [('intention', np.float32(0.6161)), ('challenges', np.float32(0.6143)), ('awoke', np.float32(0.6063))]
# Dissimilar: ('exceptions', np.float32(-0.4719))
#
# Word: f
# Similar: [('planned', np.float32(0.6876)), ('habitual', np.float32(0.6545)), ('ive', np.float32(0.6418))]
# Dissimilar: ('sweat', np.float32(-0.449))
#
# Word: g
# Similar: [('##elativ', np.float32(0.1982)), ('##ollow', np.float32(0.1773)), ('supre', np.float32(0.1756))]
# Dissimilar: ('##itish', np.float32(-0.2238))
#
# Word: h
# Similar: [('##yon', np.float32(0.218)), ('##attl', np.float32(0.1704)), ('hund', np.float32(0.168))]
# Dissimilar: ('roman', np.float32(-0.1974))
#
# Word: i
# Similar: [('professors', np.float32(0.7841)), ('they', np.float32(0.7783)), ('painstakingly', np.float32(0.7558))]
# Dissimilar: ('count', np.float32(-0.5541))
#
# Word: j
# Similar: [('r', np.float32(0.7744)), ('m', np.float32(0.7239)), ('forced', np.float32(0.6947))]
# Dissimilar: ('frail', np.float32(-0.4147))
#
# Word: k
# Similar: [('anymor', np.float32(0.1916)), ('choco', np.float32(0.173)), ('obria', np.float32(0.1653))]
# Dissimilar: ('##lright', np.float32(-0.1855))
#
# Word: l
# Similar: [('loath', np.float32(0.1866)), ('##amy', np.float32(0.1779)), ('##njamin', np.float32(0.1757))]
# Dissimilar: ('overload', np.float32(-0.2052))
#
# Word: m
# Similar: [('jimmys', np.float32(0.824)), ('s', np.float32(0.8144)), ('def', np.float32(0.8087))]
# Dissimilar: ('wh', np.float32(-0.5784))
#
# Word: n
# Similar: [('victoria', np.float32(0.867)), ('lyman', np.float32(0.8552)), ('mistakes', np.float32(0.8398))]
# Dissimilar: ('labour', np.float32(-0.5518))
#
# Word: o
# Similar: [('skinner', np.float32(0.4085)), ('combined', np.float32(0.3329)), ('dukes', np.float32(0.3315))]
# Dissimilar: ('uhuru', np.float32(-0.3564))
#
# Word: p
# Similar: [('mistakes', np.float32(0.8991)), ('lyman', np.float32(0.8979)), ('photos', np.float32(0.887))]
# Dissimilar: ('wh', np.float32(-0.6961))
#
# Word: q
# Similar: [('goodbye', np.float32(0.8226)), ('tries', np.float32(0.7967)), ('easy', np.float32(0.7766))]
# Dissimilar: ('dependent', np.float32(-0.6105))
#
# Word: r
# Similar: [('##ar', np.float32(0.8743)), ('di', np.float32(0.8712)), ('##t', np.float32(0.8686))]
# Dissimilar: ('wh', np.float32(-0.5649))
#
# Word: s
# Similar: [('m', np.float32(0.8144)), ('r', np.float32(0.7939)), ('jimmys', np.float32(0.7924))]
# Dissimilar: ('wh', np.float32(-0.6442))
#
# Word: t
# Similar: [('carin', np.float32(0.8023)), ('problemn', np.float32(0.693)), ('followers', np.float32(0.6873))]
# Dissimilar: ('nasty', np.float32(-0.4261))
#
# Word: u
# Similar: [('betrayed', np.float32(0.7304)), ('ryder', np.float32(0.698)), ('chills', np.float32(0.6977))]
# Dissimilar: ('dependent', np.float32(-0.4525))
#
# Word: v
# Similar: [('acad', np.float32(0.1715)), ('##raying', np.float32(0.1694)), ('unfortu', np.float32(0.1692))]
# Dissimilar: ('##aining', np.float32(-0.1807))
#
# Word: w
# Similar: [('rescu', np.float32(0.1983)), ('spencers', np.float32(0.1939)), ('##son', np.float32(0.1862))]
# Dissimilar: ('##ifying', np.float32(-0.1684))
#
# Word: x
# Similar: [('instead', np.float32(0.6801)), ('swing', np.float32(0.6765)), ('assessment', np.float32(0.6627))]
# Dissimilar: ('calorie', np.float32(-0.3871))
#
# Word: y
# Similar: [('frus', np.float32(0.2076)), ('##einforc', np.float32(0.1649)), ('hohoho', np.float32(0.1647))]
# Dissimilar: ('official', np.float32(-0.1873))
#
# Word: z
# Similar: [('clutter', np.float32(0.8458)), ('underneath', np.float32(0.8452)), ('aging', np.float32(0.8423))]
# Dissimilar: ('incidents', np.float32(-0.7005))
#
# Word: ex
# Similar: [('scruti', np.float32(0.185)), ('##dsid', np.float32(0.1734)), ('deserve', np.float32(0.1721))]
# Dissimilar: ('grappl', np.float32(-0.1919))
#
# Word: xx
# Similar: [('xelliealicex', np.float32(0.6373)), ('dependent', np.float32(0.5358)), ('incidents', np.float32(0.5139))]
# Dissimilar: ('devestated', np.float32(-0.571))
#
# Word: ##zz
# Similar: [('kitche', np.float32(0.1853)), ('##nha', np.float32(0.1832)), ('##w', np.float32(0.182))]
# Dissimilar: ('abandon', np.float32(-0.1815))
#
# Word: ##qu
# Similar: [('embarra', np.float32(0.1779)), ('##nclud', np.float32(0.1739)), ('##trong', np.float32(0.1682))]
# Dissimilar: ('##onard', np.float32(-0.1944))
#
# Word: bq
# Similar: [('blogge', np.float32(0.192)), ('##rci', np.float32(0.1801)), ('prese', np.float32(0.1766))]
# Dissimilar: ('girlfrie', np.float32(-0.2086))
#
# Word: bqf
# Similar: [('##sful', np.float32(0.185)), ('##cit', np.float32(0.1816)), ('paki', np.float32(0.1785))]
# Dissimilar: ('##epy', np.float32(-0.1694))
#
# Word: bqff
# Similar: [('faithfulness', np.float32(0.9317)), ('lend', np.float32(0.9184)), ('mission', np.float32(0.9164))]
# Dissimilar: ('sore', np.float32(-0.812))
#
# Word: qu
# Similar: [('##und', np.float32(0.1951)), ('hid', np.float32(0.1631)), ('adolesce', np.float32(0.1616))]
# Dissimilar: ('goodne', np.float32(-0.1903))
#
# Word: of
# Similar: [('pulling', np.float32(0.5964)), ('predictable', np.float32(0.5666)), ('balancing', np.float32(0.5424))]
# Dissimilar: ('oblige', np.float32(-0.4022))
#
# Word: ev
# Similar: [('adams', np.float32(0.1961)), ('immature', np.float32(0.1906)), ('dinner', np.float32(0.1884))]
# Dissimilar: ('##vor', np.float32(-0.1916))
#
# Word: equ
# Similar: [('capi', np.float32(0.1945)), ('##deas', np.float32(0.1824)), ('##ads', np.float32(0.1821))]
# Dissimilar: ('jum', np.float32(-0.1848))
#
# Word: exp
# Similar: [('yor', np.float32(0.2039)), ('mod', np.float32(0.1828)), ('black', np.float32(0.1753))]
# Dissimilar: ('achi', np.float32(-0.1955))
#
# Word: up
# Similar: [('watch', np.float32(0.5378)), ('back', np.float32(0.5298)), ('lash', np.float32(0.5227))]
# Dissimilar: ('dramatically', np.float32(-0.3824))
#
# Word: ju
# Similar: [('shie', np.float32(0.2195)), ('##ricana', np.float32(0.1915)), ('##dio', np.float32(0.1726))]
# Dissimilar: ('litte', np.float32(-0.2081))
#
# Word: ##bj
# Similar: [('##rtigo', np.float32(0.2281)), ('##zi', np.float32(0.1873)), ('careers', np.float32(0.1771))]
# Dissimilar: ('##ecessity', np.float32(-0.2067))
#
# Word: ##ubj
# Similar: [('mous', np.float32(0.1973)), ('##ervic', np.float32(0.1866)), ('##mbulatory', np.float32(0.1822))]
# Dissimilar: ('polite', np.float32(-0.2194))
#
# Word: obj
# Similar: [('shar', np.float32(0.1698)), ('##asantly', np.float32(0.1618)), ('##eclin', np.float32(0.1607))]
# Dissimilar: ('huma', np.float32(-0.2104))
#
# Word: subj
# Similar: [('hohoho', np.float32(0.1678)), ('##oun', np.float32(0.1654)), ('completene', np.float32(0.1623))]
# Dissimilar: ('spontan', np.float32(-0.1941))
#
# Word: jus
# Similar: [('happie', np.float32(0.1952)), ('##noo', np.float32(0.1742)), ('uncoi', np.float32(0.1694))]
# Dissimilar: ('convolu', np.float32(-0.1943))
#
# Word: jum
# Similar: [('chari', np.float32(0.1902)), ('##dback', np.float32(0.1885)), ('prohibitio', np.float32(0.1787))]
# Dissimilar: ('##entially', np.float32(-0.189))
#
# Word: jump
# Similar: [('extend', np.float32(0.8979)), ('greet', np.float32(0.8895)), ('seem', np.float32(0.8829))]
# Dissimilar: ('sore', np.float32(-0.7809))
#
# Word: jumb
# Similar: [('str', np.float32(0.1792)), ('featur', np.float32(0.1768)), ('##nomy', np.float32(0.176))]
# Dissimilar: ('##tainabl', np.float32(-0.1948))
#
# Word: exc
# Similar: [('impossi', np.float32(0.2062)), ('tickl', np.float32(0.1828)), ('pressing', np.float32(0.1723))]
# Dissimilar: ('##alling', np.float32(-0.1831))
#
# Word: ##zzy
# Similar: [('##erapist', np.float32(0.1785)), ('##atsuma', np.float32(0.175)), ('stepp', np.float32(0.1719))]
# Dissimilar: ('exite', np.float32(-0.1883))
#
# Word: jub
# Similar: [('##nsport', np.float32(0.2022)), ('giv', np.float32(0.1674)), ('##tal', np.float32(0.1644))]
# Dissimilar: ('simil', np.float32(-0.1956))
#
# Word: jumbl
# Similar: [('mobilit', np.float32(0.1786)), ('intimidate', np.float32(0.1759)), ('mooshil', np.float32(0.1754))]
# Dissimilar: ('georg', np.float32(-0.1917))
#
# Word: ##uzz
# Similar: [('##rustration', np.float32(0.1809)), ('spazzol', np.float32(0.1635)), ('apar', np.float32(0.1575))]
# Dissimilar: ('##flix', np.float32(-0.1717))
#
# Word: puzz
# Similar: [('meditate', np.float32(0.1878)), ('iv', np.float32(0.183)), ('##ination', np.float32(0.1767))]
# Dissimilar: ('harr', np.float32(-0.2468))
#
# Word: puzzl
# Similar: [('ravaged', np.float32(0.1775)), ('apologiz', np.float32(0.1758)), ('##neath', np.float32(0.1752))]
# Dissimilar: ('settl', np.float32(-0.181))
#
# Word: equa
# Similar: [('crim', np.float32(0.2207)), ('conduciv', np.float32(0.2161)), ('##rc', np.float32(0.1829))]
# Dissimilar: ('blogge', np.float32(-0.2119))
#
# Word: jubi
# Similar: [('piling', np.float32(0.1932)), ('##eighbors', np.float32(0.1755)), ('unnecessary', np.float32(0.1719))]
# Dissimilar: ('##frig', np.float32(-0.186))
#
# Word: jubil
# Similar: [('pap', np.float32(0.1656)), ('depre', np.float32(0.1642)), ('##tainly', np.float32(0.1632))]
# Dissimilar: ('##u', np.float32(-0.1878))
#
# Word: jubila
# Similar: [('##fy', np.float32(0.1802)), ('##nesday', np.float32(0.17)), ('##lla', np.float32(0.167))]
# Dissimilar: ('spoil', np.float32(-0.1845))
#
# Word: just
# Similar: [('didnt', np.float32(0.7025)), ('marry', np.float32(0.697)), ('still', np.float32(0.6957))]
# Dissimilar: ('incidents', np.float32(-0.5953))
#
# Word: ##uzzy
# Similar: [('##lve', np.float32(0.1821)), ('effort', np.float32(0.1757)), ('##eamworld', np.float32(0.1694))]
# Dissimilar: ('##visibl', np.float32(-0.2234))
#
# Word: buzzy
# Similar: [('rooted', np.float32(0.8441)), ('vapor', np.float32(0.8061)), ('lots', np.float32(0.7838))]
# Dissimilar: ('hurry', np.float32(-0.3205))
#
# Word: fuzzy
# Similar: [('generous', np.float32(0.668)), ('exceptionally', np.float32(0.6578)), ('smug', np.float32(0.6492))]
# Dissimilar: ('someone', np.float32(-0.4252))
#
# Word: ##izzy
# Similar: [('##lous', np.float32(0.1933)), ('afrai', np.float32(0.1725)), ('progra', np.float32(0.1631))]
# Dissimilar: ('##ping', np.float32(-0.186))
#
# Word: dizzy
# Similar: [('flias', np.float32(0.9083)), ('anthology', np.float32(0.9026)), ('stare', np.float32(0.8996))]
# Dissimilar: ('incidents', np.float32(-0.7874))
#
# Word: lizzy
# Similar: [('##sh', np.float32(0.8721)), ('spurring', np.float32(0.8332)), ('refocus', np.float32(0.824))]
# Dissimilar: ('sore', np.float32(-0.6532))
#
# Word: xb
# Similar: [('##nvigor', np.float32(0.1961)), ('vu', np.float32(0.18)), ('colu', np.float32(0.1776))]
# Dissimilar: ('##odoran', np.float32(-0.1916))
#
# Word: xbl
# Similar: [('ravaged', np.float32(0.2196)), ('intake', np.float32(0.2044)), ('allah', np.float32(0.2034))]
# Dissimilar: ('makes', np.float32(-0.2514))
#
# Word: xbla
# Similar: [('feels', np.float32(0.6435)), ('confirm', np.float32(0.5031)), ('atmosphere', np.float32(0.4761))]
# Dissimilar: ('austen', np.float32(-0.3407))
#
# Word: th
# Similar: [('birthdays', np.float32(0.8425)), ('flattened', np.float32(0.6834)), ('crutches', np.float32(0.6829))]
# Dissimilar: ('sore', np.float32(-0.4649))
#
# Word: jubilan
# Similar: [('##ventur', np.float32(0.1707)), ('spide', np.float32(0.1702)), ('##augh', np.float32(0.1686))]
# Dissimilar: ('##rwis', np.float32(-0.2196))
#
# Word: jubilant
# Similar: [('unsafe', np.float32(0.9806)), ('abt', np.float32(0.9577)), ('uber', np.float32(0.9451))]
# Dissimilar: ('incidents', np.float32(-0.8226))
#
# Word: my
# Similar: [('his', np.float32(0.6548)), ('seizing', np.float32(0.5895)), ('their', np.float32(0.5836))]
# Dissimilar: ('repeating', np.float32(-0.4095))
#
# Word: ov
# Similar: [('dismaye', np.float32(0.1976)), ('##noon', np.float32(0.1812)), ('transformers', np.float32(0.1743))]
# Dissimilar: ('occa', np.float32(-0.173))
#
# Word: ##pp
# Similar: [('##rigg', np.float32(0.1975)), ('pegg', np.float32(0.193)), ('miserabl', np.float32(0.1861))]
# Dissimilar: ('court', np.float32(-0.2239))
#
# Word: qui
# Similar: [('##moriz', np.float32(0.1902)), ('##ativity', np.float32(0.185)), ('##ers', np.float32(0.1734))]
# Dissimilar: ('##iation', np.float32(-0.1799))
#
# Word: wh
# Similar: [('verrrrrrrryyyy', np.float32(0.7153)), ('initiation', np.float32(0.6335)), ('inherent', np.float32(0.5418))]
# Dissimilar: ('p', np.float32(-0.6961))
#
# Word: quit
# Similar: [('indicated', np.float32(0.9692)), ('gloating', np.float32(0.957)), ('wish', np.float32(0.9471))]
# Dissimilar: ('freakishly', np.float32(-0.7089))
#
# Word: quic
# Similar: [('##rownish', np.float32(0.1652)), ('##einkind', np.float32(0.1633)), ('compassiona', np.float32(0.1611))]
# Dissimilar: ('##tabl', np.float32(-0.194))
#
# Word: quick
# Similar: [('skinn', np.float32(0.1796)), ('surpr', np.float32(0.1781)), ('##mony', np.float32(0.1768))]
# Dissimilar: ('foward', np.float32(-0.1777))
#
# Word: quickl
# Similar: [('##ccumb', np.float32(0.1686)), ('impressions', np.float32(0.1634)), ('##ashing', np.float32(0.1586))]
# Dissimilar: ('##edly', np.float32(-0.1864))
#
# Word: quickly
# Similar: [('police', np.float32(0.8603)), ('magazine', np.float32(0.8449)), ('illusion', np.float32(0.8435))]
# Dissimilar: ('latter', np.float32(-0.6692))
#
# Word: quiv
# Similar: [('##dom', np.float32(0.1971)), ('##ntrusion', np.float32(0.1853)), ('emptin', np.float32(0.1808))]
# Dissimilar: ('signal', np.float32(-0.1829))
#
# Word: ##azz
# Similar: [('##esort', np.float32(0.1747)), ('privil', np.float32(0.1706)), ('##ssari', np.float32(0.1643))]
# Dissimilar: ('toon', np.float32(-0.2113))
#
# Word: dazz
# Similar: [('##lebrating', np.float32(0.1915)), ('##llshit', np.float32(0.1792)), ('unchara', np.float32(0.1738))]
# Dissimilar: ('pane', np.float32(-0.1799))
#
# Word: ##pazz
# Similar: [('priva', np.float32(0.1924)), ('paral', np.float32(0.1923)), ('##oggy', np.float32(0.1805))]
# Dissimilar: ('bos', np.float32(-0.1789))
#
# Word: spazz
# Similar: [('##mpor', np.float32(0.2126)), ('##emberiing', np.float32(0.1866)), ('dan', np.float32(0.1698))]
# Dissimilar: ('empow', np.float32(-0.1782))
#
# Word: dazzl
# Similar: [('##ity', np.float32(0.1986)), ('##escrib', np.float32(0.1882)), ('##inancially', np.float32(0.1716))]
# Dissimilar: ('##indow', np.float32(-0.2156))
#
# Word: dazzli
# Similar: [('unwell', np.float32(0.1838)), ('interne', np.float32(0.1764)), ('folk', np.float32(0.1763))]
# Dissimilar: ('##rf', np.float32(-0.2003))
#
# Word: ##izz
# Similar: [('parties', np.float32(0.1933)), ('##nywh', np.float32(0.1738)), ('pegg', np.float32(0.1727))]
# Dissimilar: ('light', np.float32(-0.2065))
#
# Word: ##rizz
# Similar: [('trusty', np.float32(0.187)), ('##lian', np.float32(0.186)), ('zealand', np.float32(0.1833))]
# Dissimilar: ('i', np.float32(-0.2066))
#
# Word: frizz
# Similar: [('underneath', np.float32(0.8182)), ('laughable', np.float32(0.8175)), ('soothing', np.float32(0.811))]
# Dissimilar: ('sore', np.float32(-0.6356))
#
# Word: spazzo
# Similar: [('harm', np.float32(0.1744)), ('##fudd', np.float32(0.1729)), ('unfortuna', np.float32(0.1682))]
# Dissimilar: ('##ntag', np.float32(-0.1909))
#
# Word: spazzol
# Similar: [('##ycho', np.float32(0.1772)), ('hitl', np.float32(0.1716)), ('##endid', np.float32(0.1666))]
# Dissimilar: ('exci', np.float32(-0.1893))
#
# Word: spazzola
# Similar: [('beside', np.float32(0.6227)), ('yall', np.float32(0.584)), ('dated', np.float32(0.552))]
# Dissimilar: ('butt', np.float32(-0.4607))
#
# Word: dazzlin
# Similar: [('inspect', np.float32(0.2144)), ('##etw', np.float32(0.1957)), ('mircowave', np.float32(0.1814))]
# Dissimilar: ('rational', np.float32(-0.172))
#
# Word: dazzling
# Similar: [('cert', np.float32(0.7945)), ('coat', np.float32(0.6885)), ('seemingly', np.float32(0.6833))]
# Dissimilar: ('hugely', np.float32(-0.4459))
#
# Word: ##az
# Similar: [('flirtiing', np.float32(0.2004)), ('requ', np.float32(0.1975)), ('##tally', np.float32(0.1966))]
# Dissimilar: ('##haviour', np.float32(-0.1793))
#
# Word: ##maz
# Similar: [('gratitud', np.float32(0.1909)), ('##manding', np.float32(0.173)), ('sinu', np.float32(0.1659))]
# Dissimilar: ('##rrita', np.float32(-0.1912))
#
# Word: daz
# Similar: [('##evelop', np.float32(0.2023)), ('##alm', np.float32(0.2)), ('##thful', np.float32(0.178))]
# Dissimilar: ('artis', np.float32(-0.2184))
#
# Word: ##azy
# Similar: [('conduciv', np.float32(0.2119)), ('humid', np.float32(0.1797)), ('##sa', np.float32(0.1757))]
# Dissimilar: ('scre', np.float32(-0.1905))
#
# Word: lazy
# Similar: [('explorer', np.float32(0.8716)), ('habanero', np.float32(0.8617)), ('worthless', np.float32(0.8521))]
# Dissimilar: ('incidents', np.float32(-0.7706))
#
# Word: gaz
# Similar: [('##rica', np.float32(0.1837)), ('engag', np.float32(0.1813)), ('sc', np.float32(0.175))]
# Dissimilar: ('tary', np.float32(-0.1845))
#
# Word: maz
# Similar: [('cl', np.float32(0.2187)), ('liqu', np.float32(0.1763)), ('##trusion', np.float32(0.1736))]
# Dissimilar: ('##enounc', np.float32(-0.1987))
#
# Word: haz
# Similar: [('##sionabl', np.float32(0.1899)), ('unconsci', np.float32(0.1752)), ('emotico', np.float32(0.1725))]
# Dissimilar: ('new', np.float32(-0.191))
#
# Word: ##gaz
# Similar: [('##una', np.float32(0.1812)), ('energiz', np.float32(0.1794)), ('rooma', np.float32(0.1746))]
# Dissimilar: ('kno', np.float32(-0.2336))
#
# Word: amaz
# Similar: [('guil', np.float32(0.2029)), ('adap', np.float32(0.1939)), ('discourag', np.float32(0.1895))]
# Dissimilar: ('scabb', np.float32(-0.1718))
#
# Word: ##razy
# Similar: [('amoun', np.float32(0.1981)), ('throughou', np.float32(0.169)), ('awkwa', np.float32(0.167))]
# Dissimilar: ('accessari', np.float32(-0.1753))
#
# Word: crazy
# Similar: [('songs', np.float32(0.8165)), ('soft', np.float32(0.7986)), ('impacted', np.float32(0.7859))]
# Dissimilar: ('latter', np.float32(-0.6366))
#
# Word: ##agaz
# Similar: [('gall', np.float32(0.1758)), ('##esponsibiliti', np.float32(0.175)), ('##lating', np.float32(0.1698))]
# Dissimilar: ('distru', np.float32(-0.1997))
#
# Word: magaz
# Similar: [('pr', np.float32(0.1977)), ('##tral', np.float32(0.1831)), ('admitting', np.float32(0.1731))]
# Dissimilar: ('##ato', np.float32(-0.2303))
#
# Word: magazi
# Similar: [('essa', np.float32(0.1907)), ('##efectiv', np.float32(0.1751)), ('triangl', np.float32(0.1688))]
# Dissimilar: ('gove', np.float32(-0.1884))
#
# Word: magazin
# Similar: [('spac', np.float32(0.1728)), ('twin', np.float32(0.1709)), ('kiy', np.float32(0.1705))]
# Dissimilar: ('##lloons', np.float32(-0.1983))
#
# Word: ##iz
# Similar: [('##eshap', np.float32(0.1946)), ('##rwins', np.float32(0.1733)), ('##ita', np.float32(0.1701))]
# Dissimilar: ('fai', np.float32(-0.1817))
#
# Word: ab
# Similar: [('stori', np.float32(0.1962)), ('##rwi', np.float32(0.1811)), ('boundar', np.float32(0.1799))]
# Dissimilar: ('machiavellian', np.float32(-0.1934))
#
# Word: abo
# Similar: [('##elying', np.float32(0.1828)), ('##easonal', np.float32(0.1751)), ('favori', np.float32(0.1725))]
# Dissimilar: ('cron', np.float32(-0.191))
#
# Word: abou
# Similar: [('##mipro', np.float32(0.1767)), ('##nmark', np.float32(0.1688)), ('unila', np.float32(0.1669))]
# Dissimilar: ('##ouchy', np.float32(-0.191))
#
# Word: abov
# Similar: [('washro', np.float32(0.1734)), ('##iifff', np.float32(0.1696)), ('##ecur', np.float32(0.163))]
# Dissimilar: ('ryd', np.float32(-0.182))
#
# Word: about
# Similar: [('by', np.float32(0.5147)), ('relish', np.float32(0.4558)), ('sorrows', np.float32(0.4527))]
# Dissimilar: ('perpetually', np.float32(-0.3564))
#
# Word: aboun
# Similar: [('convi', np.float32(0.1977)), ('##ohibi', np.float32(0.1928)), ('scheme', np.float32(0.1837))]
# Dissimilar: ('evolv', np.float32(-0.1934))
#
# Word: abound
# Similar: [('renowned', np.float32(0.6325)), ('cruz', np.float32(0.597)), ('including', np.float32(0.4368))]
# Dissimilar: ('desp', np.float32(-0.2283))
#
# Word: ##upp
# Similar: [('disposab', np.float32(0.1793)), ('##io', np.float32(0.1701)), ('##aluabl', np.float32(0.17))]
# Dissimilar: ('##nvigor', np.float32(-0.2021))
#
# Word: supp
# Similar: [('##atform', np.float32(0.2088)), ('nut', np.float32(0.1841)), ('##essn', np.float32(0.176))]
# Dissimilar: ('##rationa', np.float32(-0.173))
#
# Word: pupp
# Similar: [('hunge', np.float32(0.1927)), ('sain', np.float32(0.1825)), ('unfaithful', np.float32(0.1823))]
# Dissimilar: ('##egins', np.float32(-0.2288))
#
# Word: puppy
# Similar: [('serving', np.float32(0.8816)), ('reiterate', np.float32(0.8545)), ('gradually', np.float32(0.8526))]
# Dissimilar: ('incidents', np.float32(-0.7263))
#
# Word: suppo
# Similar: [('##nant', np.float32(0.1972)), ('themse', np.float32(0.1878)), ('gif', np.float32(0.1871))]
# Dissimilar: ('typical', np.float32(-0.1999))
#
# Word: suppor
# Similar: [('##nmak', np.float32(0.1864)), ('aggr', np.float32(0.1749)), ('unprotect', np.float32(0.1694))]
# Dissimilar: ('glorie', np.float32(-0.2094))
#
# Word: suppos
# Similar: [('##essing', np.float32(0.1858)), ('##utur', np.float32(0.1847)), ('whil', np.float32(0.168))]
# Dissimilar: ('##littl', np.float32(-0.18))
#
# Word: support
# Similar: [('fingers', np.float32(0.8709)), ('bedroom', np.float32(0.8681)), ('assistance', np.float32(0.865))]
# Dissimilar: ('sore', np.float32(-0.7916))
#
# Word: ##ppy
# Similar: [('characte', np.float32(0.1851)), ('ourse', np.float32(0.1848)), ('##inbows', np.float32(0.167))]
# Dissimilar: ('num', np.float32(-0.1862))
#
# Word: ##appy
# Similar: [('##xious', np.float32(0.1849)), ('##lcy', np.float32(0.1779)), ('##narticul', np.float32(0.1732))]
# Dissimilar: ('facilitie', np.float32(-0.2047))
#
# Word: happy
# Similar: [('cave', np.float32(0.865)), ('raising', np.float32(0.8632)), ('transparent', np.float32(0.8575))]
# Dissimilar: ('incidents', np.float32(-0.7667))
#
# Word: ##happy
# Similar: [('sympath', np.float32(0.1729)), ('hog', np.float32(0.1652)), ('singapor', np.float32(0.165))]
# Dissimilar: ('##elpful', np.float32(-0.1865))
#
# Word: ##rappy
# Similar: [('##ncing', np.float32(0.1686)), ('##eeeeeeeally', np.float32(0.1615)), ('##uz', np.float32(0.1611))]
# Dissimilar: ('##rathon', np.float32(-0.2103))
#
# Word: crappy
# Similar: [('wimpy', np.float32(0.8964)), ('roof', np.float32(0.8848)), ('curious', np.float32(0.864))]
# Dissimilar: ('incidents', np.float32(-0.779))
#
# Word: opp
# Similar: [('##eassur', np.float32(0.1924)), ('creep', np.float32(0.1838)), ('feelings', np.float32(0.1813))]
# Dissimilar: ('dishearten', np.float32(-0.181))
#
# Word: ##nhappy
# Similar: [('sky', np.float32(0.194)), ('##rav', np.float32(0.1936)), ('genr', np.float32(0.1727))]
# Dissimilar: ('bloggers', np.float32(-0.1771))
#
# Word: unhappy
# Similar: [('vunerable', np.float32(0.8809)), ('butterfly', np.float32(0.8786)), ('organise', np.float32(0.8777))]
# Dissimilar: ('incidents', np.float32(-0.7504))
#
# Word: oppo
# Similar: [('##memberiing', np.float32(0.19)), ('hurry', np.float32(0.1803)), ('showca', np.float32(0.1737))]
# Dissimilar: ('eaters', np.float32(-0.2003))
#
# Word: oppr
# Similar: [('weigh', np.float32(0.1982)), ('hopeful', np.float32(0.1885)), ('likeable', np.float32(0.1808))]
# Dissimilar: ('##autiful', np.float32(-0.1891))
#
# Word: oppor
# Similar: [('##sponsibili', np.float32(0.186)), ('##rator', np.float32(0.1834)), ('##ground', np.float32(0.1785))]
# Dissimilar: ('##dwich', np.float32(-0.182))
#
# Word: oppos
# Similar: [('##tially', np.float32(0.2236)), ('##thiz', np.float32(0.1817)), ('stump', np.float32(0.1774))]
# Dissimilar: ('exhila', np.float32(-0.1854))
#
# Word: opport
# Similar: [('wailing', np.float32(0.1841)), ('charred', np.float32(0.1717)), ('##gitimat', np.float32(0.1701))]
# Dissimilar: ('acad', np.float32(-0.1718))
#
# Word: opportu
# Similar: [('desir', np.float32(0.1848)), ('##snt', np.float32(0.1783)), ('##ences', np.float32(0.1565))]
# Dissimilar: ('univ', np.float32(-0.2019))
#
# Word: opportun
# Similar: [('nefe', np.float32(0.1737)), ('replacem', np.float32(0.1733)), ('wa', np.float32(0.1728))]
# Dissimilar: ('wand', np.float32(-0.188))
#
# Word: opportuni
# Similar: [('##itud', np.float32(0.1766)), ('impossi', np.float32(0.1723)), ('##ermination', np.float32(0.1655))]
# Dissimilar: ('wid', np.float32(-0.1856))
#
# Word: opportunit
# Similar: [('chihar', np.float32(0.2279)), ('bonu', np.float32(0.1951)), ('buo', np.float32(0.1946))]
# Dissimilar: ('hsps', np.float32(-0.1936))
#
# Word: opportunity
# Similar: [('pay', np.float32(0.8683)), ('drive', np.float32(0.816)), ('exicting', np.float32(0.8109))]
# Dissimilar: ('sore', np.float32(-0.6708))
#
# Word: opposi
# Similar: [('disabilit', np.float32(0.1884)), ('constan', np.float32(0.166)), ('pret', np.float32(0.1638))]
# Dissimilar: ('requ', np.float32(-0.182))
#
# Word: opposit
# Similar: [('rosli', np.float32(0.2151)), ('##yy', np.float32(0.1944)), ('effe', np.float32(0.1917))]
# Dissimilar: ('subconscio', np.float32(-0.1782))
#
# Word: supporti
# Similar: [('overwh', np.float32(0.1933)), ('##tsick', np.float32(0.1899)), ('games', np.float32(0.1815))]
# Dissimilar: ('versus', np.float32(-0.2156))
#
# Word: supportiv
# Similar: [('unde', np.float32(0.1847)), ('exa', np.float32(0.1759)), ('croissan', np.float32(0.1721))]
# Dissimilar: ('##in', np.float32(-0.1728))
#
# Word: supportin
# Similar: [('fou', np.float32(0.1937)), ('##echniqu', np.float32(0.1732)), ('emptied', np.float32(0.1699))]
# Dissimilar: ('chang', np.float32(-0.1971))
#
# Word: supporting
# Similar: [('color', np.float32(0.7442)), ('sharing', np.float32(0.7433)), ('unusual', np.float32(0.7248))]
# Dissimilar: ('sore', np.float32(-0.5497))
#
# Word: yo
# Similar: [('brimming', np.float32(0.1774)), ('devices', np.float32(0.1699)), ('moro', np.float32(0.1687))]
# Dissimilar: ('##inancially', np.float32(-0.1905))
#
# Word: you
# Similar: [('they', np.float32(0.825)), ('we', np.float32(0.8024)), ('obrian', np.float32(0.7021))]
# Dissimilar: ('cynical', np.float32(-0.4401))
#
# Word: yor
# Similar: [('##thod', np.float32(0.215)), ('exp', np.float32(0.2039)), ('revampe', np.float32(0.1926))]
# Dissimilar: ('admired', np.float32(-0.2004))
#
# Word: york
# Similar: [('situations', np.float32(0.8203)), ('stage', np.float32(0.7454)), ('simplicity', np.float32(0.7174))]
# Dissimilar: ('hugely', np.float32(-0.4757))
#
# Word: yog
# Similar: [('pacifie', np.float32(0.186)), ('explod', np.float32(0.1857)), ('nightmar', np.float32(0.1838))]
# Dissimilar: ('amu', np.float32(-0.1848))
#
# Word: yoga
# Similar: [('newsprint', np.float32(0.8846)), ('blue', np.float32(0.8797)), ('satan', np.float32(0.8794))]
# Dissimilar: ('sore', np.float32(-0.7589))
#
# Word: squ
# Similar: [('##pos', np.float32(0.1951)), ('##eaning', np.float32(0.1939)), ('happi', np.float32(0.1873))]
# Dissimilar: ('chill', np.float32(-0.1922))
#
# Word: exci
# Similar: [('##antic', np.float32(0.1691)), ('shamed', np.float32(0.1665)), ('distract', np.float32(0.1608))]
# Dissimilar: ('spazzol', np.float32(-0.1893))
#
# Word: excit
# Similar: [('thes', np.float32(0.1966)), ('evi', np.float32(0.1747)), ('giraffe', np.float32(0.163))]
# Dissimilar: ('##enos', np.float32(-0.1733))
#
# Word: app
# Similar: [('animat', np.float32(0.1965)), ('accid', np.float32(0.1908)), ('##diculous', np.float32(0.1792))]
# Dissimilar: ('exict', np.float32(-0.2046))
#
# Word: ##app
# Similar: [('princ', np.float32(0.1972)), ('iced', np.float32(0.1749)), ('puts', np.float32(0.1676))]
# Dissimilar: ('##eminds', np.float32(-0.1932))
#
# Word: happ
# Similar: [('ive', np.float32(0.1898)), ('##agic', np.float32(0.1793)), ('abused', np.float32(0.1774))]
# Dissimilar: ('congre', np.float32(-0.1665))
#
# Word: ##sapp
# Similar: [('disheartene', np.float32(0.1765)), ('enlis', np.float32(0.1722)), ('##lps', np.float32(0.1717))]
# Dissimilar: ('##sserts', np.float32(-0.2182))
#
# Word: capp
# Similar: [('fair', np.float32(0.8178)), ('meals', np.float32(0.8173)), ('examination', np.float32(0.8171))]
# Dissimilar: ('exceptions', np.float32(-0.4924))
#
# Word: lapp
# Similar: [('##rsion', np.float32(0.1951)), ('specialne', np.float32(0.1809)), ('hitler', np.float32(0.1775))]
# Dissimilar: ('soil', np.float32(-0.194))
#
# Word: ##isapp
# Similar: [('eith', np.float32(0.1678)), ('pan', np.float32(0.1662)), ('disne', np.float32(0.1633))]
# Dissimilar: ('##esserts', np.float32(-0.1806))
#
# Word: disapp
# Similar: [('##esnt', np.float32(0.181)), ('##logica', np.float32(0.17)), ('hgt', np.float32(0.1692))]
# Dissimilar: ('consignm', np.float32(-0.1706))
#
# Word: lappi
# Similar: [('mosha', np.float32(0.2006)), ('nu', np.float32(0.1682)), ('##ews', np.float32(0.1626))]
# Dissimilar: ('##amin', np.float32(-0.1915))
#
# Word: ##rapp
# Similar: [('##vag', np.float32(0.1991)), ('##nsid', np.float32(0.1701)), ('comm', np.float32(0.1646))]
# Dissimilar: ('tickl', np.float32(-0.177))
#
# Word: grapp
# Similar: [('##ntia', np.float32(0.2057)), ('riv', np.float32(0.1706)), ('##eact', np.float32(0.1669))]
# Dissimilar: ('##sion', np.float32(-0.1787))
#
# Word: wrapp
# Similar: [('##ut', np.float32(0.1672)), ('##much', np.float32(0.1638)), ('submi', np.float32(0.1584))]
# Dissimilar: ('gav', np.float32(-0.1974))
#
# Word: ##appr
# Similar: [('##link', np.float32(0.2178)), ('cu', np.float32(0.176)), ('##kou', np.float32(0.169))]
# Dissimilar: ('##na', np.float32(-0.2217))
#
# Word: grappl
# Similar: [('##culous', np.float32(0.1859)), ('##jub', np.float32(0.1805)), ('adomen', np.float32(0.1689))]
# Dissimilar: ('ex', np.float32(-0.1919))
#
# Word: grappli
# Similar: [('##fit', np.float32(0.1767)), ('##nonym', np.float32(0.1739)), ('interpret', np.float32(0.1702))]
# Dissimilar: ('##rful', np.float32(-0.1968))
#
# Word: grapplin
# Similar: [('marriage', np.float32(0.1981)), ('affirmation', np.float32(0.1907)), ('ashamed', np.float32(0.19))]
# Dissimilar: ('##nsomnia', np.float32(-0.183))
#
# Word: grappling
# Similar: [('someway', np.float32(0.8678)), ('waking', np.float32(0.8545)), ('lacking', np.float32(0.8536))]
# Dissimilar: ('incidents', np.float32(-0.7488))
#
# Word: lappin
# Similar: [('unappreciat', np.float32(0.1898)), ('formul', np.float32(0.1881)), ('daw', np.float32(0.1813))]
# Dissimilar: ('nagal', np.float32(-0.1748))
#
# Word: lapping
# Similar: [('egypt', np.float32(0.7594)), ('above', np.float32(0.6351)), ('predictable', np.float32(0.6345))]
# Dissimilar: ('oblige', np.float32(-0.3833))
#
# Word: ##nappr
# Similar: [('chai', np.float32(0.167)), ('nud', np.float32(0.1613)), ('circums', np.float32(0.1604))]
# Dissimilar: ('distraugh', np.float32(-0.1913))
#
# Word: unappr
# Similar: [('marriag', np.float32(0.1827)), ('##ssional', np.float32(0.1744)), ('##ransport', np.float32(0.1739))]
# Dissimilar: ('##gargo', np.float32(-0.199))
#
# Word: appr
# Similar: [('exe', np.float32(0.1828)), ('##ympathizing', np.float32(0.1655)), ('##ve', np.float32(0.1651))]
# Dissimilar: ('##ars', np.float32(-0.1768))
#
# Word: disappo
# Similar: [('##ntionally', np.float32(0.1767)), ('##ereotypical', np.float32(0.1755)), ('##oa', np.float32(0.1743))]
# Dissimilar: ('##ogica', np.float32(-0.1939))
#
# Word: disappoi
# Similar: [('##lumb', np.float32(0.1819)), ('##attainabl', np.float32(0.1698)), ('##lking', np.float32(0.1656))]
# Dissimilar: ('discussion', np.float32(-0.1997))
#
# Word: disappoin
# Similar: [('##tamps', np.float32(0.1808)), ('##ecuriti', np.float32(0.1693)), ('stor', np.float32(0.1659))]
# Dissimilar: ('zoo', np.float32(-0.1961))
#
# Word: disappoint
# Similar: [('omg', np.float32(0.9445)), ('relax', np.float32(0.9402)), ('disgust', np.float32(0.9336))]
# Dissimilar: ('sore', np.float32(-0.6663))
#
# Word: disappointm
# Similar: [('willingly', np.float32(0.182)), ('##arn', np.float32(0.178)), ('##labb', np.float32(0.1667))]
# Dissimilar: ('host', np.float32(-0.1856))
#
# Word: ##mp
# Similar: [('hoa', np.float32(0.2034)), ('##eece', np.float32(0.1933)), ('counci', np.float32(0.1809))]
# Dissimilar: ('disagr', np.float32(-0.1764))
#
# Word: emp
# Similar: [('invigorate', np.float32(0.1991)), ('cogni', np.float32(0.174)), ('toxi', np.float32(0.1735))]
# Dissimilar: ('##rap', np.float32(-0.1816))
#
# Word: ##opp
# Similar: [('##lein', np.float32(0.1863)), ('roomat', np.float32(0.1725)), ('dinn', np.float32(0.1674))]
# Dissimilar: ('##ef', np.float32(-0.1992))
#
# Word: copp
# Similar: [('daycar', np.float32(0.1948)), ('measur', np.float32(0.1679)), ('##ehaviour', np.float32(0.16))]
# Dissimilar: ('##eece', np.float32(-0.1924))
#
# Word: ##hopp
# Similar: [('##port', np.float32(0.2006)), ('shau', np.float32(0.1946)), ('##tir', np.float32(0.1722))]
# Dissimilar: ('unsettle', np.float32(-0.1799))
#
# Word: shopp
# Similar: [('absolut', np.float32(0.1975)), ('favourite', np.float32(0.1816)), ('topics', np.float32(0.176))]
# Dissimilar: ('orth', np.float32(-0.2013))
#
# Word: popp
# Similar: [('pad', np.float32(0.2086)), ('##abl', np.float32(0.1908)), ('##neath', np.float32(0.1831))]
# Dissimilar: ('##ccustom', np.float32(-0.1965))
#
# Word: shoppi
# Similar: [('##ells', np.float32(0.1809)), ('distraugh', np.float32(0.1715)), ('atte', np.float32(0.1652))]
# Dissimilar: ('vine', np.float32(-0.1825))
#
# Word: ##ipp
# Similar: [('surg', np.float32(0.2063)), ('joyf', np.float32(0.1913)), ('##oup', np.float32(0.1789))]
# Dissimilar: ('##ctful', np.float32(-0.2219))
#
# Word: ripp
# Similar: [('##imony', np.float32(0.1941)), ('##eight', np.float32(0.1861)), ('##nanigans', np.float32(0.1855))]
# Dissimilar: ('sig', np.float32(-0.1722))
#
# Word: rippl
# Similar: [('##licious', np.float32(0.1936)), ('pri', np.float32(0.1865)), ('hallow', np.float32(0.1837))]
# Dissimilar: ('interne', np.float32(-0.1891))
#
# Word: rippli
# Similar: [('consolidatio', np.float32(0.2306)), ('ci', np.float32(0.1818)), ('##miliarity', np.float32(0.177))]
# Dissimilar: ('fund', np.float32(-0.1837))
#
# Word: ##lipp
# Similar: [('##affir', np.float32(0.1889)), ('peacefuln', np.float32(0.1773)), ('unencumberedn', np.float32(0.1747))]
# Dissimilar: ('exter', np.float32(-0.1978))
#
# Word: slipp
# Similar: [('##sitor', np.float32(0.1926)), ('turnovers', np.float32(0.164)), ('##vativ', np.float32(0.1632))]
# Dissimilar: ('fina', np.float32(-0.202))
#
# Word: flipp
# Similar: [('divi', np.float32(0.1995)), ('##evelopm', np.float32(0.1855)), ('##lancho', np.float32(0.1813))]
# Dissimilar: ('ghost', np.float32(-0.1727))
#
# Word: ##ripp
# Similar: [('##nap', np.float32(0.196)), ('mounta', np.float32(0.1816)), ('##onto', np.float32(0.1638))]
# Dissimilar: ('chor', np.float32(-0.2166))
#
# Word: ##tripp
# Similar: [('##alling', np.float32(0.1784)), ('impo', np.float32(0.1771)), ('##atonic', np.float32(0.1713))]
# Dissimilar: ('##eal', np.float32(-0.1757))
#
# Word: stripp
# Similar: [('##enerational', np.float32(0.2076)), ('##nbows', np.float32(0.1954)), ('gratitud', np.float32(0.1915))]
# Dissimilar: ('particula', np.float32(-0.2147))
#
# Word: shoppin
# Similar: [('cult', np.float32(0.1887)), ('rhyth', np.float32(0.1801)), ('##ecent', np.float32(0.1667))]
# Dissimilar: ('##rida', np.float32(-0.2313))
#
# Word: shopping
# Similar: [('explode', np.float32(0.9167)), ('pause', np.float32(0.9156)), ('setting', np.float32(0.9134))]
# Dissimilar: ('sore', np.float32(-0.8085))
#
# Word: ripplin
# Similar: [('##eonard', np.float32(0.178)), ('##etrospect', np.float32(0.1675)), ('##custom', np.float32(0.1662))]
# Dissimilar: ('##wi', np.float32(-0.1779))
#
# Word: rippling
# Similar: [('statistic', np.float32(0.8912)), ('stem', np.float32(0.8806)), ('argued', np.float32(0.8774))]
# Dissimilar: ('sore', np.float32(-0.7429))
#
# Word: ##topp
# Similar: [('opiu', np.float32(0.2045)), ('smother', np.float32(0.1897)), ('living', np.float32(0.1867))]
# Dissimilar: ('che', np.float32(-0.1968))
#
# Word: stopp
# Similar: [('harm', np.float32(0.1817)), ('bos', np.float32(0.18)), ('##gnific', np.float32(0.1635))]
# Dissimilar: ('##eopard', np.float32(-0.1894))
#
# Word: topp
# Similar: [('##parat', np.float32(0.1835)), ('creatur', np.float32(0.1751)), ('true', np.float32(0.171))]
# Dissimilar: ('##troying', np.float32(-0.1882))
#
# Word: ##ropp
# Similar: [('pacifi', np.float32(0.2109)), ('pakista', np.float32(0.1978)), ('against', np.float32(0.1875))]
# Dissimilar: ('intimat', np.float32(-0.2042))
#
# Word: dropp
# Similar: [('##asical', np.float32(0.1843)), ('##conds', np.float32(0.175)), ('victo', np.float32(0.1739))]
# Dissimilar: ('troub', np.float32(-0.173))
#
# Word: droppi
# Similar: [('emerg', np.float32(0.1794)), ('uuuugh', np.float32(0.1689)), ('##rsion', np.float32(0.1684))]
# Dissimilar: ('##amp', np.float32(-0.1891))
#
# Word: toppi
# Similar: [('##cuting', np.float32(0.1846)), ('##rinking', np.float32(0.1743)), ('photogra', np.float32(0.1719))]
# Dissimilar: ('##stagram', np.float32(-0.2125))
#
# Word: droppin
# Similar: [('encourag', np.float32(0.1757)), ('##ogica', np.float32(0.1731)), ('nigh', np.float32(0.169))]
# Dissimilar: ('##tritional', np.float32(-0.1735))
#
# Word: dropping
# Similar: [('mira', np.float32(0.9333)), ('tempted', np.float32(0.9248)), ('fortunate', np.float32(0.9066))]
# Dissimilar: ('incidents', np.float32(-0.8125))
#
# Word: toppin
# Similar: [('##nerally', np.float32(0.2064)), ('stol', np.float32(0.1908)), ('croissa', np.float32(0.1888))]
# Dissimilar: ('picking', np.float32(-0.1818))
#
# Word: topping
# Similar: [('mirror', np.float32(0.8868)), ('brooks', np.float32(0.8364)), ('erik', np.float32(0.8354))]
# Dissimilar: ('sore', np.float32(-0.7063))
#
# Word: to
# Similar: [('sending', np.float32(0.551)), ('notch', np.float32(0.5285)), ('investigators', np.float32(0.521))]
# Dissimilar: ('examples', np.float32(-0.3658))
#
# Word: no
# Similar: [('america', np.float32(0.6547)), ('another', np.float32(0.6423)), ('prospects', np.float32(0.5792))]
# Dissimilar: ('tx', np.float32(-0.4462))
#
# Word: now
# Similar: [('zooming', np.float32(0.6947)), ('still', np.float32(0.6526)), ('mountains', np.float32(0.6474))]
# Dissimilar: ('spouse', np.float32(-0.5049))
#
# Word: not
# Similar: [('chuffed', np.float32(0.6523)), ('afraid', np.float32(0.6437)), ('sure', np.float32(0.641))]
# Dissimilar: ('riders', np.float32(-0.4417))
#
# Word: xm
# Similar: [('##mors', np.float32(0.1811)), ('colou', np.float32(0.1731)), ('##fectiv', np.float32(0.171))]
# Dissimilar: ('spon', np.float32(-0.1827))
#
# Word: xma
# Similar: [('communicat', np.float32(0.1908)), ('##upstamps', np.float32(0.1765)), ('##ractiv', np.float32(0.1725))]
# Dissimilar: ('amplifi', np.float32(-0.178))
#
# Word: xmas
# Similar: [('rant', np.float32(0.8478)), ('quit', np.float32(0.8287)), ('received', np.float32(0.8244))]
# Dissimilar: ('freakishly', np.float32(-0.6061))
#
# Word: ##jo
# Similar: [('##anag', np.float32(0.1918)), ('roo', np.float32(0.1879)), ('twic', np.float32(0.1823))]
# Dissimilar: ('##bration', np.float32(-0.1913))
#
# Word: ##joy
# Similar: [('##lling', np.float32(0.1833)), ('traumatis', np.float32(0.176)), ('##chologica', np.float32(0.1683))]
# Dissimilar: ('##mains', np.float32(-0.1838))
#
# Word: ##jor
# Similar: [('hardc', np.float32(0.2062)), ('camb', np.float32(0.1861)), ('lounge', np.float32(0.1638))]
# Dissimilar: ('futur', np.float32(-0.162))
#
# Word: ##ajor
# Similar: [('##ontation', np.float32(0.1996)), ('##iour', np.float32(0.1824)), ('sati', np.float32(0.1762))]
# Dissimilar: ('signa', np.float32(-0.1631))
#
# Word: major
# Similar: [('wuss', np.float32(0.5957)), ('second', np.float32(0.595)), ('big', np.float32(0.5936))]
# Dissimilar: ('wh', np.float32(-0.4984))
#
# Word: ##njoy
# Similar: [('##org', np.float32(0.1732)), ('##educ', np.float32(0.1677)), ('bod', np.float32(0.1656))]
# Dissimilar: ('obv', np.float32(-0.1901))
#
# Word: enjoy
# Similar: [('reveal', np.float32(0.9091)), ('dream', np.float32(0.9053)), ('bought', np.float32(0.8983))]
# Dissimilar: ('incidents', np.float32(-0.7527))
#
# Word: empt
# Similar: [('logi', np.float32(0.1943)), ('occured', np.float32(0.189)), ('discourag', np.float32(0.1856))]
# Dissimilar: ('##amatically', np.float32(-0.1887))
#
# Word: empty
# Similar: [('roof', np.float32(0.881)), ('alaska', np.float32(0.8781)), ('grouchy', np.float32(0.8757))]
# Dissimilar: ('incidents', np.float32(-0.7526))
#
# Word: emph
# Similar: [('##una', np.float32(0.1833)), ('##dentify', np.float32(0.1812)), ('ca', np.float32(0.1801))]
# Dissimilar: ('##randmoth', np.float32(-0.2))
#
# Word: empha
# Similar: [('disa', np.float32(0.1906)), ('bridg', np.float32(0.1794)), ('##irty', np.float32(0.1695))]
# Dissimilar: ('applicatio', np.float32(-0.1873))
#
# Word: emphas
# Similar: [('riders', np.float32(0.1921)), ('viol', np.float32(0.1748)), ('##egion', np.float32(0.1681))]
# Dissimilar: ('emot', np.float32(-0.18))
#
# Word: emphasiz
# Similar: [('##nsiv', np.float32(0.1917)), ('overwhe', np.float32(0.1664)), ('washr', np.float32(0.1617))]
# Dissimilar: ('##cognition', np.float32(-0.2183))
#
# Word: emphasi
# Similar: [('anything', np.float32(0.1948)), ('sniiiiifff', np.float32(0.1924)), ('cliched', np.float32(0.1848))]
# Dissimilar: ('sor', np.float32(-0.1864))
#
# Word: emphasis
# Similar: [('##eread', np.float32(0.1852)), ('chins', np.float32(0.1781)), ('jong', np.float32(0.1757))]
# Dissimilar: ('##twh', np.float32(-0.1816))
#
# Word: empti
# Similar: [('taylor', np.float32(0.174)), ('dishearten', np.float32(0.1693)), ('fund', np.float32(0.1601))]
# Dissimilar: ('cambo', np.float32(-0.1929))
#
# Word: ##ng
# Similar: [('mosqu', np.float32(0.2035)), ('trimm', np.float32(0.1742)), ('tickl', np.float32(0.1725))]
# Dissimilar: ('##dmi', np.float32(-0.2273))
#
# Word: ##gh
# Similar: [('honk', np.float32(0.2045)), ('##ab', np.float32(0.1857)), ('conservativ', np.float32(0.1796))]
# Dissimilar: ('stabl', np.float32(-0.1752))
#
# Word: ##giz
# Similar: [('catap', np.float32(0.1919)), ('##egins', np.float32(0.1838)), ('ale', np.float32(0.178))]
# Dissimilar: ('ours', np.float32(-0.1879))
#
# Word: ##ugh
# Similar: [('##lt', np.float32(0.1894)), ('##umoni', np.float32(0.1854)), ('cohe', np.float32(0.1757))]
# Dissimilar: ('gree', np.float32(-0.1944))
#
# Word: ##igh
# Similar: [('local', np.float32(0.1727)), ('hor', np.float32(0.1717)), ('##lind', np.float32(0.1675))]
# Dissimilar: ('obligat', np.float32(-0.1869))
#
# Word: nigh
# Similar: [('putt', np.float32(0.1941)), ('depr', np.float32(0.182)), ('equati', np.float32(0.1747))]
# Dissimilar: ('copi', np.float32(-0.1724))
#
# Word: righ
# Similar: [('uniqu', np.float32(0.1728)), ('##rmally', np.float32(0.1691)), ('comatos', np.float32(0.1673))]
# Dissimilar: ('incheswhyinch', np.float32(-0.1784))
#
# Word: migh
# Similar: [('##pous', np.float32(0.1815)), ('worthl', np.float32(0.1812)), ('##loci', np.float32(0.1805))]
# ...
# Dissimilar: ('hits', np.float32(-0.1841))
#
# Word: customers
# Similar: [('prettier', np.float32(0.7152)), ('wrapping', np.float32(0.7111)), ('solve', np.float32(0.7043))]
# Dissimilar: ('latter', np.float32(-0.5689))
#
# Word: flowers
# Similar: [('stickiness', np.float32(0.874)), ('harbor', np.float32(0.8672)), ('culprit', np.float32(0.8655))]
# Dissimilar: ('sore', np.float32(-0.7082))
#
# Word: teachers
# Similar: [('devour', np.float32(0.7738)), ('repay', np.float32(0.6725)), ('led', np.float32(0.6634))]
# Dissimilar: ('cynical', np.float32(-0.4572))
#
# Word: matters
# Similar: [('matter', np.float32(0.7476)), ('wondering', np.float32(0.7439)), ('warn', np.float32(0.7379))]
# Dissimilar: ('latte', np.float32(-0.6384))
#
# Word: ##aders
# Similar: [('##tuck', np.float32(0.1742)), ('particularl', np.float32(0.1678)), ('base', np.float32(0.1658))]
# Dissimilar: ('##rohibi', np.float32(-0.1814))
#
# Word: riders
# Similar: [('dependent', np.float32(0.5121)), ('category', np.float32(0.4731)), ('americana', np.float32(0.4662))]
# Dissimilar: ('lucky', np.float32(-0.5489))
#
# Word: developers
# Similar: [('hyper', np.float32(0.8182)), ('appropriately', np.float32(0.8027)), ('dismayed', np.float32(0.7994))]
# Dissimilar: ('incidents', np.float32(-0.5262))
#
# Word: papers
# Similar: [('appreciated', np.float32(0.7398)), ('rehearsals', np.float32(0.7373)), ('newspapers', np.float32(0.729))]
# Dissimilar: ('sore', np.float32(-0.5664))
#
# Word: wearers
# Similar: [('wearily', np.float32(0.9431)), ('cringe', np.float32(0.9232)), ('anticipated', np.float32(0.9216))]
# Dissimilar: ('sore', np.float32(-0.8142))
#
# Word: followers
# Similar: [('carin', np.float32(0.713)), ('t', np.float32(0.6873)), ('oblige', np.float32(0.4618))]
# Dissimilar: ('bro', np.float32(-0.4361))
#
# Word: eaters
# Similar: [('circle', np.float32(0.5086)), ('[PAD]', np.float32(0.4682)), ('like', np.float32(0.4123))]
# Dissimilar: ('kindness', np.float32(-0.3289))
#
# Word: reminders
# Similar: [('ini', np.float32(0.8894)), ('typed', np.float32(0.8853)), ('encounter', np.float32(0.8829))]
# Dissimilar: ('incidents', np.float32(-0.7348))
#
# Word: numbers
# Similar: [('india', np.float32(0.9181)), ('clara', np.float32(0.9165)), ('soap', np.float32(0.8811))]
# Dissimilar: ('sore', np.float32(-0.7672))
#
# Word: watchers
# Similar: [('cypress', np.float32(0.795)), ('perceived', np.float32(0.7881)), ('rhythm', np.float32(0.7745))]
# Dissimilar: ('sore', np.float32(-0.5553))
#
# Word: supporters
# Similar: [('sinks', np.float32(0.878)), ('automation', np.float32(0.8621)), ('reactions', np.float32(0.8591))]
# Dissimilar: ('sore', np.float32(-0.5982))
#
# Word: shoulders
# Similar: [('ankle', np.float32(0.9226)), ('sleeve', np.float32(0.8914)), ('bedroom', np.float32(0.8913))]
# Dissimilar: ('incidents', np.float32(-0.796))
#
# Word: workers
# Similar: [('co', np.float32(0.7414)), ('bore', np.float32(0.5931)), ('pregant', np.float32(0.592))]
# Dissimilar: ('marriages', np.float32(-0.3763))
#
# Word: nighters
# Similar: [('stoned', np.float32(0.7795)), ('whiney', np.float32(0.769)), ('nervous', np.float32(0.7586))]
# Dissimilar: ('latte', np.float32(-0.6764))
#
# Word: offers
# Similar: [('gently', np.float32(0.5074)), ('initially', np.float32(0.4295)), ('changed', np.float32(0.4252))]
# Dissimilar: ('inter', np.float32(-0.3407))
#
# Word: downers
# Similar: [('aware', np.float32(0.8483)), ('capable', np.float32(0.8363)), ('trigger', np.float32(0.8361))]
# Dissimilar: ('incidents', np.float32(-0.6531))
#
# Word: users
# Similar: [('trips', np.float32(0.6702)), ('peak', np.float32(0.5864)), ('spending', np.float32(0.5856))]
# Dissimilar: ('questionable', np.float32(-0.4385))
#
# Word: mrs
# Similar: [('lightning', np.float32(0.5208)), ('truthful', np.float32(0.4938)), ('fa', np.float32(0.485))]
# Dissimilar: ('attractive', np.float32(-0.3991))
#
# Word: ##ners
# Similar: [('tradition', np.float32(0.1832)), ('##otion', np.float32(0.178)), ('transce', np.float32(0.1672))]
# Dissimilar: ('asha', np.float32(-0.2155))
#
# Word: ##eaders
# Similar: [('##air', np.float32(0.2092)), ('spoken', np.float32(0.2043)), ('embar', np.float32(0.1897))]
# Dissimilar: ('##rrific', np.float32(-0.1787))
#
# Word: readers
# Similar: [('loyal', np.float32(0.8253)), ('sharing', np.float32(0.8099)), ('rest', np.float32(0.8068))]
# Dissimilar: ('sore', np.float32(-0.634))
#
# Word: ##eers
# Similar: [('##min', np.float32(0.1856)), ('##nsomnia', np.float32(0.1727)), ('##riously', np.float32(0.1716))]
# Dissimilar: ('eas', np.float32(-0.186))
#
# Word: peers
# Similar: [('typical', np.float32(0.7065)), ('manageable', np.float32(0.518)), ('smooth', np.float32(0.5158))]
# Dissimilar: ('latter', np.float32(-0.3888))
#
# Word: careers
# Similar: [('established', np.float32(0.5652)), ('they', np.float32(0.4535)), ('tenge', np.float32(0.4512))]
# Dissimilar: ('charged', np.float32(-0.3371))
#
# Word: ##eners
# Similar: [('horn', np.float32(0.2042)), ('##ood', np.float32(0.198)), ('##suad', np.float32(0.1834))]
# Dissimilar: ('##iption', np.float32(-0.1824))
#
# Word: sweeteners
# Similar: [('incheswhyinches', np.float32(0.6175)), ('bundle', np.float32(0.5933)), ('erm', np.float32(0.5793))]
# Dissimilar: ('latte', np.float32(-0.4526))
#
# Word: quite
# Similar: [('hopelessly', np.float32(0.8108)), ('unusually', np.float32(0.7959)), ('insatiably', np.float32(0.7956))]
# Dissimilar: ('incidents', np.float32(-0.595))
#
# Word: ##end
# Similar: [('##edrooms', np.float32(0.1794)), ('##nde', np.float32(0.1705)), ('##rap', np.float32(0.162))]
# Dissimilar: ('notch', np.float32(-0.1716))
#
# Word: weekend
# Similar: [('embrace', np.float32(0.838)), ('devote', np.float32(0.8276)), ('marathon', np.float32(0.827))]
# Dissimilar: ('levi', np.float32(-0.6156))
#
# Word: legend
# Similar: [('fever', np.float32(0.9023)), ('reiterate', np.float32(0.8959)), ('exercised', np.float32(0.8884))]
# Dissimilar: ('incidents', np.float32(-0.6982))
#
# Word: offend
# Similar: [('hallucinati', np.float32(0.2045)), ('marr', np.float32(0.1832)), ('tal', np.float32(0.1681))]
# Dissimilar: ('proposed', np.float32(-0.2036))
#
# Word: tend
# Similar: [('percieve', np.float32(0.9419)), ('vow', np.float32(0.9407)), ('adjust', np.float32(0.9218))]
# Dissimilar: ('incidents', np.float32(-0.739))
#
# Word: send
# Similar: [('lurking', np.float32(0.746)), ('verse', np.float32(0.7413)), ('record', np.float32(0.7389))]
# Dissimilar: ('hugely', np.float32(-0.3936))
#
# Word: ##nde
# Similar: [('facul', np.float32(0.1838)), ('##amatic', np.float32(0.1835)), ('betw', np.float32(0.1807))]
# Dissimilar: ('##ssful', np.float32(-0.23))
#
# Word: ##ndee
# Similar: [('gotte', np.float32(0.1886)), ('unfair', np.float32(0.1875)), ('##onounc', np.float32(0.1855))]
# Dissimilar: ('chari', np.float32(-0.1837))
#
# Word: ##ndeed
# Similar: [('##obl', np.float32(0.1912)), ('##akfa', np.float32(0.1877)), ('##tf', np.float32(0.1596))]
# Dissimilar: ('satur', np.float32(-0.1791))
#
# Word: offende
# Similar: [('##agging', np.float32(0.195)), ('##atsby', np.float32(0.1833)), ('suns', np.float32(0.1815))]
# Dissimilar: ('fl', np.float32(-0.2074))
#
# Word: offended
# Similar: [('ghosts', np.float32(0.9159)), ('honoured', np.float32(0.9153)), ('appropriately', np.float32(0.9104))]
# Dissimilar: ('incidents', np.float32(-0.8352))
#
# Word: come
# Similar: [('rise', np.float32(0.822)), ('concentrate', np.float32(0.8117)), ('holyhead', np.float32(0.8029))]
# Dissimilar: ('sore', np.float32(-0.6044))
#
# Word: comes
# Similar: [('emotional', np.float32(0.8623)), ('flee', np.float32(0.8523)), ('treasure', np.float32(0.8401))]
# Dissimilar: ('latter', np.float32(-0.6957))
#
# Word: ##ead
# Similar: [('seattle', np.float32(0.1918)), ('##rport', np.float32(0.1916)), ('well', np.float32(0.1895))]
# Dissimilar: ('##astf', np.float32(-0.2002))
#
# Word: read
# Similar: [('emily', np.float32(0.8717)), ('clench', np.float32(0.8691)), ('stepped', np.float32(0.8499))]
# Dissimilar: ('sore', np.float32(-0.6884))
#
# Word: dread
# Similar: [('birding', np.float32(0.69)), ('lurker', np.float32(0.6486)), ('bit', np.float32(0.6457))]
# Dissimilar: ('etsy', np.float32(-0.4674))
#
# Word: ##read
# Similar: [('##stakingly', np.float32(0.1733)), ('blair', np.float32(0.1678)), ('hers', np.float32(0.1619))]
# Dissimilar: ('attitud', np.float32(-0.1928))
#
# Word: tad
# Similar: [('bonus', np.float32(0.8975)), ('warning', np.float32(0.8782)), ('failure', np.float32(0.8648))]
# Dissimilar: ('incidents', np.float32(-0.7156))
#
# Word: rt
# Similar: [('urg', np.float32(0.2161)), ('coura', np.float32(0.1871)), ('##unish', np.float32(0.1714))]
# Dissimilar: ('##ttachm', np.float32(-0.1802))
#
# Word: ##eread
# Similar: [('cours', np.float32(0.2114)), ('frust', np.float32(0.1968)), ('emphasis', np.float32(0.1852))]
# Dissimilar: ('##akn', np.float32(-0.1733))
#
# Word: reread
# Similar: [('brag', np.float32(0.9427)), ('turns', np.float32(0.9331)), ('stepped', np.float32(0.9246))]
# Dissimilar: ('incidents', np.float32(-0.812))
#
# Word: rte
# Similar: [('emoticons', np.float32(0.8147)), ('img', np.float32(0.6778)), ('mrdanbaird', np.float32(0.6404))]
# Dissimilar: ('keep', np.float32(-0.2161))
#
# Word: shocke
# Similar: [('##vativ', np.float32(0.1935)), ('depriv', np.float32(0.1709)), ('surpr', np.float32(0.167))]
# Dissimilar: ('rampa', np.float32(-0.1834))
#
# Word: shocked
# Similar: [('offended', np.float32(0.8793)), ('doubtful', np.float32(0.8731)), ('proud', np.float32(0.8721))]
# Dissimilar: ('incidents', np.float32(-0.8134))
#
# Word: hope
# Similar: [('thought', np.float32(0.9279)), ('wish', np.float32(0.8986)), ('bought', np.float32(0.886))]
# Dissimilar: ('latte', np.float32(-0.638))
#
# Word: hopel
# Similar: [('##rsuad', np.float32(0.192)), ('dub', np.float32(0.1893)), ('director', np.float32(0.1693))]
# Dissimilar: ('##all', np.float32(-0.1812))
#
# Word: hopes
# Similar: [('privileged', np.float32(0.895)), ('dumpee', np.float32(0.8908)), ('waits', np.float32(0.8823))]
# Dissimilar: ('incidents', np.float32(-0.7703))
#
# Word: hopele
# Similar: [('exhil', np.float32(0.1995)), ('##nhuman', np.float32(0.1789)), ('##ailormoon', np.float32(0.1734))]
# Dissimilar: ('camb', np.float32(-0.193))
#
# Word: hopeless
# Similar: [('suffocated', np.float32(0.9508)), ('stare', np.float32(0.9353)), ('admiration', np.float32(0.9285))]
# Dissimilar: ('incidents', np.float32(-0.8282))
#
# Word: she
# Similar: [('he', np.float32(0.7663)), ('i', np.float32(0.6812)), ('biochemistry', np.float32(0.6504))]
# Dissimilar: ('thrift', np.float32(-0.4771))
#
# Word: shr
# Similar: [('stimulat', np.float32(0.167)), ('##lind', np.float32(0.1662)), ('populatio', np.float32(0.1646))]
# Dissimilar: ('##azy', np.float32(-0.183))
#
# Word: shes
# Similar: [('treasured', np.float32(0.8102)), ('scarce', np.float32(0.8029)), ('terrific', np.float32(0.7934))]
# Dissimilar: ('incidents', np.float32(-0.7026))
#
# Word: shre
# Similar: [('costum', np.float32(0.1812)), ('eaters', np.float32(0.1809)), ('##ncapabl', np.float32(0.1796))]
# Dissimilar: ('eb', np.float32(-0.1737))
#
# Word: shred
# Similar: [('verse', np.float32(0.7638)), ('exchange', np.float32(0.754)), ('tab', np.float32(0.7528))]
# Dissimilar: ('islam', np.float32(-0.4254))
#
# Word: live
# Similar: [('throw', np.float32(0.9027)), ('stated', np.float32(0.899)), ('walk', np.float32(0.8957))]
# Dissimilar: ('sore', np.float32(-0.787))
#
# Word: lives
# Similar: [('spite', np.float32(0.8171)), ('simplicity', np.float32(0.8057)), ('misery', np.float32(0.7991))]
# Dissimilar: ('sore', np.float32(-0.5341))
#
# Word: accepte
# Similar: [('##gards', np.float32(0.19)), ('##ental', np.float32(0.1864)), ('manageabl', np.float32(0.1782))]
# Dissimilar: ('amu', np.float32(-0.183))
#
# Word: accepted
# Similar: [('offended', np.float32(0.8941)), ('suspicious', np.float32(0.8936)), ('dissatisfied', np.float32(0.8819))]
# Dissimilar: ('incidents', np.float32(-0.7249))
#
# Word: ##ens
# Similar: [('##epeating', np.float32(0.1832)), ('prepost', np.float32(0.1822)), ('concer', np.float32(0.1807))]
# Dissimilar: ('tempe', np.float32(-0.1777))
#
# Word: jens
# Similar: [('retirement', np.float32(0.4669)), ('methods', np.float32(0.367)), ('mobility', np.float32(0.3567))]
# Dissimilar: ('repeating', np.float32(-0.2224))
#
# Word: sens
# Similar: [('movi', np.float32(0.2097)), ('thirt', np.float32(0.1899)), ('##veal', np.float32(0.1859))]
# Dissimilar: ('subco', np.float32(-0.1686))
#
# Word: listens
# Similar: [('play', np.float32(0.8706)), ('pulp', np.float32(0.8659)), ('lunchroom', np.float32(0.8658))]
# Dissimilar: ('sore', np.float32(-0.7003))
#
# Word: tons
# Similar: [('periods', np.float32(0.9102)), ('extensions', np.float32(0.8902)), ('aware', np.float32(0.8902))]
# Dissimilar: ('incidents', np.float32(-0.7299))
#
# Word: sense
# Similar: [('plenty', np.float32(0.848)), ('mixture', np.float32(0.8455)), ('assessment', np.float32(0.8452))]
# Dissimilar: ('sore', np.float32(-0.4557))
#
# Word: ##er
# Similar: [('value', np.float32(0.7245)), ('bull', np.float32(0.7189)), ('lifting', np.float32(0.7152))]
# Dissimilar: ('sore', np.float32(-0.5002))
#
# Word: matter
# Similar: [('directly', np.float32(0.8754)), ('comprehend', np.float32(0.8379)), ('celebrates', np.float32(0.8342))]
# Dissimilar: ('incidents', np.float32(-0.6845))
#
# Word: flower
# Similar: [('mica', np.float32(0.837)), ('race', np.float32(0.8242)), ('fake', np.float32(0.8158))]
# Dissimilar: ('instructions', np.float32(-0.554))
#
# Word: tender
# Similar: [('steve', np.float32(0.8355)), ('unprepared', np.float32(0.8237)), ('strongest', np.float32(0.8199))]
# Dissimilar: ('incidents', np.float32(-0.6031))
#
# Word: paper
# Similar: [('revamped', np.float32(0.9295)), ('blink', np.float32(0.9251)), ('reality', np.float32(0.9107))]
# Dissimilar: ('sore', np.float32(-0.7341))
#
# Word: bother
# Similar: [('fuck', np.float32(0.9246)), ('stress', np.float32(0.9079)), ('threaten', np.float32(0.9018))]
# Dissimilar: ('incidents', np.float32(-0.6351))
#
# Word: younger
# Similar: [('worthless', np.float32(0.8275)), ('fever', np.float32(0.809)), ('gift', np.float32(0.8089))]
# Dissimilar: ('latte', np.float32(-0.748))
#
# Word: slower
# Similar: [('brooks', np.float32(0.7994)), ('deceased', np.float32(0.7963)), ('grouchy', np.float32(0.7902))]
# Dissimilar: ('latter', np.float32(-0.6391))
#
# Word: employer
# Similar: [('pedestrian', np.float32(0.7684)), ('vertigo', np.float32(0.7653)), ('sooo', np.float32(0.749))]
# Dissimilar: ('sore', np.float32(-0.5397))
#
# Word: sober
# Similar: [('respond', np.float32(0.885)), ('comfort', np.float32(0.877)), ('scream', np.float32(0.8739))]
# Dissimilar: ('sore', np.float32(-0.7701))
#
# Word: leader
# Similar: [('elder', np.float32(0.6413)), ('pauses', np.float32(0.5865)), ('foot', np.float32(0.5801))]
# Dissimilar: ('really', np.float32(-0.45))
#
# Word: teacher
# Similar: [('stature', np.float32(0.9324)), ('outcome', np.float32(0.9238)), ('tomfoolery', np.float32(0.9194))]
# Dissimilar: ('sore', np.float32(-0.7736))
#
# Word: follower
# Similar: [('race', np.float32(0.833)), ('box', np.float32(0.8228)), ('sensation', np.float32(0.8184))]
# Dissimilar: ('latter', np.float32(-0.5738))
#
# Word: shower
# Similar: [('spider', np.float32(0.8789)), ('wuss', np.float32(0.8765)), ('soda', np.float32(0.8752))]
# Dissimilar: ('sore', np.float32(-0.6999))
#
# Word: designer
# Similar: [('names', np.float32(0.7951)), ('##llness', np.float32(0.7726)), ('existance', np.float32(0.7719))]
# Dissimilar: ('freakishly', np.float32(-0.5183))
#
# Word: wilder
# Similar: [('warp', np.float32(0.6954)), ('joel', np.float32(0.6635)), ('princess', np.float32(0.6561))]
# Dissimilar: ('marriages', np.float32(-0.4238))
#
# Word: number
# Similar: [('couple', np.float32(0.8436)), ('amount', np.float32(0.8425)), ('piece', np.float32(0.8341))]
# Dissimilar: ('hugely', np.float32(-0.6406))
#
# Word: greater
# Similar: [('assuage', np.float32(0.7192)), ('future', np.float32(0.7182)), ('stairs', np.float32(0.7165))]
# Dissimilar: ('latter', np.float32(-0.5848))
#
# Word: per
# Similar: [('kamen', np.float32(0.5657)), ('previous', np.float32(0.5582)), ('video', np.float32(0.5459))]
# Dissimilar: ('him', np.float32(-0.391))
#
# Word: prayer
# Similar: [('anna', np.float32(0.9175)), ('touching', np.float32(0.9002)), ('treatment', np.float32(0.8978))]
# Dissimilar: ('incidents', np.float32(-0.7125))
#
# Word: is
# Similar Words (with Cosine Similarity):
#   wasnt: 0.5350
#   feels: 0.5206
#   hurts: 0.5196
# Dissimilar Word: violence (Cosine Similarity: -0.2859)

# %% [markdown]
# ## Starting Task 3

# %% [markdown]
# ### Loading Vocabulary and Initialize Word2Vec Model

# %%
# Load vocabulary from file
vocab_file_path = "../Data/vocabulary_86.txt"
with open(vocab_file_path, "r", encoding="utf-8") as f:
    vocab = [line.strip() for line in f]  # Read and clean each line

# Create word-to-index and index-to-word mappings for easy lookup
word_to_idx = {word: idx for idx, word in enumerate(vocab)}
idx_to_word = {idx: word for word, idx in word_to_idx.items()}

# Define hyperparameters (embedding dimension must match Task 2 settings)
embedding_dim = 400  

# Initialize and load the pre-trained Word2Vec model
word2vec_model = Word2VecModel(len(vocab))
word2vec_model.load_state_dict(torch.load("word2vec_checkpoint.pth"))
word2vec_model.eval()  # Set model to evaluation mode (no gradient updates)
# Out:
# Word2VecModel(
#   (embedding): Embedding(14000, 400)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=400, out_features=14000, bias=True)
# )

# %% [markdown]
# ### Define Neural Language Model Dataset

# %%
from torch.utils.data import Dataset

class NeuralLMDataset(Dataset):
    """
    Custom Dataset for Neural Language Modeling.
    Converts a tokenized corpus into (context, target) pairs for training.
    """
    def __init__(self, corpus, word_to_idx, context_size=4):
        """
        Args:
            corpus (dict): Tokenized text data from tokenized_data.json
            word_to_idx (dict): Mapping from words to indices
            context_size (int): Number of words used as context for prediction
        """
        self.word_to_idx = word_to_idx
        self.context_size = context_size
        self.data = self.preprocess_data(corpus)

    def preprocess_data(self, corpus):
        """
        Process corpus into training pairs (context, target).
        Only includes words that exist in the vocabulary.
        """
        data = []
        for key in corpus:
            tokens = corpus[key]  # Get tokenized sentence
            for i in range(len(tokens) - self.context_size):
                context = tokens[i:i + self.context_size]  # Extract context window
                target = tokens[i + self.context_size]  # Next word to predict

                # Ensure all words exist in vocabulary before adding to dataset
                if all(word in self.word_to_idx for word in context + [target]):
                    context_indices = [self.word_to_idx[word] for word in context]
                    target_index = self.word_to_idx[target]
                    data.append((context_indices, target_index))
        return data

    def __len__(self):
        """Returns the total number of (context, target) pairs."""
        return len(self.data)

    def __getitem__(self, idx):
        """Fetches a single (context, target) pair as tensors."""
        context, target = self.data[idx]
        return torch.tensor(context, dtype=torch.long), torch.tensor(target, dtype=torch.long)

# %% [markdown]
# ### Define Neural Language Models

# %%
import torch.nn as nn

class NeuralLM1(nn.Module):
    """
    A simple feedforward Neural Language Model with one hidden layer.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=128):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)  # Embedding layer
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)  # Fully connected hidden layer
        self.fc2 = nn.Linear(hidden_dim, vocab_size)  # Output layer

    def forward(self, context):
        """
        Forward pass through the model.
        Args:
            context (Tensor): Input tensor containing word indices
        Returns:
            Tensor: Logits for each word in vocabulary
        """
        embedded = self.embeddings(context).view(context.shape[0], -1)  # Flatten embedding output
        hidden = torch.relu(self.fc1(embedded))  # Apply ReLU activation
        output = self.fc2(hidden)  # Output logits
        return output


class NeuralLM2(nn.Module):
    """
    A deeper Neural Language Model with two hidden layers and dropout for regularization.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=256):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)  # Additional hidden layer
        self.fc3 = nn.Linear(hidden_dim, vocab_size)
        self.dropout = nn.Dropout(0.3)  # Dropout for regularization

    def forward(self, context):
        embedded = self.embeddings(context).view(context.shape[0], -1)
        hidden = torch.relu(self.fc1(embedded))
        hidden = self.dropout(torch.relu(self.fc2(hidden)))  # Apply dropout after activation
        output = self.fc3(hidden)
        return output


class NeuralLM3(nn.Module):
    """
    A more advanced Neural Language Model with batch normalization.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=512):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)  # Batch normalization
        self.fc2 = nn.Linear(hidden_dim, vocab_size)

    def forward(self, context):
        embedded = self.embeddings(context).view(context.shape[0], -1)
        hidden = torch.relu(self.bn1(self.fc1(embedded)))  # Apply batch normalization
        output = self.fc2(hidden)
        return output

# %% [markdown]
# ### Training and Evaluation of Neural Language Models

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import json
import math
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# Load tokenized dataset
with open("../Data/tokenized_data.json", "r", encoding="utf-8") as f:
    corpus = json.load(f)

# Hyperparameters
context_size = 4
embedding_dim = 400
batch_size = 1024
epochs = 45
learning_rate = 0.002
train_ratio = 0.8  # 80% Train, 20% Validation

# Create dataset instance
dataset = NeuralLMDataset(corpus, word_to_idx, context_size)

# Split dataset into training and validation sets
train_size = int(train_ratio * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Training function with validation tracking
def train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    """
    Trains a neural language model and evaluates it on a validation set.

    Args:
        model (nn.Module): Neural Language Model.
        train_loader (DataLoader): Dataloader for training data.
        val_loader (DataLoader): Dataloader for validation data.
        criterion (nn.Module): Loss function (CrossEntropyLoss).
        optimizer (torch.optim): Optimizer (Adam).
        epochs (int): Number of training epochs.

    Returns:
        train_losses (list): Loss values for training set.
        val_losses (list): Loss values for validation set.
    """
    model.train()
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        total_train_loss, total_val_loss = 0, 0

        # Training phase
        for context, target in train_loader:
            context, target = context.long(), target.long()

            optimizer.zero_grad()
            output = model(context)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation phase
        model.eval()
        with torch.no_grad():
            for context, target in val_loader:
                context, target = context.long(), target.long()
                output = model(context)
                loss = criterion(output, target)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

    return train_losses, val_losses

# Initialize models
models = {
    "NeuralLM1": NeuralLM1(len(vocab), embedding_dim, context_size),
    "NeuralLM2": NeuralLM2(len(vocab), embedding_dim, context_size),
    "NeuralLM3": NeuralLM3(len(vocab), embedding_dim, context_size),
}

# Train all models and plot loss curves
plt.figure(figsize=(10, 5))
for name, model in models.items():
    print(f"Training {name}...")
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()
    train_losses, val_losses = train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs)

    # Plot loss curves
    plt.plot(train_losses, label=f"{name} - Train")
    plt.plot(val_losses, linestyle="dashed", label=f"{name} - Val")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Neural LM Training & Validation Loss")
plt.legend()
plt.show()

# Define functions for model evaluation
def compute_accuracy(model, dataloader):
    """
    Computes accuracy of the model on a given dataset.

    Args:
        model (nn.Module): Trained model.
        dataloader (DataLoader): DataLoader containing dataset.

    Returns:
        float: Accuracy of the model.
    """
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for context, target in dataloader:
            context, target = context.long(), target.long()
            output = model(context)
            _, predicted = torch.max(output, dim=1)
            correct += (predicted == target).sum().item()
            total += target.size(0)
    return correct / total

def compute_perplexity(model, dataloader, criterion):
    """
    Computes perplexity of the model on a given dataset.

    Args:
        model (nn.Module): Trained model.
        dataloader (DataLoader): DataLoader containing dataset.
        criterion (nn.Module): Loss function (CrossEntropyLoss).

    Returns:
        float: Perplexity score.
    """
    model.eval()
    total_loss, total_samples = 0, 0
    with torch.no_grad():
        for context, target in dataloader:
            context, target = context.long(), target.long()
            output = model(context)
            loss = criterion(output, target)
            total_loss += loss.item() * target.size(0)
            total_samples += target.size(0)

    avg_loss = total_loss / total_samples
    return math.exp(avg_loss)

# Evaluate models and store metrics
train_accs, val_accs = [], []
train_ppls, val_ppls = [], []

for name, model in models.items():
    print(f"Evaluating {name}...")

    train_acc = compute_accuracy(model, train_loader)
    val_acc = compute_accuracy(model, val_loader)
    
    train_ppl = compute_perplexity(model, train_loader, criterion)
    val_ppl = compute_perplexity(model, val_loader, criterion)

    train_accs.append(train_acc)
    val_accs.append(val_acc)
    train_ppls.append(train_ppl)
    val_ppls.append(val_ppl)

    print(f"{name} - Train Acc: {train_acc * 100:.2f}% | Val Acc: {val_acc * 100:.2f}%")
    print(f"{name} - Train PPL: {train_ppl:.2f} | Val PPL: {val_ppl:.2f}")

# Compute average metrics
avg_train_acc = sum(train_accs) / len(train_accs)
avg_val_acc = sum(val_accs) / len(val_accs)
avg_train_ppl = sum(train_ppls) / len(train_ppls)
avg_val_ppl = sum(val_ppls) / len(val_ppls)

# Print average metrics
print("\n===== Average Metrics Across Models =====")
print(f"Average Train Accuracy: {avg_train_acc * 100:.2f}%")
print(f"Average Validation Accuracy: {avg_val_acc * 100:.2f}%")
print(f"Average Train Perplexity: {avg_train_ppl:.2f}")
print(f"Average Validation Perplexity: {avg_val_ppl:.2f}")
# Out:
# Training NeuralLM1...
# Epoch [1/45] - Train Loss: 7.3031 | Val Loss: 6.2726
# Epoch [2/45] - Train Loss: 5.3460 | Val Loss: 6.0561
# Epoch [3/45] - Train Loss: 4.6329 | Val Loss: 6.0767
# Epoch [4/45] - Train Loss: 3.9977 | Val Loss: 6.3166
# Epoch [5/45] - Train Loss: 3.3143 | Val Loss: 6.7518
# Epoch [6/45] - Train Loss: 2.6337 | Val Loss: 7.2769
# Epoch [7/45] - Train Loss: 2.1018 | Val Loss: 7.6903
# Epoch [8/45] - Train Loss: 1.7047 | Val Loss: 8.0671
# Epoch [9/45] - Train Loss: 1.3985 | Val Loss: 8.4362
# Epoch [10/45] - Train Loss: 1.1570 | Val Loss: 8.7871
# Epoch [11/45] - Train Loss: 0.9500 | Val Loss: 9.0974
# Epoch [12/45] - Train Loss: 0.7929 | Val Loss: 9.4165
# Epoch [13/45] - Train Loss: 0.6617 | Val Loss: 9.7767
# Epoch [14/45] - Train Loss: 0.5563 | Val Loss: 10.0425
# Epoch [15/45] - Train Loss: 0.4735 | Val Loss: 10.3109
# Epoch [16/45] - Train Loss: 0.4116 | Val Loss: 10.5776
# Epoch [17/45] - Train Loss: 0.3606 | Val Loss: 10.8317
# Epoch [18/45] - Train Loss: 0.3230 | Val Loss: 11.0263
# Epoch [19/45] - Train Loss: 0.2934 | Val Loss: 11.2552
# Epoch [20/45] - Train Loss: 0.2670 | Val Loss: 11.4176
# Epoch [21/45] - Train Loss: 0.2464 | Val Loss: 11.5980
# Epoch [22/45] - Train Loss: 0.2413 | Val Loss: 11.7285
# Epoch [23/45] - Train Loss: 0.2234 | Val Loss: 11.8861
# Epoch [24/45] - Train Loss: 0.2154 | Val Loss: 12.0259
# Epoch [25/45] - Train Loss: 0.2098 | Val Loss: 12.1431
# Epoch [26/45] - Train Loss: 0.2046 | Val Loss: 12.2653
# Epoch [27/45] - Train Loss: 0.2004 | Val Loss: 12.3589
# Epoch [28/45] - Train Loss: 0.1973 | Val Loss: 12.4344
# Epoch [29/45] - Train Loss: 0.1932 | Val Loss: 12.5562
# Epoch [30/45] - Train Loss: 0.1896 | Val Loss: 12.6076
# Epoch [31/45] - Train Loss: 0.1825 | Val Loss: 12.7157
# Epoch [32/45] - Train Loss: 0.1835 | Val Loss: 12.7595
# Epoch [33/45] - Train Loss: 0.1836 | Val Loss: 12.8271
# Epoch [34/45] - Train Loss: 0.1826 | Val Loss: 12.8843
# Epoch [35/45] - Train Loss: 0.1771 | Val Loss: 12.9552
# Epoch [36/45] - Train Loss: 0.1761 | Val Loss: 13.0089
# Epoch [37/45] - Train Loss: 0.1731 | Val Loss: 13.0383
# Epoch [38/45] - Train Loss: 0.1726 | Val Loss: 13.0915
# Epoch [39/45] - Train Loss: 0.1692 | Val Loss: 13.1389
# Epoch [40/45] - Train Loss: 0.1705 | Val Loss: 13.2032
# Epoch [41/45] - Train Loss: 0.1717 | Val Loss: 13.2268
# Epoch [42/45] - Train Loss: 0.1697 | Val Loss: 13.2892
# Epoch [43/45] - Train Loss: 0.1689 | Val Loss: 13.3158
# Epoch [44/45] - Train Loss: 0.1743 | Val Loss: 13.3642
# Epoch [45/45] - Train Loss: 0.1677 | Val Loss: 13.3783
# Training NeuralLM2...
# Epoch [1/45] - Train Loss: 7.0568 | Val Loss: 6.2116
# Epoch [2/45] - Train Loss: 5.6246 | Val Loss: 5.9676
# Epoch [3/45] - Train Loss: 4.9727 | Val Loss: 5.9575
# Epoch [4/45] - Train Loss: 4.3328 | Val Loss: 6.2204
# Epoch [5/45] - Train Loss: 3.6160 | Val Loss: 6.7983
# Epoch [6/45] - Train Loss: 2.7584 | Val Loss: 7.8250
# Epoch [7/45] - Train Loss: 1.9626 | Val Loss: 8.7040
# Epoch [8/45] - Train Loss: 1.3679 | Val Loss: 9.4574
# Epoch [9/45] - Train Loss: 0.9514 | Val Loss: 10.3255
# Epoch [10/45] - Train Loss: 0.6584 | Val Loss: 11.0599
# Epoch [11/45] - Train Loss: 0.4635 | Val Loss: 11.7915
# Epoch [12/45] - Train Loss: 0.3554 | Val Loss: 12.2611
# Epoch [13/45] - Train Loss: 0.2935 | Val Loss: 12.6608
# Epoch [14/45] - Train Loss: 0.2569 | Val Loss: 12.9863
# Epoch [15/45] - Train Loss: 0.2383 | Val Loss: 13.2040
# Epoch [16/45] - Train Loss: 0.2226 | Val Loss: 13.2222
# Epoch [17/45] - Train Loss: 0.2082 | Val Loss: 13.3354
# Epoch [18/45] - Train Loss: 0.2073 | Val Loss: 13.4646
# Epoch [19/45] - Train Loss: 0.1966 | Val Loss: 13.5737
# Epoch [20/45] - Train Loss: 0.1918 | Val Loss: 13.6667
# Epoch [21/45] - Train Loss: 0.1904 | Val Loss: 13.7536
# Epoch [22/45] - Train Loss: 0.1833 | Val Loss: 13.7681
# Epoch [23/45] - Train Loss: 0.1805 | Val Loss: 13.7961
# Epoch [24/45] - Train Loss: 0.1772 | Val Loss: 14.0149
# Epoch [25/45] - Train Loss: 0.1721 | Val Loss: 13.9184
# Epoch [26/45] - Train Loss: 0.1719 | Val Loss: 14.0574
# Epoch [27/45] - Train Loss: 0.1652 | Val Loss: 14.0807
# Epoch [28/45] - Train Loss: 0.1620 | Val Loss: 14.2568
# Epoch [29/45] - Train Loss: 0.1611 | Val Loss: 14.2716
# Epoch [30/45] - Train Loss: 0.1598 | Val Loss: 14.1624
# Epoch [31/45] - Train Loss: 0.1532 | Val Loss: 14.3534
# Epoch [32/45] - Train Loss: 0.1546 | Val Loss: 14.2926
# Epoch [33/45] - Train Loss: 0.1524 | Val Loss: 14.4176
# Epoch [34/45] - Train Loss: 0.1515 | Val Loss: 14.6073
# Epoch [35/45] - Train Loss: 0.1489 | Val Loss: 14.6274
# Epoch [36/45] - Train Loss: 0.1484 | Val Loss: 14.6473
# Epoch [37/45] - Train Loss: 0.1468 | Val Loss: 14.6454
# Epoch [38/45] - Train Loss: 0.1408 | Val Loss: 14.8027
# Epoch [39/45] - Train Loss: 0.1418 | Val Loss: 14.9724
# Epoch [40/45] - Train Loss: 0.1435 | Val Loss: 14.8207
# Epoch [41/45] - Train Loss: 0.1437 | Val Loss: 14.8873
# Epoch [42/45] - Train Loss: 0.1400 | Val Loss: 15.1313
# Epoch [43/45] - Train Loss: 0.1362 | Val Loss: 15.0657
# Epoch [44/45] - Train Loss: 0.1354 | Val Loss: 15.1443
# Epoch [45/45] - Train Loss: 0.1373 | Val Loss: 15.1399
# Training NeuralLM3...
# Epoch [1/45] - Train Loss: 6.6709 | Val Loss: 6.1413
# Epoch [2/45] - Train Loss: 4.7776 | Val Loss: 5.9306
# Epoch [3/45] - Train Loss: 3.5962 | Val Loss: 6.3686
# Epoch [4/45] - Train Loss: 2.2669 | Val Loss: 7.2292
# Epoch [5/45] - Train Loss: 1.3639 | Val Loss: 7.8449
# Epoch [6/45] - Train Loss: 0.8378 | Val Loss: 8.4728
# Epoch [7/45] - Train Loss: 0.5419 | Val Loss: 8.9707
# Epoch [8/45] - Train Loss: 0.3828 | Val Loss: 9.3450
# Epoch [9/45] - Train Loss: 0.3074 | Val Loss: 9.5814
# Epoch [10/45] - Train Loss: 0.2661 | Val Loss: 9.7501
# Epoch [11/45] - Train Loss: 0.2412 | Val Loss: 9.9056
# Epoch [12/45] - Train Loss: 0.2323 | Val Loss: 9.9979
# Epoch [13/45] - Train Loss: 0.2227 | Val Loss: 10.0184
# Epoch [14/45] - Train Loss: 0.2072 | Val Loss: 10.1262
# Epoch [15/45] - Train Loss: 0.2116 | Val Loss: 10.1878
# Epoch [16/45] - Train Loss: 0.2111 | Val Loss: 10.1836
# Epoch [17/45] - Train Loss: 0.2025 | Val Loss: 10.3167
# Epoch [18/45] - Train Loss: 0.2000 | Val Loss: 10.3495
# Epoch [19/45] - Train Loss: 0.1943 | Val Loss: 10.3729
# Epoch [20/45] - Train Loss: 0.1940 | Val Loss: 10.4211
# Epoch [21/45] - Train Loss: 0.1897 | Val Loss: 10.5155
# Epoch [22/45] - Train Loss: 0.1847 | Val Loss: 10.4589
# Epoch [23/45] - Train Loss: 0.1812 | Val Loss: 10.4943
# Epoch [24/45] - Train Loss: 0.1825 | Val Loss: 10.5323
# Epoch [25/45] - Train Loss: 0.1786 | Val Loss: 10.5427
# Epoch [26/45] - Train Loss: 0.1719 | Val Loss: 10.5658
# Epoch [27/45] - Train Loss: 0.1711 | Val Loss: 10.6667
# Epoch [28/45] - Train Loss: 0.1695 | Val Loss: 10.6551
# Epoch [29/45] - Train Loss: 0.1649 | Val Loss: 10.7528
# Epoch [30/45] - Train Loss: 0.1643 | Val Loss: 10.7360
# Epoch [31/45] - Train Loss: 0.1644 | Val Loss: 10.7329
# Epoch [32/45] - Train Loss: 0.1585 | Val Loss: 10.7321
# Epoch [33/45] - Train Loss: 0.1579 | Val Loss: 10.7855
# Epoch [34/45] - Train Loss: 0.1547 | Val Loss: 10.8317
# Epoch [35/45] - Train Loss: 0.1519 | Val Loss: 10.9201
# Epoch [36/45] - Train Loss: 0.1510 | Val Loss: 10.8754
# Epoch [37/45] - Train Loss: 0.1506 | Val Loss: 10.9020
# Epoch [38/45] - Train Loss: 0.1489 | Val Loss: 10.9648
# Epoch [39/45] - Train Loss: 0.1487 | Val Loss: 10.9357
# Epoch [40/45] - Train Loss: 0.1453 | Val Loss: 10.9661
# Epoch [41/45] - Train Loss: 0.1474 | Val Loss: 11.0132
# Epoch [42/45] - Train Loss: 0.1457 | Val Loss: 11.0323
# Epoch [43/45] - Train Loss: 0.1410 | Val Loss: 11.0481
# Epoch [44/45] - Train Loss: 0.1408 | Val Loss: 11.0920
# Epoch [45/45] - Train Loss: 0.1382 | Val Loss: 11.0653
# Evaluating NeuralLM1...
# NeuralLM1 - Train Acc: 96.21% | Val Acc: 11.65%
# NeuralLM1 - Train PPL: 1.13 | Val PPL: 645961.17
# Evaluating NeuralLM2...
# NeuralLM2 - Train Acc: 96.31% | Val Acc: 11.84%
# NeuralLM2 - Train PPL: 1.10 | Val PPL: 3751163.53
# Evaluating NeuralLM3...
# NeuralLM3 - Train Acc: 96.34% | Val Acc: 13.47%
# NeuralLM3 - Train PPL: 1.10 | Val PPL: 63946.02
#
# ===== Average Metrics Across Models =====
# Average Train Accuracy: 96.28%
# Average Validation Accuracy: 12.32%
# Average Train Perplexity: 1.11
# Average Validation Perplexity: 1487023.57

# %% [markdown]
# ### Predict Next Tokens

# %%
def predict_next_tokens(model, sentence, word_to_idx, idx_to_word, context_size=4, top_k=1):
    model.eval()
    tokens = sentence.strip().split()  # Simple tokenization (split by space)
    
    # Ensure [UNK] token exists in vocabulary
    unk_token = "[UNK]"
    if unk_token not in word_to_idx:
        print("Warning: [UNK] token is missing from vocabulary!")
        return []
    
    # Ensure the sentence has at least 'context_size' words
    if len(tokens) < context_size:
        print(f"Skipping: '{sentence}' (not enough context words)")
        return []

    # Get the last 'context_size' tokens
    context = tokens[-context_size:]
    
    predicted_words = []
    
    for _ in range(3):  # Predict three tokens
        # Convert words to indices, using [UNK] if word is not found
        context_indices = [word_to_idx.get(word, word_to_idx[unk_token]) for word in context]
        context_tensor = torch.tensor(context_indices, dtype=torch.long).unsqueeze(0)
        
        output = model(context_tensor)  # Get predictions
        
        # Select the top prediction
        predicted_idx = torch.argmax(output, dim=1).item()
        predicted_word = idx_to_word.get(predicted_idx, unk_token)  # Handle missing index

        predicted_words.append(predicted_word)
        context.append(predicted_word)  # Update context with predicted word
        context.pop(0)  # Maintain context size

    return predicted_words

# Load test sentences
test_file = "sample_test.txt"
with open(test_file, "r", encoding="utf-8") as f:
    test_sentences = [line.strip() for line in f]

# Select a trained model (e.g., NeuralLM3 as it's the best-performing one)
best_model = models["NeuralLM1"]

# Make predictions for each sentence
predictions = {}
for sentence in test_sentences:
    predictions[sentence] = predict_next_tokens(best_model, sentence, word_to_idx, idx_to_word)

# Print results
for sentence, predicted in predictions.items():
    print(f"Input: {sentence}")
    print(f"Predicted: {' '.join(predicted)}\n")
# Out:
# Input: i felt like earlier this year i was starting to feel emotional that it
# Predicted: was all over
#
# Input: i do need constant reminders when i go through lulls in feeling submiss
# Predicted: and i feel
#
# Input: i was really feeling crappy even after my awesome
# Predicted: week of workouts
#
# Input: i finally realise the feeling of being hated and its after effects are
# Predicted: a big way
#
# Input: i am feeling unhappy and weird
# Predicted: about many people
