# %%
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import json

def load_mappings():
    vocab_file_path = "../Data/vocabulary_86.txt"

    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = []
        for line in f:
            vocab.append(line.strip())

    word_index_mapping,index_word_mapping = {},{}

    for i, j in enumerate(vocab):
        word_index_mapping[j] = i
    for i, j in word_index_mapping.items():
        index_word_mapping[j] = i


    return word_index_mapping, index_word_mapping

class Word2VecModel(torch.nn.Module):
    def __init__(self, vocab_size, embedding_dim, dropout_rate):
        super().__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Embedding(vocab_size, embedding_dim),
            torch.nn.Linear(embedding_dim, vocab_size)
        )

    def forward(self, context):
        embedded = self.network[0](context).mean(dim=1)
        out = self.network[1](embedded)
        return out
    def get_triplets(self):

        """"
        Will generate 5 random triplets and show the similarities as well
        remember to reound them off
        """
        embeddings = self.network[0].weight.data.cpu().numpy()

        #Reference -> https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html
        cos_similarity_mat = cosine_similarity(embeddings)
        indexes = []
        triplets = []
        for word, index in word_index_mapping.items():
            similar, similar_indices_list = [], []

            similar_indices = np.argsort(cos_similarity_mat[index])[::-1]

            for i in similar_indices:
                if i != index:
                    similar_indices_list.append(i)

            similar_indices = similar_indices_list[:3]

            for i in similar_indices:
                similar.append([index_word_mapping[i], cos_similarity_mat[index][i]])

            dissimilar_index = np.argsort(cos_similarity_mat[index])[0]
            dissimilar = (index_word_mapping[dissimilar_index], cos_similarity_mat[index][dissimilar_index])

            triplet = [word, similar, dissimilar]
            triplets.append(triplet)

        for triplet in triplets:
            print(triplet[0], "\n")
            print("similar words:")
            for i in range(len(triplet[1])):
                print("word: " ,triplet[1][i][0]," ", "with similarity: ", triplet[1][i][1])
            print("Dissimilar:", triplet[2][0], triplet[2][1] , "\n")


def load_model(filepath, vocab_size, embedding_dim, dropout_rate):
    model = Word2VecModel(vocab_size, embedding_dim, dropout_rate)
    model.load_state_dict(torch.load(filepath))
    model.eval()
    return model

def get_triplet_for_word(model, word, word_index_mapping, index_word_mapping):
    if word not in word_index_mapping:
        print(f"{word} not found in vocabulary")
        return

    index_of_word = word_index_mapping[word]
    embeddings = model.network[0].weight.data.cpu().numpy()
    cos_similarity_mat = cosine_similarity(embeddings)

    similar_indices = np.argsort(cos_similarity_mat[index_of_word])[::-1]
    similar = [[index_word_mapping[i], cos_similarity_mat[index_of_word][i]]
               for i in similar_indices if i != index_of_word][:3]

    dissimilar_index = np.argsort(cos_similarity_mat[index_of_word])[0]
    dissimilar = [index_word_mapping[dissimilar_index], cos_similarity_mat[index_of_word][dissimilar_index]]

    print("Similar words:")
    for _ in similar:
        print(f"{_[0]} with similarity {_[1]}")
    print(f"Dissimilar: {dissimilar[0]} with similarity {dissimilar[1]}\n")

if __name__ == "__main__":
    vocab_size = 14000
    embedding_dim = 300
    dropout_rate = 0
    model_path = "word2vec_checkpoint.pth"

    word_index_mapping, index_word_mapping = load_mappings()
    model = load_model(model_path, vocab_size, embedding_dim, dropout_rate)

    model.get_triplets()
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_12904\3204955615.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filepath))
# [PAD]
#
# similar words:
# word:  earning   with similarity:  0.6760272
# word:  pure   with similarity:  0.6417333
# word:  thinner   with similarity:  0.63405806
# Dissimilar: lamb -0.45545483
#
# [UNK]
#
# similar words:
# word:  ##aday   with similarity:  0.21323165
# word:  victi   with similarity:  0.19443172
# word:  riv   with similarity:  0.18993014
# Dissimilar: ##rywh -0.2097566
#
# ##a
#
# similar words:
# word:  transport   with similarity:  0.79665136
# word:  darren   with similarity:  0.77197444
# word:  burn   with similarity:  0.7147912
# Dissimilar: expression -0.45093632
#
# ##b
#
# similar words:
# word:  ##gardl   with similarity:  0.25526077
# word:  fri   with similarity:  0.23432463
# word:  brown   with similarity:  0.1972457
# Dissimilar: khali -0.22845101
#
# ##c
#
# similar words:
# word:  press   with similarity:  0.22496365
# word:  ##caus   with similarity:  0.22254768
# word:  ##aidhai   with similarity:  0.21799582
# Dissimilar: wants -0.22612415
#
# ##d
#
# similar words:
# word:  argument   with similarity:  0.6442915
# word:  percolated   with similarity:  0.59295
# word:  soda   with similarity:  0.5600544
# Dissimilar: wh -0.41340515
#
# ##e
#
# similar words:
# word:  refocus   with similarity:  0.67322445
# word:  nowhere   with similarity:  0.6411915
# word:  send   with similarity:  0.6373228
# Dissimilar: oils -0.39610004
#
# ##f
#
# similar words:
# word:  ##ssibly   with similarity:  0.2172841
# word:  toxin   with similarity:  0.20475571
# word:  ##nging   with similarity:  0.20409724
# Dissimilar: convolute -0.24574988
#
# ##g
#
# similar words:
# word:  s   with similarity:  0.55004895
# word:  chiangmai   with similarity:  0.45280838
# word:  ##at   with similarity:  0.4311968
# Dissimilar: frail -0.2731926
#
# ##h
#
# similar words:
# word:  lord   with similarity:  0.7322728
# word:  flat   with similarity:  0.71360236
# word:  interpreted   with similarity:  0.68474334
# Dissimilar: miss -0.3597207
#
# ##i
#
# similar words:
# word:  soil   with similarity:  0.22895594
# word:  conta   with similarity:  0.22501065
# word:  ##tbrok   with similarity:  0.21977912
# Dissimilar: acro -0.20481499
#
# ##j
#
# similar words:
# word:  ##lix   with similarity:  0.21809705
# word:  ##arin   with similarity:  0.21685834
# word:  ##efl   with similarity:  0.19755962
# Dissimilar: ##enly -0.22765411
#
# ##k
#
# similar words:
# word:  ##dow   with similarity:  0.2564044
# word:  ##vastating   with similarity:  0.18477552
# word:  ##ndblog   with similarity:  0.18310332
# Dissimilar: ##ping -0.20873895
#
# ##l
#
# similar words:
# word:  ##a   with similarity:  0.6661992
# word:  austen   with similarity:  0.6621476
# word:  ##at   with similarity:  0.65394944
# Dissimilar: reilly -0.40037397
#
# ##m
#
# similar words:
# word:  everything   with similarity:  0.22423834
# word:  cous   with similarity:  0.21812828
# word:  fell   with similarity:  0.21743517
# Dissimilar: newrhinegargoyl -0.21887134
#
# ##n
#
# similar words:
# word:  spoilers   with similarity:  0.55325025
# word:  f   with similarity:  0.534365
# word:  cut   with similarity:  0.53138334
# Dissimilar: wh -0.4607979
#
# ##o
#
# similar words:
# word:  ##affic   with similarity:  0.2078947
# word:  resign   with similarity:  0.20476569
# word:  ##ponsibl   with similarity:  0.20185867
# Dissimilar: ##tsuma -0.20780167
#
# ##p
#
# similar words:
# word:  page   with similarity:  0.22290899
# word:  dissatis   with similarity:  0.21632995
# word:  compas   with similarity:  0.21373585
# Dissimilar: ##egion -0.22520237
#
# ##q
#
# similar words:
# word:  ##irport   with similarity:  0.2136309
# word:  ##t   with similarity:  0.202795
# word:  application   with similarity:  0.19913574
# Dissimilar: ##randchi -0.20762292
#
# ##r
#
# similar words:
# word:  carrry   with similarity:  0.62491226
# word:  remain   with similarity:  0.6237879
# word:  poke   with similarity:  0.61028194
# Dissimilar: unhealed -0.52725166
#
# ##s
#
# similar words:
# word:  mermaidhaire   with similarity:  0.5663954
# word:  soda   with similarity:  0.53089267
# word:  jimmys   with similarity:  0.5237147
# Dissimilar: chatter -0.36004433
#
# ##t
#
# similar words:
# word:  ##at   with similarity:  0.6592719
# word:  soda   with similarity:  0.6578512
# word:  ##an   with similarity:  0.6461521
# Dissimilar: wh -0.36596873
#
# ##u
#
# similar words:
# word:  saturd   with similarity:  0.20480764
# word:  ##plac   with similarity:  0.19952774
# word:  record   with similarity:  0.19617887
# Dissimilar: availabl -0.20940581
#
# ##v
#
# similar words:
# word:  earliest   with similarity:  0.23620999
# word:  edit   with similarity:  0.20768465
# word:  ##lancholy   with similarity:  0.19596934
# Dissimilar: ##tory -0.22418082
#
# ##w
#
# similar words:
# word:  positive   with similarity:  0.24600041
# word:  ##asantn   with similarity:  0.23796989
# word:  forward   with similarity:  0.2278709
# Dissimilar: abund -0.19411968
#
# ##x
#
# similar words:
# word:  hype   with similarity:  0.20194253
# word:  ##inancia   with similarity:  0.18619929
# word:  wrest   with similarity:  0.1848687
# Dissimilar: ##eith -0.2070694
#
# ##y
#
# similar words:
# word:  truthful   with similarity:  0.2451925
# word:  convention   with similarity:  0.24503683
# word:  refocus   with similarity:  0.23318575
# Dissimilar: modu -0.21581146
#
# ##z
#
# similar words:
# word:  ##amworl   with similarity:  0.24103498
# word:  cance   with similarity:  0.18987684
# word:  heartle   with similarity:  0.18693858
# Dissimilar: consta -0.25103116
#
# a
#
# similar words:
# word:  mooshilu   with similarity:  0.60232884
# word:  rylin   with similarity:  0.51315355
# word:  shove   with similarity:  0.51247066
# Dissimilar: amish -0.40245354
#
# b
#
# similar words:
# word:  took   with similarity:  0.60765785
# word:  feefyefo   with similarity:  0.57426417
# word:  indicated   with similarity:  0.5420784
# Dissimilar: appropriately -0.52492964
#
# c
#
# similar words:
# word:  mixed   with similarity:  0.68035096
# word:  redeem   with similarity:  0.5743449
# word:  guy   with similarity:  0.57184875
# Dissimilar: expression -0.41942704
#
# d
#
# similar words:
# word:  present   with similarity:  0.43113026
# word:  mereka   with similarity:  0.4288128
# word:  di   with similarity:  0.4230416
# Dissimilar: ntoward -0.2866642
#
# e
#
# similar words:
# word:  owl   with similarity:  0.6228041
# word:  ##ts   with similarity:  0.53297114
# word:  of   with similarity:  0.45765707
# Dissimilar: advent -0.4198327
#
# f
#
# similar words:
# word:  won   with similarity:  0.69920075
# word:  habitual   with similarity:  0.6623987
# word:  emptied   with similarity:  0.60476893
# Dissimilar: feefyefo -0.3564468
#
# g
#
# similar words:
# word:  jubila   with similarity:  0.21538574
# word:  ##talin   with similarity:  0.20456398
# word:  ##nack   with similarity:  0.20430064
# Dissimilar: ##efit -0.22055641
#
# h
#
# similar words:
# word:  happi   with similarity:  0.22693014
# word:  grandmother   with similarity:  0.20853674
# word:  ##sonat   with similarity:  0.20542243
# Dissimilar: tempe -0.25855008
#
# i
#
# similar words:
# word:  zimmerman   with similarity:  0.59857357
# word:  happpy   with similarity:  0.5948539
# word:  obrian   with similarity:  0.58727235
# Dissimilar: count -0.5261501
#
# j
#
# similar words:
# word:  cards   with similarity:  0.54809326
# word:  nourished   with similarity:  0.5438476
# word:  argument   with similarity:  0.5407793
# Dissimilar: aversion -0.40305182
#
# k
#
# similar words:
# word:  deserve   with similarity:  0.22447003
# word:  tampon   with similarity:  0.21852632
# word:  kne   with similarity:  0.19852981
# Dissimilar: poi -0.22267891
#
# l
#
# similar words:
# word:  flaw   with similarity:  0.23977537
# word:  ##rcolat   with similarity:  0.22934845
# word:  text   with similarity:  0.22742447
# Dissimilar: ##ssibl -0.20333657
#
# m
#
# similar words:
# word:  peep   with similarity:  0.64736253
# word:  shorts   with similarity:  0.58502585
# word:  rid   with similarity:  0.5804303
# Dissimilar: wh -0.46892688
#
# n
#
# similar words:
# word:  lyman   with similarity:  0.75055134
# word:  soda   with similarity:  0.7415116
# word:  ow   with similarity:  0.6750358
# Dissimilar: expression -0.48227265
#
# o
#
# similar words:
# word:  shamed   with similarity:  0.46245396
# word:  slutty   with similarity:  0.36281097
# word:  moreso   with similarity:  0.35934758
# Dissimilar: writin -0.45312527
#
# p
#
# similar words:
# word:  photos   with similarity:  0.77612245
# word:  soda   with similarity:  0.7345773
# word:  list   with similarity:  0.72837424
# Dissimilar: wh -0.617183
#
# q
#
# similar words:
# word:  dubstep   with similarity:  0.6790735
# word:  hubby   with similarity:  0.64917284
# word:  succumb   with similarity:  0.62446475
# Dissimilar: fuzzy -0.41814277
#
# r
#
# similar words:
# word:  soda   with similarity:  0.67247564
# word:  n   with similarity:  0.6491525
# word:  impressive   with similarity:  0.61715347
# Dissimilar: sony -0.38135302
#
# s
#
# similar words:
# word:  forced   with similarity:  0.6156303
# word:  soda   with similarity:  0.5755537
# word:  peep   with similarity:  0.5714846
# Dissimilar: wh -0.55051655
#
# t
#
# similar words:
# word:  problemn   with similarity:  0.5475263
# word:  folk   with similarity:  0.5213718
# word:  paraphrase   with similarity:  0.4905651
# Dissimilar: iya -0.33565205
#
# u
#
# similar words:
# word:  alexander   with similarity:  0.5705467
# word:  grandmother   with similarity:  0.5560137
# word:  i   with similarity:  0.53190583
# Dissimilar: pills -0.44692054
#
# v
#
# similar words:
# word:  flushe   with similarity:  0.20397764
# word:  limite   with similarity:  0.18971713
# word:  constru   with similarity:  0.18621348
# Dissimilar: pag -0.20757687
#
# w
#
# similar words:
# word:  ##act   with similarity:  0.23000766
# word:  ##truction   with similarity:  0.2019184
# word:  brid   with similarity:  0.20086896
# Dissimilar: spazzol -0.23404896
#
# x
#
# similar words:
# word:  dramas   with similarity:  0.5141169
# word:  wailing   with similarity:  0.48399732
# word:  continuous   with similarity:  0.4719234
# Dissimilar: keep -0.37536463
#
# y
#
# similar words:
# word:  ##evel   with similarity:  0.21684803
# word:  insulting   with similarity:  0.20949276
# word:  how   with similarity:  0.20073935
# Dissimilar: ##magin -0.2128795
#
# z
#
# similar words:
# word:  stayviolation   with similarity:  0.75892913
# word:  thaim   with similarity:  0.7504531
# word:  tartandheathered   with similarity:  0.74537975
# Dissimilar: stock -0.33625433
#
# ex
#
# similar words:
# word:  opening   with similarity:  0.212875
# word:  pakis   with similarity:  0.2090511
# word:  ##stat   with similarity:  0.20465414
# Dissimilar: croi -0.22236174
#
# xx
#
# similar words:
# word:  xelliealicex   with similarity:  0.7529645
# word:  oils   with similarity:  0.64153963
# word:  peak   with similarity:  0.51162046
# Dissimilar: gotten -0.43240917
#
# ##zz
#
# similar words:
# word:  spac   with similarity:  0.21840574
# word:  ##atl   with similarity:  0.20979461
# word:  device   with similarity:  0.2012336
# Dissimilar: ##rkou -0.22239955
#
# ##qu
#
# similar words:
# word:  dia   with similarity:  0.24963355
# word:  strayed   with similarity:  0.21641219
# word:  references   with similarity:  0.20298435
# Dissimilar: cate -0.22044767
#
# bq
#
# similar words:
# word:  ##tuition   with similarity:  0.22418824
# word:  resp   with similarity:  0.21415976
# word:  ##no   with similarity:  0.18884873
# Dissimilar: cruz -0.24136432
#
# bqf
#
# similar words:
# word:  ##ana   with similarity:  0.22943941
# word:  flash   with similarity:  0.2271484
# word:  ##emands   with similarity:  0.20215362
# Dissimilar: ##timat -0.19007815
#
# bqff
#
# similar words:
# word:  makeup   with similarity:  0.85544825
# word:  mission   with similarity:  0.84958684
# word:  artwork   with similarity:  0.7837047
# Dissimilar: expression -0.572856
#
# qu
#
# similar words:
# word:  imbib   with similarity:  0.20231175
# word:  imprint   with similarity:  0.20134215
# word:  ##cro   with similarity:  0.19135247
# Dissimilar: ##riticiz -0.23110463
#
# of
#
# similar words:
# word:  wonderfully   with similarity:  0.51331604
# word:  aout   with similarity:  0.48077548
# word:  hedge   with similarity:  0.48025993
# Dissimilar: oblige -0.3297816
#
# ev
#
# similar words:
# word:  lonelin   with similarity:  0.19047712
# word:  ##stal   with similarity:  0.18964276
# word:  ##nbai   with similarity:  0.18659061
# Dissimilar: insinc -0.21862005
#
# equ
#
# similar words:
# word:  equall   with similarity:  0.2095402
# word:  unchara   with similarity:  0.2013898
# word:  marv   with similarity:  0.19666164
# Dissimilar: honkerblonke -0.22290906
#
# exp
#
# similar words:
# word:  cinna   with similarity:  0.21791753
# word:  ##urth   with similarity:  0.20159696
# word:  ##rook   with similarity:  0.18955179
# Dissimilar: straight -0.20721711
#
# up
#
# similar words:
# word:  grass   with similarity:  0.39920422
# word:  motors   with similarity:  0.39357382
# word:  sentinel   with similarity:  0.32300907
# Dissimilar: who -0.2557985
#
# ju
#
# similar words:
# word:  pia   with similarity:  0.21179035
# word:  ##oppy   with similarity:  0.211488
# word:  ##mmak   with similarity:  0.2096479
# Dissimilar: ##nvincibl -0.21327728
#
# ##bj
#
# similar words:
# word:  ##vert   with similarity:  0.21842009
# word:  portraya   with similarity:  0.20892255
# word:  entir   with similarity:  0.195305
# Dissimilar: pronounce -0.21892567
#
# ##ubj
#
# similar words:
# word:  ##eeth   with similarity:  0.20004898
# word:  ##rdag   with similarity:  0.19618313
# word:  ##rican   with similarity:  0.19526789
# Dissimilar: ##rrowing -0.20990753
#
# obj
#
# similar words:
# word:  intimated   with similarity:  0.23751289
# word:  wond   with similarity:  0.21570146
# word:  ##iwa   with similarity:  0.20478275
# Dissimilar: key -0.24436496
#
# subj
#
# similar words:
# word:  bondmus   with similarity:  0.2635666
# word:  ##ritiona   with similarity:  0.21046996
# word:  ##fum   with similarity:  0.20975247
# Dissimilar: ##ereby -0.18938239
#
# jus
#
# similar words:
# word:  audience   with similarity:  0.22851884
# word:  strange   with similarity:  0.21601443
# word:  ##aut   with similarity:  0.21175814
# Dissimilar: roslin -0.21017069
#
# jum
#
# similar words:
# word:  estrangeme   with similarity:  0.21370926
# word:  minuscul   with similarity:  0.21140912
# word:  ##uck   with similarity:  0.20510289
# Dissimilar: engi -0.23788656
#
# jump
#
# similar words:
# word:  perform   with similarity:  0.8121963
# word:  greet   with similarity:  0.80741686
# word:  exercised   with similarity:  0.7844603
# Dissimilar: expression -0.59662807
#
# jumb
#
# similar words:
# word:  ##org   with similarity:  0.22310579
# word:  ##rtur   with similarity:  0.20809793
# word:  ##rity   with similarity:  0.1939119
# Dissimilar: unfit -0.20726432
#
# exc
#
# similar words:
# word:  gaming   with similarity:  0.23078828
# word:  recent   with similarity:  0.22456041
# word:  video   with similarity:  0.20355175
# Dissimilar: pisse -0.214158
#
# ##zzy
#
# similar words:
# word:  ##rations   with similarity:  0.27251312
# word:  list   with similarity:  0.26091835
# word:  call   with similarity:  0.23874158
# Dissimilar: mellow -0.21871065
#
# jub
#
# similar words:
# word:  heat   with similarity:  0.20514192
# word:  ##tially   with similarity:  0.20378642
# word:  regret   with similarity:  0.20264804
# Dissimilar: ##cativ -0.20332031
#
# jumbl
#
# similar words:
# word:  prepost   with similarity:  0.23992306
# word:  ##ning   with similarity:  0.23387544
# word:  ##roying   with similarity:  0.21822055
# Dissimilar: system -0.25032002
#
# ##uzz
#
# similar words:
# word:  investm   with similarity:  0.20525211
# word:  volu   with similarity:  0.20033848
# word:  ema   with similarity:  0.20004001
# Dissimilar: outb -0.21343882
#
# puzz
#
# similar words:
# word:  ##sant   with similarity:  0.24391828
# word:  ##stil   with similarity:  0.23693885
# word:  reaction   with similarity:  0.22646323
# Dissimilar: pate -0.24343517
#
# puzzl
#
# similar words:
# word:  ##riz   with similarity:  0.19777308
# word:  ##urkish   with similarity:  0.18926075
# word:  ##ticu   with similarity:  0.18707496
# Dissimilar: ##rwards -0.25342748
#
# equa
#
# similar words:
# word:  ##ndence   with similarity:  0.20712218
# word:  ##latonic   with similarity:  0.20404573
# word:  hypocr   with similarity:  0.1904774
# Dissimilar: planne -0.26967993
#
# jubi
#
# similar words:
# word:  ##eaffirm   with similarity:  0.2029541
# word:  ##eemingly   with similarity:  0.20200263
# word:  startl   with similarity:  0.19896047
# Dissimilar: various -0.21508467
#
# jubil
#
# similar words:
# word:  drink   with similarity:  0.23610507
# word:  laurie   with similarity:  0.23534182
# word:  chills   with similarity:  0.21861686
# Dissimilar: freaking -0.23964752
#
# jubila
#
# similar words:
# word:  learns   with similarity:  0.22274137
# word:  obvious   with similarity:  0.21950167
# word:  g   with similarity:  0.21538574
# Dissimilar: jou -0.22309127
#
# just
#
# similar words:
# word:  cuz   with similarity:  0.36558786
# word:  definitely   with similarity:  0.36210144
# word:  however   with similarity:  0.35848647
# Dissimilar: independence -0.27735224
#
# ##uzzy
#
# similar words:
# word:  trying   with similarity:  0.25049034
# word:  ##parat   with similarity:  0.23657827
# word:  lup   with similarity:  0.21303044
# Dissimilar: hogma -0.217979
#
# buzzy
#
# similar words:
# word:  iced   with similarity:  0.74239326
# word:  greatness   with similarity:  0.732262
# word:  workouts   with similarity:  0.72797865
# Dissimilar: minor -0.3863569
#
# fuzzy
#
# similar words:
# word:  unhealed   with similarity:  0.54208076
# word:  cynical   with similarity:  0.46407852
# word:  underneath   with similarity:  0.42619494
# Dissimilar: show -0.5531021
#
# ##izzy
#
# similar words:
# word:  equat   with similarity:  0.23069637
# word:  ##rsuad   with similarity:  0.21435027
# word:  ##sua   with similarity:  0.21277696
# Dissimilar: ##noo -0.22401951
#
# dizzy
#
# similar words:
# word:  lightheaded   with similarity:  0.7429391
# word:  received   with similarity:  0.7289304
# word:  obstacles   with similarity:  0.7210785
# Dissimilar: hath -0.48418522
#
# lizzy
#
# similar words:
# word:  ##sh   with similarity:  0.8316931
# word:  brought   with similarity:  0.77720374
# word:  washing   with similarity:  0.68931717
# Dissimilar: expression -0.5168448
#
# xb
#
# similar words:
# word:  ##eeeeeeeeally   with similarity:  0.19281468
# word:  ##sion   with similarity:  0.19163579
# word:  jaded   with similarity:  0.18917131
# Dissimilar: ##fway -0.21068941
#
# xbl
#
# similar words:
# word:  day   with similarity:  0.20214497
# word:  lupron   with similarity:  0.20194302
# word:  zooming   with similarity:  0.20150615
# Dissimilar: protectiv -0.23561612
#
# xbla
#
# similar words:
# word:  appeared   with similarity:  0.6768723
# word:  display   with similarity:  0.60971284
# word:  craisins   with similarity:  0.5921166
# Dissimilar: fuzzy -0.3982256
#
# th
#
# similar words:
# word:  crutches   with similarity:  0.8007286
# word:  hgtv   with similarity:  0.7564837
# word:  belittled   with similarity:  0.7319211
# Dissimilar: aversion -0.49690112
#
# jubilan
#
# similar words:
# word:  ##sign   with similarity:  0.24274454
# word:  tum   with similarity:  0.18493402
# word:  ##xually   with similarity:  0.18103696
# Dissimilar: promis -0.2221479
#
# jubilant
#
# similar words:
# word:  hyper   with similarity:  0.96515924
# word:  admiration   with similarity:  0.8806553
# word:  swirling   with similarity:  0.8757215
# Dissimilar: expression -0.5983298
#
# my
#
# similar words:
# word:  smooth   with similarity:  0.5925689
# word:  plants   with similarity:  0.48479405
# word:  your   with similarity:  0.4712182
# Dissimilar: shred -0.34900188
#
# ov
#
# similar words:
# word:  ##gious   with similarity:  0.2535655
# word:  intellig   with similarity:  0.21699812
# word:  mensa   with similarity:  0.20041296
# Dissimilar: snap -0.21724191
#
# ##pp
#
# similar words:
# word:  ##eacting   with similarity:  0.23128428
# word:  cubicle   with similarity:  0.22133017
# word:  thigh   with similarity:  0.21971984
# Dissimilar: gotta -0.22023326
#
# qui
#
# similar words:
# word:  ##ality   with similarity:  0.20879044
# word:  contribu   with similarity:  0.20484091
# word:  cauti   with similarity:  0.19489619
# Dissimilar: difference -0.20969027
#
# wh
#
# similar words:
# word:  initiation   with similarity:  0.71731275
# word:  ridiculously   with similarity:  0.57551026
# word:  inherent   with similarity:  0.5636534
# Dissimilar: peep -0.65204525
#
# quit
#
# similar words:
# word:  ini   with similarity:  0.8504532
# word:  held   with similarity:  0.8502722
# word:  indicated   with similarity:  0.84157354
# Dissimilar: aversion -0.5448425
#
# quic
#
# similar words:
# word:  outcom   with similarity:  0.20789044
# word:  em   with similarity:  0.20489115
# word:  ##di   with similarity:  0.20376386
# Dissimilar: writers -0.23232655
#
# quick
#
# similar words:
# word:  worr   with similarity:  0.20669527
# word:  busine   with similarity:  0.19335456
# word:  ##upp   with similarity:  0.18810254
# Dissimilar: ##ngr -0.21079753
#
# quickl
#
# similar words:
# word:  walls   with similarity:  0.21337688
# word:  surrounded   with similarity:  0.21169893
# word:  victi   with similarity:  0.20466508
# Dissimilar: hell -0.20189005
#
# quickly
#
# similar words:
# word:  evident   with similarity:  0.67731446
# word:  touristy   with similarity:  0.6225041
# word:  lucky   with similarity:  0.58942145
# Dissimilar: everytime -0.43461585
#
# quiv
#
# similar words:
# word:  sarcastic   with similarity:  0.22852416
# word:  ##ation   with similarity:  0.19802873
# word:  ##duling   with similarity:  0.19655497
# Dissimilar: ru -0.2387806
#
# ##azz
#
# similar words:
# word:  notic   with similarity:  0.23326725
# word:  abo   with similarity:  0.23126784
# word:  ##itish   with similarity:  0.20788117
# Dissimilar: ##xist -0.214456
#
# dazz
#
# similar words:
# word:  rem   with similarity:  0.21789335
# word:  ##tanding   with similarity:  0.19758368
# word:  cav   with similarity:  0.1963876
# Dissimilar: ##nstinctiv -0.2275799
#
# ##pazz
#
# similar words:
# word:  ##djust   with similarity:  0.2169131
# word:  ##mark   with similarity:  0.21011297
# word:  gui   with similarity:  0.20823132
# Dissimilar: writt -0.2086855
#
# spazz
#
# similar words:
# word:  dorm   with similarity:  0.22811063
# word:  pleasures   with similarity:  0.22451057
# word:  determined   with similarity:  0.21146928
# Dissimilar: oc -0.22417173
#
# dazzl
#
# similar words:
# word:  prese   with similarity:  0.2000617
# word:  ##aving   with similarity:  0.1981727
# word:  ##erc   with similarity:  0.1953328
# Dissimilar: ##encumb -0.20554814
#
# dazzli
#
# similar words:
# word:  ##cip   with similarity:  0.21913095
# word:  betraye   with similarity:  0.20201759
# word:  fangi   with similarity:  0.20179921
# Dissimilar: surrounded -0.23439623
#
# ##izz
#
# similar words:
# word:  ##oup   with similarity:  0.21946509
# word:  china   with similarity:  0.21398757
# word:  nighters   with similarity:  0.21209304
# Dissimilar: ##nistration -0.21004309
#
# ##rizz
#
# similar words:
# word:  volunte   with similarity:  0.23324811
# word:  ##nience   with similarity:  0.21831796
# word:  american   with similarity:  0.21440995
# Dissimilar: ##am -0.2176907
#
# frizz
#
# similar words:
# word:  aoi   with similarity:  0.88014704
# word:  inarticulate   with similarity:  0.866851
# word:  laughable   with similarity:  0.8596097
# Dissimilar: unhealed -0.3615881
#
# spazzo
#
# similar words:
# word:  dazzlin   with similarity:  0.21595144
# word:  cousi   with similarity:  0.20402138
# word:  lauren   with similarity:  0.20089193
# Dissimilar: thri -0.2227117
#
# spazzol
#
# similar words:
# word:  prick   with similarity:  0.23396657
# word:  canvas   with similarity:  0.2195262
# word:  gradually   with similarity:  0.21754244
# Dissimilar: w -0.23404896
#
# spazzola
#
# similar words:
# word:  prima   with similarity:  0.5908645
# word:  beside   with similarity:  0.587294
# word:  ##e   with similarity:  0.58065593
# Dissimilar: potentially -0.46240035
#
# dazzlin
#
# similar words:
# word:  zoo   with similarity:  0.22465879
# word:  spazzo   with similarity:  0.21595144
# word:  clar   with similarity:  0.20250095
# Dissimilar: witn -0.2060912
#
# dazzling
#
# similar words:
# word:  cert   with similarity:  0.7741265
# word:  sigil   with similarity:  0.6817448
# word:  littered   with similarity:  0.67993534
# Dissimilar: unconsciously -0.43564665
#
# ##az
#
# similar words:
# word:  remembe   with similarity:  0.22814406
# word:  ##dication   with similarity:  0.20934914
# word:  sani   with similarity:  0.20613644
# Dissimilar: ##rally -0.23076056
#
# ##maz
#
# similar words:
# word:  equals   with similarity:  0.21163706
# word:  ##edical   with similarity:  0.21038352
# word:  ##estl   with similarity:  0.20181298
# Dissimilar: coz -0.22505794
#
# daz
#
# similar words:
# word:  enthusi   with similarity:  0.20544262
# word:  wimp   with similarity:  0.20471571
# word:  ##sts   with similarity:  0.2037189
# Dissimilar: evolv -0.22577514
#
# ##azy
#
# similar words:
# word:  ##rfum   with similarity:  0.1956315
# word:  ##lls   with similarity:  0.19461334
# word:  ripp   with similarity:  0.19160965
# Dissimilar: ballis -0.22531794
#
# lazy
#
# similar words:
# word:  snob   with similarity:  0.71411335
# word:  hopeless   with similarity:  0.7092601
# word:  sip   with similarity:  0.7037906
# Dissimilar: accept -0.45334244
#
# gaz
#
# similar words:
# word:  steady   with similarity:  0.21305376
# word:  ling   with similarity:  0.2103368
# word:  ##gac   with similarity:  0.20473988
# Dissimilar: ##tand -0.23917885
#
# maz
#
# similar words:
# word:  enthusia   with similarity:  0.21256913
# word:  ##diocy   with similarity:  0.20851904
# word:  conditi   with similarity:  0.20577492
# Dissimilar: light -0.20120537
#
# haz
#
# similar words:
# word:  ##atonic   with similarity:  0.21760853
# word:  reshape   with similarity:  0.21703385
# word:  ##agon   with similarity:  0.20980652
# Dissimilar: wheth -0.22298768
#
# ##gaz
#
# similar words:
# word:  ##llarium   with similarity:  0.27668586
# word:  ##esentful   with similarity:  0.22057796
# word:  savag   with similarity:  0.2081811
# Dissimilar: awhil -0.20692855
#
# amaz
#
# similar words:
# word:  ##sby   with similarity:  0.21811463
# word:  ##niga   with similarity:  0.20818695
# word:  ##rsion   with similarity:  0.19235976
# Dissimilar: ##nsity -0.23355138
#
# ##razy
#
# similar words:
# word:  ##cour   with similarity:  0.22590606
# word:  lawy   with similarity:  0.21171118
# word:  scho   with similarity:  0.20340008
# Dissimilar: ##uthful -0.20601669
#
# crazy
#
# similar words:
# word:  songs   with similarity:  0.61808026
# word:  soft   with similarity:  0.6106698
# word:  approve   with similarity:  0.5951447
# Dissimilar: tastes -0.39956844
#
# ##agaz
#
# similar words:
# word:  opposi   with similarity:  0.2285319
# word:  reaffirm   with similarity:  0.19455484
# word:  reliev   with similarity:  0.19318558
# Dissimilar: afa -0.23551562
#
# magaz
#
# similar words:
# word:  ube   with similarity:  0.23726848
# word:  zero   with similarity:  0.22314201
# word:  directions   with similarity:  0.21437305
# Dissimilar: ##ima -0.2308784
#
# magazi
#
# similar words:
# word:  ##mu   with similarity:  0.22610776
# word:  cocktail   with similarity:  0.19944368
# word:  lib   with similarity:  0.19413349
# Dissimilar: ##emipro -0.25890177
#
# magazin
#
# similar words:
# word:  lat   with similarity:  0.23461874
# word:  growl   with similarity:  0.21732394
# word:  besid   with similarity:  0.21446204
# Dissimilar: ##ecollection -0.21876717
#
# ##iz
#
# similar words:
# word:  escap   with similarity:  0.21528065
# word:  constructions   with similarity:  0.2128864
# word:  thi   with similarity:  0.20571548
# Dissimilar: epis -0.1986267
#
# ab
#
# similar words:
# word:  christch   with similarity:  0.24004468
# word:  crosswo   with similarity:  0.2071486
# word:  exit   with similarity:  0.20034161
# Dissimilar: ##chologica -0.21547441
#
# abo
#
# similar words:
# word:  suppo   with similarity:  0.23612069
# word:  ##azz   with similarity:  0.23126784
# word:  inherent   with similarity:  0.2285791
# Dissimilar: piece -0.24971235
#
# abou
#
# similar words:
# word:  cudd   with similarity:  0.20934865
# word:  appricia   with similarity:  0.19999078
# word:  ##formation   with similarity:  0.19490576
# Dissimilar: ##dul -0.21409288
#
# abov
#
# similar words:
# word:  ##aw   with similarity:  0.22408368
# word:  ##mpathizing   with similarity:  0.2072068
# word:  ##nmak   with similarity:  0.19600758
# Dissimilar: ##epths -0.21419562
#
# about
#
# similar words:
# word:  progressive   with similarity:  0.51190466
# word:  involves   with similarity:  0.48589426
# word:  calorie   with similarity:  0.4782164
# Dissimilar: vicious -0.23804924
#
# aboun
#
# similar words:
# word:  exclusive   with similarity:  0.1994176
# word:  declin   with similarity:  0.18979488
# word:  ##ttitud   with similarity:  0.18635872
# Dissimilar: polyvor -0.20430708
#
# abound
#
# similar words:
# word:  succumb   with similarity:  0.85341996
# word:  cave   with similarity:  0.85104257
# word:  labels   with similarity:  0.8470408
# Dissimilar: aversion -0.59615695
#
# ##upp
#
# similar words:
# word:  ambie   with similarity:  0.206169
# word:  ##nerations   with similarity:  0.20599501
# word:  surge   with similarity:  0.20270045
# Dissimilar: ##ver -0.24101524
#
# supp
#
# similar words:
# word:  vibrat   with similarity:  0.23735072
# word:  cambodi   with similarity:  0.22833298
# word:  khal   with similarity:  0.2015236
# Dissimilar: ##eds -0.19394445
#
# pupp
#
# similar words:
# word:  fuchs   with similarity:  0.20225568
# word:  ##itiation   with similarity:  0.20056319
# word:  ##calculabl   with similarity:  0.19260225
# Dissimilar: ##ndor -0.19610046
#
# puppy
#
# similar words:
# word:  serving   with similarity:  0.69059396
# word:  rightly   with similarity:  0.63119507
# word:  unusually   with similarity:  0.6067041
# Dissimilar: exhibitions -0.418042
#
# suppo
#
# similar words:
# word:  abo   with similarity:  0.23612069
# word:  tary   with similarity:  0.21265525
# word:  listle   with similarity:  0.19746903
# Dissimilar: unprepar -0.23981537
#
# suppor
#
# similar words:
# word:  ##dical   with similarity:  0.250951
# word:  eas   with similarity:  0.19778927
# word:  ##ckish   with similarity:  0.19507226
# Dissimilar: ##onour -0.24494429
#
# suppos
#
# similar words:
# word:  remembranc   with similarity:  0.23999158
# word:  ##nori   with similarity:  0.21516417
# word:  propose   with similarity:  0.21032278
# Dissimilar: nonsense -0.2350559
#
# support
#
# similar words:
# word:  trauma   with similarity:  0.62368214
# word:  ways   with similarity:  0.6025223
# word:  prep   with similarity:  0.6024014
# Dissimilar: unhealed -0.47478724
#
# ##ppy
#
# similar words:
# word:  traditionalist   with similarity:  0.21817896
# word:  fleece   with similarity:  0.18185729
# word:  broth   with similarity:  0.18069728
# Dissimilar: outb -0.22130191
#
# ##appy
#
# similar words:
# word:  ##tur   with similarity:  0.21031393
# word:  appropriately   with similarity:  0.20194322
# word:  disappoi   with similarity:  0.19789325
# Dissimilar: catapul -0.19905834
#
# happy
#
# similar words:
# word:  yourself   with similarity:  0.70900387
# word:  honoured   with similarity:  0.7033295
# word:  ashamed   with similarity:  0.68675506
# Dissimilar: expression -0.49426216
#
# ##happy
#
# similar words:
# word:  applicatio   with similarity:  0.22508788
# word:  ##ttymuch   with similarity:  0.20688999
# word:  underwe   with similarity:  0.20513171
# Dissimilar: compensat -0.19724332
#
# ##rappy
#
# similar words:
# word:  ##vitation   with similarity:  0.20683396
# word:  ##ainstakingly   with similarity:  0.19597836
# word:  drake   with similarity:  0.19221711
# Dissimilar: light -0.21883726
#
# crappy
#
# similar words:
# word:  sentimental   with similarity:  0.81008536
# word:  roof   with similarity:  0.7819915
# word:  wimpy   with similarity:  0.78194106
# Dissimilar: unhealed -0.46400496
#
# opp
#
# similar words:
# word:  ##ticip   with similarity:  0.22041915
# word:  ##eeds   with similarity:  0.2043466
# word:  san   with similarity:  0.19717349
# Dissimilar: apprici -0.2415042
#
# ##nhappy
#
# similar words:
# word:  ##ama   with similarity:  0.22004345
# word:  ##mplish   with similarity:  0.20456778
# word:  tast   with similarity:  0.20400035
# Dissimilar: ##onship -0.22381839
#
# unhappy
#
# similar words:
# word:  distressed   with similarity:  0.72299904
# word:  stunned   with similarity:  0.7180314
# word:  depressed   with similarity:  0.7135065
# Dissimilar: unhealed -0.59303933
#
# oppo
#
# similar words:
# word:  ##nymor   with similarity:  0.23085688
# word:  int   with similarity:  0.21278791
# word:  manne   with similarity:  0.1972228
# Dissimilar: ##lashing -0.20187558
#
# oppr
#
# similar words:
# word:  ##picious   with similarity:  0.24748495
# word:  prolong   with similarity:  0.2042145
# word:  ##nbows   with similarity:  0.19295818
# Dissimilar: really -0.21474512
#
# oppor
#
# similar words:
# word:  discour   with similarity:  0.22446263
# word:  ##ensiv   with similarity:  0.18545647
# word:  complication   with similarity:  0.18462887
# Dissimilar: ##magination -0.19657293
#
# oppos
#
# similar words:
# word:  ##ticipa   with similarity:  0.23328552
# word:  attractiv   with similarity:  0.22316986
# word:  ##w   with similarity:  0.20384884
# Dissimilar: stoned -0.2014482
#
# opport
#
# similar words:
# word:  conservative   with similarity:  0.23334852
# word:  those   with similarity:  0.23241162
# word:  occupat   with similarity:  0.2094051
# Dissimilar: ##ailormoon -0.23759139
#
# opportu
#
# similar words:
# word:  ##ntact   with similarity:  0.21717906
# word:  ##morrow   with similarity:  0.20308654
# word:  maje   with similarity:  0.2015292
# Dissimilar: bante -0.20421557
#
# opportun
#
# similar words:
# word:  authorities   with similarity:  0.22801636
# word:  dubl   with similarity:  0.22657967
# word:  violence   with similarity:  0.20214419
# Dissimilar: fruit -0.21404754
#
# opportuni
#
# similar words:
# word:  pav   with similarity:  0.19188027
# word:  girlf   with similarity:  0.19102348
# word:  jok   with similarity:  0.18444051
# Dissimilar: epis -0.23351595
#
# opportunit
#
# similar words:
# word:  laur   with similarity:  0.23407978
# word:  laptop   with similarity:  0.22951248
# word:  profi   with similarity:  0.22283727
# Dissimilar: socia -0.22590196
#
# opportunity
#
# similar words:
# word:  led   with similarity:  0.69039595
# word:  module   with similarity:  0.6768894
# word:  exicting   with similarity:  0.6515271
# Dissimilar: unhealed -0.476737
#
# opposi
#
# similar words:
# word:  ##agaz   with similarity:  0.2285319
# word:  quirky   with similarity:  0.20844099
# word:  effort   with similarity:  0.20628901
# Dissimilar: ##lations -0.2494139
#
# opposit
#
# similar words:
# word:  spok   with similarity:  0.22343121
# word:  cours   with similarity:  0.2207067
# word:  ##equ   with similarity:  0.217855
# Dissimilar: refr -0.25923544
#
# supporti
#
# similar words:
# word:  laptop   with similarity:  0.2091798
# word:  exict   with similarity:  0.20660485
# word:  credit   with similarity:  0.2020982
# Dissimilar: ##eadership -0.2136801
#
# supportiv
#
# similar words:
# word:  schem   with similarity:  0.21200141
# word:  ##llery   with similarity:  0.21044151
# word:  ##umb   with similarity:  0.20617008
# Dissimilar: chuffed -0.23012796
#
# supportin
#
# similar words:
# word:  ensur   with similarity:  0.22926226
# word:  ##ancially   with similarity:  0.20184113
# word:  closur   with similarity:  0.19514269
# Dissimilar: battere -0.23396038
#
# supporting
#
# similar words:
# word:  helping   with similarity:  0.56562173
# word:  actions   with similarity:  0.5337633
# word:  mindful   with similarity:  0.51270473
# Dissimilar: fuzzy -0.39642864
#
# yo
#
# similar words:
# word:  subconsciousl   with similarity:  0.206677
# word:  ##stom   with similarity:  0.19890401
# word:  medication   with similarity:  0.19716486
# Dissimilar: affectionat -0.19086674
#
# you
#
# similar words:
# word:  we   with similarity:  0.54368204
# word:  they   with similarity:  0.5377175
# word:  korean   with similarity:  0.4679573
# Dissimilar: marvellous -0.32549256
#
# yor
#
# similar words:
# word:  awarene   with similarity:  0.20978671
# word:  montagu   with similarity:  0.1998292
# word:  ##tual   with similarity:  0.1978508
# Dissimilar: ##igg -0.2168563
#
# york
#
# similar words:
# word:  situations   with similarity:  0.66317606
# word:  rehearsals   with similarity:  0.55494004
# word:  slipped   with similarity:  0.55138046
# Dissimilar: hath -0.36037135
#
# yog
#
# similar words:
# word:  rememb   with similarity:  0.22474791
# word:  ##rsecut   with similarity:  0.21000715
# word:  adolesc   with similarity:  0.20182514
# Dissimilar: sant -0.21846898
#
# yoga
#
# similar words:
# word:  ashamed   with similarity:  0.80963117
# word:  differences   with similarity:  0.78967965
# word:  habit   with similarity:  0.7514257
# Dissimilar: unhealed -0.6531512
#
# squ
#
# similar words:
# word:  ##sor   with similarity:  0.21358056
# word:  siz   with similarity:  0.20311753
# word:  educa   with similarity:  0.20110139
# Dissimilar: cla -0.20951927
#
# exci
#
# similar words:
# word:  measuring   with similarity:  0.21671714
# word:  ##tatch   with similarity:  0.21192923
# word:  ##uition   with similarity:  0.20986785
# Dissimilar: ##atsby -0.22766316
#
# excit
#
# similar words:
# word:  ##lov   with similarity:  0.22961098
# word:  typing   with similarity:  0.21036097
# word:  uncharacteristically   with similarity:  0.20446384
# Dissimilar: coordi -0.21161275
#
# app
#
# similar words:
# word:  ##lcoho   with similarity:  0.23870045
# word:  ##erms   with similarity:  0.20318562
# word:  letting   with similarity:  0.1970517
# Dissimilar: cathol -0.21906659
#
# ##app
#
# similar words:
# word:  ##eliev   with similarity:  0.2011129
# word:  mischief   with similarity:  0.20047839
# word:  machin   with similarity:  0.19995564
# Dissimilar: ##rpetually -0.22045138
#
# happ
#
# similar words:
# word:  twice   with similarity:  0.23320034
# word:  coppers   with similarity:  0.2156568
# word:  ##erv   with similarity:  0.20560679
# Dissimilar: ##hi -0.20895304
#
# ##sapp
#
# similar words:
# word:  ##siting   with similarity:  0.23912132
# word:  disb   with similarity:  0.23727834
# word:  single   with similarity:  0.2129485
# Dissimilar: attachme -0.21120612
#
# capp
#
# similar words:
# word:  almost   with similarity:  0.22280353
# word:  ##sitat   with similarity:  0.21987869
# word:  unencumber   with similarity:  0.21150663
# Dissimilar: ##ritish -0.21003641
#
# lapp
#
# similar words:
# word:  exhausti   with similarity:  0.20877692
# word:  ##publ   with similarity:  0.2004519
# word:  empower   with similarity:  0.19087741
# Dissimilar: goodby -0.2394063
#
# ##isapp
#
# similar words:
# word:  ##rror   with similarity:  0.22611547
# word:  caus   with similarity:  0.2133382
# word:  voic   with similarity:  0.2128756
# Dissimilar: begl -0.21320134
#
# disapp
#
# similar words:
# word:  costum   with similarity:  0.23111132
# word:  ##iqu   with similarity:  0.21642722
# word:  ##rica   with similarity:  0.19443272
# Dissimilar: afaerytal -0.2058595
#
# lappi
#
# similar words:
# word:  energetically   with similarity:  0.18865474
# word:  hesei   with similarity:  0.18773404
# word:  kamen   with similarity:  0.18739246
# Dissimilar: rally -0.21897046
#
# ##rapp
#
# similar words:
# word:  ##ilk   with similarity:  0.21128608
# word:  ##tock   with similarity:  0.20526479
# word:  dispos   with similarity:  0.2016806
# Dissimilar: ##port -0.2083222
#
# grapp
#
# similar words:
# word:  ar   with similarity:  0.24422027
# word:  prospe   with similarity:  0.20466815
# word:  ##yway   with similarity:  0.19766131
# Dissimilar: consta -0.22234923
#
# wrapp
#
# similar words:
# word:  subpa   with similarity:  0.20682444
# word:  ##rugg   with similarity:  0.19979894
# word:  ##esitant   with similarity:  0.19654547
# Dissimilar: have -0.19279438
#
# ##appr
#
# similar words:
# word:  ##ymp   with similarity:  0.22068022
# word:  zambi   with similarity:  0.21032616
# word:  formula   with similarity:  0.20219827
# Dissimilar: chosen -0.22636725
#
# grappl
#
# similar words:
# word:  ##lligence   with similarity:  0.20562527
# word:  ##tack   with similarity:  0.20561934
# word:  marginalise   with similarity:  0.18989985
# Dissimilar: ##ticu -0.20108882
#
# grappli
#
# similar words:
# word:  happin   with similarity:  0.22727159
# word:  ##iliarity   with similarity:  0.2150691
# word:  ##eback   with similarity:  0.2091256
# Dissimilar: oth -0.2594142
#
# grapplin
#
# similar words:
# word:  gang   with similarity:  0.2301399
# word:  ##resting   with similarity:  0.21590789
# word:  sing   with similarity:  0.21289848
# Dissimilar: bik -0.21244936
#
# grappling
#
# similar words:
# word:  visiting   with similarity:  0.7278199
# word:  dealing   with similarity:  0.70519894
# word:  lacking   with similarity:  0.6729091
# Dissimilar: expression -0.4453909
#
# lappin
#
# similar words:
# word:  disrespe   with similarity:  0.19948027
# word:  councilm   with similarity:  0.19806269
# word:  ##turn   with similarity:  0.19455574
# Dissimilar: baptized -0.21387942
#
# lapping
#
# similar words:
# word:  insults   with similarity:  0.50220233
# word:  difficult   with similarity:  0.497965
# word:  kamen   with similarity:  0.49618655
# Dissimilar: honestly -0.45000944
#
# ##nappr
#
# similar words:
# word:  ##lakin   with similarity:  0.20777725
# word:  disappoin   with similarity:  0.19391613
# word:  ##eminist   with similarity:  0.19052292
# Dissimilar: ##fo -0.20042285
#
# unappr
#
# similar words:
# word:  annoy   with similarity:  0.22468549
# word:  overwhe   with similarity:  0.20597523
# word:  pok   with similarity:  0.20263885
# Dissimilar: bust -0.24149773
#
# appr
#
# similar words:
# word:  ##njamin   with similarity:  0.21610449
# word:  nakaha   with similarity:  0.20689753
# word:  ##ylor   with similarity:  0.20652442
# Dissimilar: ##larm -0.24959394
#
# disappo
#
# similar words:
# word:  ##rytal   with similarity:  0.23214835
# word:  reduc   with similarity:  0.21793212
# word:  ##eattl   with similarity:  0.20947821
# Dissimilar: ##eatl -0.20343518
#
# disappoi
#
# similar words:
# word:  ##lliealicex   with similarity:  0.21064809
# word:  recogniz   with similarity:  0.20261285
# word:  ##dictabl   with similarity:  0.1982597
# Dissimilar: crone -0.20209317
#
# disappoin
#
# similar words:
# word:  ##etatch   with similarity:  0.21520488
# word:  lette   with similarity:  0.20181508
# word:  ##ctimiz   with similarity:  0.19990537
# Dissimilar: ##evic -0.21955553
#
# disappoint
#
# similar words:
# word:  bless   with similarity:  0.8330007
# word:  relax   with similarity:  0.82838434
# word:  darren   with similarity:  0.7930748
# Dissimilar: expression -0.5390755
#
# disappointm
#
# similar words:
# word:  parties   with similarity:  0.26581964
# word:  aside   with similarity:  0.22206819
# word:  for   with similarity:  0.20986965
# Dissimilar: longest -0.22865504
#
# ##mp
#
# similar words:
# word:  ##foot   with similarity:  0.20019142
# word:  ##bellious   with similarity:  0.19106367
# word:  ##membering   with similarity:  0.1903643
# Dissimilar: colum -0.20700565
#
# emp
#
# similar words:
# word:  ##inking   with similarity:  0.20701647
# word:  managem   with similarity:  0.20276427
# word:  stimulat   with similarity:  0.19854106
# Dissimilar: hoa -0.21881568
#
# ##opp
#
# similar words:
# word:  ##laying   with similarity:  0.19713695
# word:  popu   with similarity:  0.19711396
# word:  blow   with similarity:  0.19353086
# Dissimilar: fiction -0.21927112
#
# copp
#
# similar words:
# word:  shouldn   with similarity:  0.23388766
# word:  realised   with similarity:  0.23116432
# word:  kiyosh   with similarity:  0.22284994
# Dissimilar: minist -0.2337837
#
# ##hopp
#
# similar words:
# word:  po   with similarity:  0.23059696
# word:  anguishe   with similarity:  0.20381865
# word:  dinne   with similarity:  0.19057213
# Dissimilar: ##epriv -0.21413144
#
# shopp
#
# similar words:
# word:  ##aniz   with similarity:  0.20401067
# word:  carrying   with similarity:  0.20344107
# word:  unconsc   with similarity:  0.19664848
# Dissimilar: ##evelopm -0.19760095
#
# popp
#
# similar words:
# word:  sil   with similarity:  0.22004756
# word:  acquaint   with similarity:  0.21358414
# word:  ##dg   with similarity:  0.20366584
# Dissimilar: mi -0.23238738
#
# shoppi
#
# similar words:
# word:  acne   with similarity:  0.20841348
# word:  ##deem   with similarity:  0.20233136
# word:  ##amy   with similarity:  0.19936584
# Dissimilar: singl -0.19655341
#
# ##ipp
#
# similar words:
# word:  rott   with similarity:  0.24547154
# word:  scrutin   with similarity:  0.23678234
# word:  cartwhe   with similarity:  0.20653246
# Dissimilar: dign -0.24068382
#
# ripp
#
# similar words:
# word:  offend   with similarity:  0.22801764
# word:  healing   with similarity:  0.22279568
# word:  awareness   with similarity:  0.19840363
# Dissimilar: mix -0.23206833
#
# rippl
#
# similar words:
# word:  endorse   with similarity:  0.23734061
# word:  hopeless   with similarity:  0.2099563
# word:  appalled   with similarity:  0.20517647
# Dissimilar: ##rious -0.21141216
#
# rippli
#
# similar words:
# word:  inhibite   with similarity:  0.23024149
# word:  ##andf   with similarity:  0.20268954
# word:  ##dmoth   with similarity:  0.19185263
# Dissimilar: shape -0.23255672
#
# ##lipp
#
# similar words:
# word:  shar   with similarity:  0.22784324
# word:  distanc   with similarity:  0.21240328
# word:  sis   with similarity:  0.2122299
# Dissimilar: stepp -0.22022055
#
# slipp
#
# similar words:
# word:  ##dstroms   with similarity:  0.2239557
# word:  even   with similarity:  0.22197434
# word:  dorm   with similarity:  0.20915751
# Dissimilar: memb -0.23952506
#
# flipp
#
# similar words:
# word:  ##obb   with similarity:  0.20747018
# word:  ##atl   with similarity:  0.19832495
# word:  ##randfath   with similarity:  0.19473305
# Dissimilar: ##cky -0.24972792
#
# ##ripp
#
# similar words:
# word:  ##cifically   with similarity:  0.2562658
# word:  ##rsus   with similarity:  0.23655957
# word:  china   with similarity:  0.21480411
# Dissimilar: ##esidu -0.23720965
#
# ##tripp
#
# similar words:
# word:  ##aming   with similarity:  0.25921336
# word:  photogr   with similarity:  0.21351118
# word:  ##onabl   with similarity:  0.20166476
# Dissimilar: ##xt -0.19542368
#
# stripp
#
# similar words:
# word:  ##lings   with similarity:  0.20634632
# word:  ##riousl   with similarity:  0.2042343
# word:  ##aths   with similarity:  0.20394027
# Dissimilar: sleeping -0.21508475
#
# shoppin
#
# similar words:
# word:  ##thoo   with similarity:  0.20540655
# word:  ##gativity   with similarity:  0.2044726
# word:  devis   with similarity:  0.19270489
# Dissimilar: ##tti -0.22878225
#
# shopping
#
# similar words:
# word:  stepped   with similarity:  0.80484116
# word:  encounter   with similarity:  0.78856385
# word:  stared   with similarity:  0.78766286
# Dissimilar: expression -0.63349736
#
# ripplin
#
# similar words:
# word:  ski   with similarity:  0.21028961
# word:  haba   with similarity:  0.20349327
# word:  ##akup   with similarity:  0.19949012
# Dissimilar: ##lessing -0.25853857
#
# rippling
#
# similar words:
# word:  psychopathology   with similarity:  0.78271425
# word:  stem   with similarity:  0.7485685
# word:  context   with similarity:  0.74694055
# Dissimilar: unhealed -0.54668546
#
# ##topp
#
# similar words:
# word:  st   with similarity:  0.21365464
# word:  council   with similarity:  0.21163052
# word:  evo   with similarity:  0.2062336
# Dissimilar: natura -0.21891285
#
# stopp
#
# similar words:
# word:  ##ptical   with similarity:  0.23418581
# word:  impoverish   with similarity:  0.19975953
# word:  comedies   with similarity:  0.19337551
# Dissimilar: sharkn -0.2262255
#
# topp
#
# similar words:
# word:  endorphi   with similarity:  0.20729402
# word:  ##believ   with similarity:  0.20620641
# word:  cap   with similarity:  0.20536748
# Dissimilar: writ -0.2305525
#
# ##ropp
#
# similar words:
# word:  beforehand   with similarity:  0.20963757
# word:  ##manding   with similarity:  0.20529607
# word:  jul   with similarity:  0.20409635
# Dissimilar: ##bord -0.21004716
#
# dropp
#
# similar words:
# word:  chocola   with similarity:  0.22727396
# word:  rebuilding   with similarity:  0.20772508
# word:  intensely   with similarity:  0.20272912
# Dissimilar: comato -0.26712245
#
# droppi
#
# similar words:
# word:  coop   with similarity:  0.21157502
# word:  hallucina   with similarity:  0.2000779
# word:  ##rs   with similarity:  0.18700156
# Dissimilar: ##arrow -0.21745026
#
# toppi
#
# ...
# Dissimilar: aversion -0.44842836
#
# numbers
#
# similar words:
# word:  wafts   with similarity:  0.7989018
# word:  videos   with similarity:  0.76973206
# word:  protection   with similarity:  0.70898795
# Dissimilar: aversion -0.5451683
#
# watchers
#
# similar words:
# word:  lane   with similarity:  0.9302773
# word:  artists   with similarity:  0.9297083
# word:  temple   with similarity:  0.9084724
# Dissimilar: aversion -0.6228359
#
# supporters
#
# similar words:
# word:  vapor   with similarity:  0.73149014
# word:  salt   with similarity:  0.7006988
# word:  greatness   with similarity:  0.69008607
# Dissimilar: letting -0.39296708
#
# shoulders
#
# similar words:
# word:  ankle   with similarity:  0.82012075
# word:  impostor   with similarity:  0.792886
# word:  moisturizer   with similarity:  0.76339644
# Dissimilar: unhealed -0.5810972
#
# workers
#
# similar words:
# word:  co   with similarity:  0.6076735
# word:  apologise   with similarity:  0.57874095
# word:  costumes   with similarity:  0.554409
# Dissimilar: humiliating -0.30488506
#
# nighters
#
# similar words:
# word:  emptied   with similarity:  0.6109938
# word:  figuring   with similarity:  0.58469653
# word:  genres   with similarity:  0.55207604
# Dissimilar: versus -0.36299324
#
# offers
#
# similar words:
# word:  gently   with similarity:  0.58396673
# word:  examine   with similarity:  0.47512212
# word:  accusing   with similarity:  0.46064332
# Dissimilar: americana -0.3497009
#
# downers
#
# similar words:
# word:  lacking   with similarity:  0.79264987
# word:  puff   with similarity:  0.77520573
# word:  capable   with similarity:  0.7668263
# Dissimilar: education -0.507855
#
# users
#
# similar words:
# word:  trips   with similarity:  0.6643981
# word:  spend   with similarity:  0.6499184
# word:  nowadays   with similarity:  0.5741246
# Dissimilar: drunk -0.39237833
#
# mrs
#
# similar words:
# word:  refocus   with similarity:  0.59362864
# word:  gs   with similarity:  0.58774287
# word:  showing   with similarity:  0.5840724
# Dissimilar: others -0.44796354
#
# ##ners
#
# similar words:
# word:  cit   with similarity:  0.23479111
# word:  ##mistry   with similarity:  0.21465111
# word:  ##wor   with similarity:  0.19828197
# Dissimilar: ##ha -0.20922562
#
# ##eaders
#
# similar words:
# word:  ##asuring   with similarity:  0.24129802
# word:  ##laxing   with similarity:  0.21871342
# word:  disgu   with similarity:  0.19240613
# Dissimilar: ##ipro -0.21701252
#
# readers
#
# similar words:
# word:  loyal   with similarity:  0.6564071
# word:  bum   with similarity:  0.6062626
# word:  loss   with similarity:  0.5787782
# Dissimilar: service -0.4122102
#
# ##eers
#
# similar words:
# word:  fiel   with similarity:  0.1939363
# word:  screenshot   with similarity:  0.18329139
# word:  ##esnt   with similarity:  0.17819731
# Dissimilar: ##lair -0.2671366
#
# peers
#
# similar words:
# word:  typical   with similarity:  0.6595306
# word:  lamb   with similarity:  0.46598464
# word:  show   with similarity:  0.43406436
# Dissimilar: fuzzy -0.38650036
#
# careers
#
# similar words:
# word:  satan   with similarity:  0.6453622
# word:  sasha   with similarity:  0.5987401
# word:  sexually   with similarity:  0.5668595
# Dissimilar: riders -0.35168818
#
# ##eners
#
# similar words:
# word:  ##rag   with similarity:  0.19751222
# word:  davi   with similarity:  0.19583276
# word:  ##avour   with similarity:  0.19168328
# Dissimilar: ##diator -0.19890188
#
# sweeteners
#
# similar words:
# word:  grandiosely   with similarity:  0.7015875
# word:  inquire   with similarity:  0.6253782
# word:  giraffes   with similarity:  0.5972211
# Dissimilar: homis -0.4443143
#
# quite
#
# similar words:
# word:  unusually   with similarity:  0.59213006
# word:  insatiably   with similarity:  0.586293
# word:  impatient   with similarity:  0.58277893
# Dissimilar: shirley -0.3735952
#
# ##end
#
# similar words:
# word:  caw   with similarity:  0.25501496
# word:  intimated   with similarity:  0.22727032
# word:  dumpe   with similarity:  0.22556758
# Dissimilar: ##ellarium -0.2277235
#
# weekend
#
# similar words:
# word:  game   with similarity:  0.67864996
# word:  reshaped   with similarity:  0.67594916
# word:  essence   with similarity:  0.67261785
# Dissimilar: facebook -0.40127328
#
# legend
#
# similar words:
# word:  indicated   with similarity:  0.8430332
# word:  gain   with similarity:  0.7891179
# word:  paused   with similarity:  0.76960427
# Dissimilar: behind -0.50020355
#
# offend
#
# similar words:
# word:  ripp   with similarity:  0.22801764
# word:  ##ably   with similarity:  0.22770457
# word:  int   with similarity:  0.20942123
# Dissimilar: xm -0.23984297
#
# tend
#
# similar words:
# word:  succumb   with similarity:  0.8440781
# word:  preform   with similarity:  0.8426165
# word:  travel   with similarity:  0.8216981
# Dissimilar: expression -0.5563291
#
# send
#
# similar words:
# word:  university   with similarity:  0.80040854
# word:  lauper   with similarity:  0.70180684
# word:  region   with similarity:  0.6811373
# Dissimilar: unhealed -0.4452879
#
# ##nde
#
# similar words:
# word:  strange   with similarity:  0.2108123
# word:  ##rvi   with similarity:  0.20419331
# word:  repre   with similarity:  0.20326085
# Dissimilar: ##isocial -0.22260907
#
# ##ndee
#
# similar words:
# word:  flatt   with similarity:  0.20315675
# word:  missgiving   with similarity:  0.19711015
# word:  activitie   with similarity:  0.1897182
# Dissimilar: examp -0.19840683
#
# ##ndeed
#
# similar words:
# word:  chanc   with similarity:  0.23118651
# word:  disappo   with similarity:  0.19995935
# word:  wher   with similarity:  0.19567303
# Dissimilar: circu -0.24574673
#
# offende
#
# similar words:
# word:  arouse   with similarity:  0.22535433
# word:  incheswhyinche   with similarity:  0.1972204
# word:  mrdanbai   with similarity:  0.19470102
# Dissimilar: elde -0.21249123
#
# offended
#
# similar words:
# word:  whiney   with similarity:  0.7897759
# word:  jubilant   with similarity:  0.7748324
# word:  burdened   with similarity:  0.75890994
# Dissimilar: expression -0.5653932
#
# come
#
# similar words:
# word:  rise   with similarity:  0.6414396
# word:  redeem   with similarity:  0.6199358
# word:  holyhead   with similarity:  0.59078866
# Dissimilar: dread -0.4205934
#
# comes
#
# similar words:
# word:  north   with similarity:  0.6813152
# word:  standards   with similarity:  0.661462
# word:  event   with similarity:  0.6449317
# Dissimilar: unhealed -0.43925196
#
# ##ead
#
# similar words:
# word:  easi   with similarity:  0.19734967
# word:  panorm   with similarity:  0.19723725
# word:  pakis   with similarity:  0.19675955
# Dissimilar: unil -0.25598523
#
# read
#
# similar words:
# word:  table   with similarity:  0.56563103
# word:  stepped   with similarity:  0.5570171
# word:  empathize   with similarity:  0.54745984
# Dissimilar: hath -0.45211157
#
# dread
#
# similar words:
# word:  town   with similarity:  0.8999164
# word:  prank   with similarity:  0.80661815
# word:  among   with similarity:  0.79672
# Dissimilar: edgy -0.52973753
#
# ##read
#
# similar words:
# word:  wearin   with similarity:  0.21174228
# word:  dharav   with similarity:  0.20528406
# word:  nef   with similarity:  0.18992062
# Dissimilar: anticipate -0.23831646
#
# tad
#
# similar words:
# word:  catalyst   with similarity:  0.748751
# word:  slicing   with similarity:  0.7405017
# word:  failure   with similarity:  0.7215309
# Dissimilar: tastes -0.4444447
#
# rt
#
# similar words:
# word:  ##rvous   with similarity:  0.23055936
# word:  joyf   with similarity:  0.19341472
# word:  uncharact   with similarity:  0.19156343
# Dissimilar: ##asona -0.23533031
#
# ##eread
#
# similar words:
# word:  transpar   with similarity:  0.2014572
# word:  ##venty   with similarity:  0.1977642
# word:  courtes   with similarity:  0.19710861
# Dissimilar: pulling -0.2512976
#
# reread
#
# similar words:
# word:  turns   with similarity:  0.8363018
# word:  brag   with similarity:  0.81752527
# word:  deny   with similarity:  0.8154267
# Dissimilar: expression -0.56729746
#
# rte
#
# similar words:
# word:  emoticons   with similarity:  0.7486343
# word:  crime   with similarity:  0.51939607
# word:  img   with similarity:  0.49015772
# Dissimilar: parties -0.25821197
#
# shocke
#
# similar words:
# word:  jasons   with similarity:  0.2133878
# word:  besides   with similarity:  0.19344956
# word:  ##evity   with similarity:  0.19286738
# Dissimilar: ##publi -0.21573843
#
# shocked
#
# similar words:
# word:  offended   with similarity:  0.7542429
# word:  whiney   with similarity:  0.7060834
# word:  thrilled   with similarity:  0.7012053
# Dissimilar: expression -0.4562814
#
# hope
#
# similar words:
# word:  thought   with similarity:  0.8000118
# word:  dream   with similarity:  0.74726975
# word:  wish   with similarity:  0.7442607
# Dissimilar: dread -0.49034765
#
# hopel
#
# similar words:
# word:  unfortu   with similarity:  0.22681832
# word:  dar   with similarity:  0.19165109
# word:  ##low   with similarity:  0.18947807
# Dissimilar: deliv -0.25542846
#
# hopes
#
# similar words:
# word:  jubilant   with similarity:  0.624096
# word:  hyper   with similarity:  0.6005763
# word:  rabbits   with similarity:  0.5681038
# Dissimilar: accept -0.39329895
#
# hopele
#
# similar words:
# word:  wasn   with similarity:  0.21771747
# word:  stopped   with similarity:  0.20331207
# word:  sound   with similarity:  0.2017738
# Dissimilar: atte -0.21309248
#
# hopeless
#
# similar words:
# word:  admiration   with similarity:  0.8120752
# word:  blush   with similarity:  0.7845468
# word:  cringe   with similarity:  0.7705607
# Dissimilar: expression -0.5303571
#
# she
#
# similar words:
# word:  he   with similarity:  0.6036403
# word:  biochemistry   with similarity:  0.4729221
# word:  housebound   with similarity:  0.47266433
# Dissimilar: transformers -0.331695
#
# shr
#
# similar words:
# word:  ##atiably   with similarity:  0.2308507
# word:  self   with similarity:  0.21324374
# word:  anguish   with similarity:  0.20333521
# Dissimilar: ##ci -0.22459956
#
# shes
#
# similar words:
# word:  hes   with similarity:  0.6329802
# word:  active   with similarity:  0.5992607
# word:  sexually   with similarity:  0.58307505
# Dissimilar: thousands -0.42546937
#
# shre
#
# similar words:
# word:  aggressiv   with similarity:  0.21340275
# word:  ##rsation   with similarity:  0.20419046
# word:  ##rriag   with similarity:  0.19044031
# Dissimilar: ##flix -0.2645387
#
# shred
#
# similar words:
# word:  string   with similarity:  0.63276285
# word:  motivation   with similarity:  0.6079885
# word:  tab   with similarity:  0.586824
# Dissimilar: rally -0.4133059
#
# live
#
# similar words:
# word:  stated   with similarity:  0.72367936
# word:  walk   with similarity:  0.7054032
# word:  preform   with similarity:  0.6972222
# Dissimilar: aversion -0.50020623
#
# lives
#
# similar words:
# word:  midst   with similarity:  0.5679307
# word:  daycare   with similarity:  0.5623942
# word:  sandblog   with similarity:  0.54225665
# Dissimilar: aversion -0.3318902
#
# accepte
#
# similar words:
# word:  ##timiz   with similarity:  0.24637926
# word:  ##ndmoth   with similarity:  0.1944405
# word:  ##eodorant   with similarity:  0.189351
# Dissimilar: ##utho -0.21381089
#
# accepted
#
# similar words:
# word:  honoured   with similarity:  0.77683973
# word:  someones   with similarity:  0.77204823
# word:  belong   with similarity:  0.7669537
# Dissimilar: transformers -0.4894576
#
# ##ens
#
# similar words:
# word:  intolerably   with similarity:  0.22820377
# word:  everywhe   with similarity:  0.21210799
# word:  ##lave   with similarity:  0.20098518
# Dissimilar: in -0.25020936
#
# jens
#
# similar words:
# word:  retirement   with similarity:  0.74046594
# word:  shortly   with similarity:  0.5328263
# word:  large   with similarity:  0.47813976
# Dissimilar: deteriorate -0.29899332
#
# sens
#
# similar words:
# word:  bou   with similarity:  0.19959904
# word:  volunte   with similarity:  0.19159678
# word:  platitude   with similarity:  0.19122392
# Dissimilar: chor -0.25023228
#
# listens
#
# similar words:
# word:  percieve   with similarity:  0.7718881
# word:  relating   with similarity:  0.7356918
# word:  introduce   with similarity:  0.69751203
# Dissimilar: fuzzy -0.5224404
#
# tons
#
# similar words:
# word:  periods   with similarity:  0.8421003
# word:  lauren   with similarity:  0.81112564
# word:  depth   with similarity:  0.76840407
# Dissimilar: education -0.38813484
#
# sense
#
# similar words:
# word:  combined   with similarity:  0.69455564
# word:  plenty   with similarity:  0.65626335
# word:  chapter   with similarity:  0.6556008
# Dissimilar: fiction -0.37112102
#
# ##er
#
# similar words:
# word:  lifting   with similarity:  0.50984704
# word:  dropping   with similarity:  0.482486
# word:  refined   with similarity:  0.46084166
# Dissimilar: americana -0.32673207
#
# matter
#
# similar words:
# word:  acceptance   with similarity:  0.73035556
# word:  comprehend   with similarity:  0.69052416
# word:  directly   with similarity:  0.6902334
# Dissimilar: unhealed -0.4767748
#
# flower
#
# similar words:
# word:  crystal   with similarity:  0.5421112
# word:  police   with similarity:  0.5116839
# word:  crashed   with similarity:  0.5053377
# Dissimilar: deke -0.45744395
#
# tender
#
# similar words:
# word:  groggy   with similarity:  0.7071098
# word:  rushed   with similarity:  0.68762386
# word:  dazed   with similarity:  0.6827257
# Dissimilar: unconsciously -0.42721388
#
# paper
#
# similar words:
# word:  hoax   with similarity:  0.78883684
# word:  habit   with similarity:  0.7842048
# word:  conscience   with similarity:  0.76735234
# Dissimilar: aversion -0.65754724
#
# bother
#
# similar words:
# word:  stress   with similarity:  0.74843746
# word:  threaten   with similarity:  0.7406484
# word:  ridden   with similarity:  0.7059154
# Dissimilar: thousands -0.4664551
#
# younger
#
# similar words:
# word:  bicycle   with similarity:  0.6603957
# word:  series   with similarity:  0.65574527
# word:  worthless   with similarity:  0.6124009
# Dissimilar: islam -0.39661953
#
# slower
#
# similar words:
# word:  soothe   with similarity:  0.7075872
# word:  obnoxious   with similarity:  0.6161269
# word:  expressing   with similarity:  0.59093606
# Dissimilar: iced -0.3469384
#
# employer
#
# similar words:
# word:  indonesia   with similarity:  0.7429391
# word:  stems   with similarity:  0.61635214
# word:  lord   with similarity:  0.60901207
# Dissimilar: understad -0.37420285
#
# sober
#
# similar words:
# word:  ask   with similarity:  0.70965236
# word:  refresh   with similarity:  0.70626825
# word:  warn   with similarity:  0.6975344
# Dissimilar: expression -0.5938931
#
# leader
#
# similar words:
# word:  appetite   with similarity:  0.6726482
# word:  insecurities   with similarity:  0.6033507
# word:  intake   with similarity:  0.59436816
# Dissimilar: displays -0.41646588
#
# teacher
#
# similar words:
# word:  conditions   with similarity:  0.90193796
# word:  schach   with similarity:  0.8796042
# word:  dharma   with similarity:  0.8763233
# Dissimilar: tastes -0.48513174
#
# follower
#
# similar words:
# word:  ba   with similarity:  0.6921106
# word:  fair   with similarity:  0.6656329
# word:  speech   with similarity:  0.66398287
# Dissimilar: halloween -0.38810763
#
# shower
#
# similar words:
# word:  wuss   with similarity:  0.715748
# word:  wrap   with similarity:  0.70845395
# word:  sip   with similarity:  0.6974411
# Dissimilar: islam -0.4600254
#
# designer
#
# similar words:
# word:  ini   with similarity:  0.79287004
# word:  indicated   with similarity:  0.785881
# word:  rmb   with similarity:  0.744682
# Dissimilar: eulalias -0.4507888
#
# wilder
#
# similar words:
# word:  films   with similarity:  0.61917764
# word:  billy   with similarity:  0.53063035
# word:  wally   with similarity:  0.4533469
# Dissimilar: killing -0.45163077
#
# number
#
# similar words:
# word:  piece   with similarity:  0.71082026
# word:  plenty   with similarity:  0.6878703
# word:  amusement   with similarity:  0.68510157
# Dissimilar: hugely -0.4615923
#
# greater
#
# similar words:
# word:  federal   with similarity:  0.5512445
# word:  transcendent   with similarity:  0.5331765
# word:  distressed   with similarity:  0.53104466
# Dissimilar: [PAD] -0.39255673
#
# per
#
# similar words:
# word:  showcase   with similarity:  0.56187606
# word:  flames   with similarity:  0.5119186
# word:  abusive   with similarity:  0.501443
# Dissimilar: luke -0.3377484
#
# prayer
#
# similar words:
# word:  chair   with similarity:  0.5196464
# word:  shades   with similarity:  0.51953447
# word:  firs   with similarity:  0.50882566
# Dissimilar: accept -0.32905596
